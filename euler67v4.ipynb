# %%
from pprint import pprint
import copy

# %%
def fileReader():
    tempList=[]   
    with open(r"/Users/aaronSmith/Documents/p067_triangle.txt","r") as f:
        lines = list(map(lambda l: l.strip(), f.readlines()))
        for i in range(len(lines)):
            for j in lines[i].split(","):

                tempList.append(j.split(" "))
                
    triangleList=[]
    for l in tempList:
        l=list(map(int,l))
        triangleList.append(l)
    
    return triangleList

# %%
def plinko(choices):
    try:
        listOfLists=[]
        while True:
            tempList=[]
            shrinkingChoices=copy.deepcopy(choices)

            if len(choices[2])>=len(choices[3]):
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(choices[2].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(1,-1,-1):
                    tempList.append(shrinkingChoices[i].pop(-1))
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[1])>=len(choices[2]):
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(choices[1].pop())
                shrinkingChoices=copy.deepcopy(choices)
                tempList.append(shrinkingChoices[0].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[0])>=len(choices[1]):
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(shrinkingChoices[1].pop())
                tempList.append(choices[0].pop())
                shrinkingChoices=copy.deepcopy(choices)
                listOfLists.append(tempList)
                tempList=[]
                continue
                
            else:
                tempList.append(choices[3].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(2,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
 
    except IndexError:
#         listOfLists.pop()
        return listOfLists

# %%
triangleList=fileReader()
iY=0
finalPathSum=triangleList[0][0]
print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")


for i in range(len(triangleList)-4):
    testList=copy.deepcopy(triangleList[iY+1:iY+5])
    choices=copy.deepcopy(testList)

    allLists=[]
    listOfLists=plinko(choices)
    allLists.extend(listOfLists)

    reverseChoices=copy.deepcopy(testList)
    for i in range(len(reverseChoices)):
        reverseChoices[i].reverse()

    listOfLists=plinko(reverseChoices)
    allLists.extend(listOfLists)

    sumList=[]
    for l in allLists:
        sumList.append(sum(l)) 
    pickedNumber=allLists[sumList.index(max(sumList))][-1]
    finalPathSum+=pickedNumber
    print("\nOriginal Cone of choices")
    pprint(testList)
    print("\nThe best backwards path is", allLists[sumList.index(max(sumList))], "with a sum of", max(sumList),
          "\n",pickedNumber,"is the picked number in the next row\n")
    iY+=1
    if testList[0].index(pickedNumber)==0:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop()
    else:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop(0)
    print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")
finalPathSum+=max(sumList)
print("\nAdding in", max(sumList), "for the final 4 rows, and the grand total of", finalPathSum)

print(triangleList)
# finalAnswer supposed to be 7273
# Out:
# Current Path Sum= 59 after row 0
#
#
#
#
# Original Cone of choices
# [[73, 41], [52, 40, 9], [26, 53, 6, 34], [10, 51, 87, 86, 81]]
#
# The best backwards path is [87, 53, 52, 73] with a sum of 265
#  73 is the picked number in the next row
#
# Current Path Sum= 132 after row 1
#
#
#
#
# Original Cone of choices
# [[52, 40], [26, 53, 6], [10, 51, 87, 86], [61, 95, 66, 57, 25]]
#
# The best backwards path is [66, 87, 53, 52] with a sum of 258
#  52 is the picked number in the next row
#
# Current Path Sum= 184 after row 2
#
#
#
#
# Original Cone of choices
# [[26, 53], [10, 51, 87], [61, 95, 66, 57], [90, 81, 80, 38, 92]]
#
# The best backwards path is [92, 57, 87, 53] with a sum of 289
#  53 is the picked number in the next row
#
# Current Path Sum= 237 after row 3
#
#
#
#
# Original Cone of choices
# [[51, 87], [95, 66, 57], [81, 80, 38, 92], [28, 51, 76, 81, 18]]
#
# The best backwards path is [81, 92, 57, 87] with a sum of 317
#  87 is the picked number in the next row
#
# Current Path Sum= 324 after row 4
#
#
#
#
# Original Cone of choices
# [[66, 57], [80, 38, 92], [51, 76, 81, 18], [95, 87, 62, 81, 17]]
#
# The best backwards path is [81, 81, 92, 57] with a sum of 311
#  57 is the picked number in the next row
#
# Current Path Sum= 381 after row 5
#
#
#
#
# Original Cone of choices
# [[38, 92], [76, 81, 18], [87, 62, 81, 17], [58, 2, 79, 62, 39]]
#
# The best backwards path is [79, 81, 81, 92] with a sum of 333
#  92 is the picked number in the next row
#
# Current Path Sum= 473 after row 6
#
#
#
#
# Original Cone of choices
# [[81, 18], [62, 81, 17], [2, 79, 62, 39], [78, 31, 81, 18, 90]]
#
# The best backwards path is [81, 79, 81, 81] with a sum of 322
#  81 is the picked number in the next row
#
# Current Path Sum= 554 after row 7
#
#
#
#
# Original Cone of choices
# [[62, 81], [2, 79, 62], [78, 31, 81, 18], [84, 93, 32, 13, 97]]
#
# The best backwards path is [93, 31, 79, 81] with a sum of 284
#  81 is the picked number in the next row
#
# Current Path Sum= 635 after row 8
#
#
#
#
# Original Cone of choices
# [[79, 62], [31, 81, 18], [93, 32, 13, 97], [18, 78, 86, 13, 30]]
#
# The best backwards path is [78, 93, 31, 79] with a sum of 281
#  79 is the picked number in the next row
#
# Current Path Sum= 714 after row 9
#
#
#
#
# Original Cone of choices
# [[31, 81], [93, 32, 13], [18, 78, 86, 13], [38, 42, 17, 82, 87]]
#
# The best backwards path is [82, 86, 32, 81] with a sum of 281
#  81 is the picked number in the next row
#
# Current Path Sum= 795 after row 10
#
#
#
#
# Original Cone of choices
# [[32, 13], [78, 86, 13], [42, 17, 82, 87], [9, 7, 75, 97, 95]]
#
# The best backwards path is [97, 82, 86, 32] with a sum of 297
#  32 is the picked number in the next row
#
# Current Path Sum= 827 after row 11
#
#
#
#
# Original Cone of choices
# [[78, 86], [42, 17, 82], [9, 7, 75, 97], [94, 65, 55, 77, 55]]
#
# The best backwards path is [77, 97, 82, 86] with a sum of 342
#  86 is the picked number in the next row
#
# Current Path Sum= 913 after row 12
#
#
#
#
# Original Cone of choices
# [[17, 82], [7, 75, 97], [65, 55, 77, 55], [42, 75, 69, 23, 97]]
#
# The best backwards path is [97, 55, 97, 82] with a sum of 331
#  82 is the picked number in the next row
#
# Current Path Sum= 995 after row 13
#
#
#
#
# Original Cone of choices
# [[75, 97], [55, 77, 55], [75, 69, 23, 97], [98, 60, 13, 12, 36]]
#
# The best backwards path is [98, 75, 55, 75] with a sum of 303
#  75 is the picked number in the next row
#
# Current Path Sum= 1070 after row 14
#
#
#
#
# Original Cone of choices
# [[55, 77], [75, 69, 23], [98, 60, 13, 12], [28, 22, 34, 35, 62]]
#
# The best backwards path is [28, 98, 75, 55] with a sum of 256
#  55 is the picked number in the next row
#
# Current Path Sum= 1125 after row 15
#
#
#
#
# Original Cone of choices
# [[75, 69], [98, 60, 13], [28, 22, 34, 35], [34, 81, 62, 40, 65]]
#
# The best backwards path is [81, 28, 98, 75] with a sum of 282
#  75 is the picked number in the next row
#
# Current Path Sum= 1200 after row 16
#
#
#
#
# Original Cone of choices
# [[98, 60], [28, 22, 34], [34, 81, 62, 40], [36, 14, 70, 26, 2]]
#
# The best backwards path is [70, 81, 28, 98] with a sum of 277
#  98 is the picked number in the next row
#
# Current Path Sum= 1298 after row 17
#
#
#
#
# Original Cone of choices
# [[28, 22], [34, 81, 62], [36, 14, 70, 26], [37, 42, 14, 58, 84]]
#
# The best backwards path is [58, 70, 81, 28] with a sum of 237
#  28 is the picked number in the next row
#
# Current Path Sum= 1326 after row 18
#
#
#
#
# Original Cone of choices
# [[34, 81], [36, 14, 70], [37, 42, 14, 58], [84, 73, 79, 15, 39]]
#
# The best backwards path is [39, 58, 70, 81] with a sum of 248
#  81 is the picked number in the next row
#
# Current Path Sum= 1407 after row 19
#
#
#
#
# Original Cone of choices
# [[14, 70], [42, 14, 58], [73, 79, 15, 39], [37, 50, 2, 45, 9]]
#
# The best backwards path is [50, 79, 14, 70] with a sum of 213
#  70 is the picked number in the next row
#
# Current Path Sum= 1477 after row 20
#
#
#
#
# Original Cone of choices
# [[14, 58], [79, 15, 39], [50, 2, 45, 9], [78, 19, 35, 62, 71]]
#
# The best backwards path is [78, 50, 79, 14] with a sum of 221
#  14 is the picked number in the next row
#
# Current Path Sum= 1491 after row 21
#
#
#
#
# Original Cone of choices
# [[79, 15], [50, 2, 45], [78, 19, 35, 62], [91, 54, 46, 57, 7]]
#
# The best backwards path is [91, 78, 50, 79] with a sum of 298
#  79 is the picked number in the next row
#
# Current Path Sum= 1570 after row 22
#
#
#
#
# Original Cone of choices
# [[50, 2], [78, 19, 35], [91, 54, 46, 57], [63, 49, 51, 31, 24]]
#
# The best backwards path is [63, 91, 78, 50] with a sum of 282
#  50 is the picked number in the next row
#
# Current Path Sum= 1620 after row 23
#
#
#
#
# Original Cone of choices
# [[78, 19], [91, 54, 46], [63, 49, 51, 31], [13, 3, 9, 9, 24]]
#
# The best backwards path is [13, 63, 91, 78] with a sum of 245
#  78 is the picked number in the next row
#
# Current Path Sum= 1698 after row 24
#
#
#
#
# Original Cone of choices
# [[91, 54], [63, 49, 51], [13, 3, 9, 9], [62, 49, 59, 61, 30]]
#
# The best backwards path is [62, 13, 63, 91] with a sum of 229
#  91 is the picked number in the next row
#
# Current Path Sum= 1789 after row 25
#
#
#
#
# Original Cone of choices
# [[63, 49], [13, 3, 9], [62, 49, 59, 61], [18, 98, 79, 36, 62]]
#
# The best backwards path is [98, 62, 13, 63] with a sum of 236
#  63 is the picked number in the next row
#
# Current Path Sum= 1852 after row 26
#
#
#
#
# Original Cone of choices
# [[13, 3], [62, 49, 59], [18, 98, 79, 36], [38, 13, 57, 36, 9]]
#
# The best backwards path is [57, 98, 62, 13] with a sum of 230
#  13 is the picked number in the next row
#
# Current Path Sum= 1865 after row 27
#
#
#
#
# Original Cone of choices
# [[62, 49], [18, 98, 79], [38, 13, 57, 36], [3, 21, 27, 22, 19]]
#
# The best backwards path is [27, 57, 98, 62] with a sum of 244
#  62 is the picked number in the next row
#
# Current Path Sum= 1927 after row 28
#
#
#
#
# Original Cone of choices
# [[18, 98], [38, 13, 57], [3, 21, 27, 22], [21, 5, 64, 42, 62]]
#
# The best backwards path is [64, 27, 57, 98] with a sum of 246
#  98 is the picked number in the next row
#
# Current Path Sum= 2025 after row 29
#
#
#
#
# Original Cone of choices
# [[13, 57], [21, 27, 22], [5, 64, 42, 62], [16, 44, 82, 38, 30]]
#
# The best backwards path is [82, 64, 27, 57] with a sum of 230
#  57 is the picked number in the next row
#
# Current Path Sum= 2082 after row 30
#
#
#
#
# Original Cone of choices
# [[27, 22], [64, 42, 62], [44, 82, 38, 30], [39, 7, 4, 34, 21]]
#
# The best backwards path is [7, 82, 64, 27] with a sum of 180
#  27 is the picked number in the next row
#
# Current Path Sum= 2109 after row 31
#
#
#
#
# Original Cone of choices
# [[64, 42], [44, 82, 38], [39, 7, 4, 34], [7, 69, 51, 96, 3]]
#
# The best backwards path is [96, 4, 82, 64] with a sum of 246
#  64 is the picked number in the next row
#
# Current Path Sum= 2173 after row 32
#
#
#
#
# Original Cone of choices
# [[44, 82], [39, 7, 4], [7, 69, 51, 96], [6, 34, 96, 60, 32]]
#
# The best backwards path is [96, 69, 7, 82] with a sum of 254
#  82 is the picked number in the next row
#
# Current Path Sum= 2255 after row 33
#
#
#
#
# Original Cone of choices
# [[7, 4], [69, 51, 96], [34, 96, 60, 32], [67, 6, 47, 96, 99]]
#
# The best backwards path is [96, 60, 96, 4] with a sum of 256
#  4 is the picked number in the next row
#
# Current Path Sum= 2259 after row 34
#
#
#
#
# Original Cone of choices
# [[51, 96], [96, 60, 32], [6, 47, 96, 99], [98, 81, 48, 16, 53]]
#
# The best backwards path is [48, 96, 60, 96] with a sum of 300
#  96 is the picked number in the next row
#
# Current Path Sum= 2355 after row 35
#
#
#
#
# Original Cone of choices
# [[60, 32], [47, 96, 99], [81, 48, 16, 53], [70, 83, 42, 88, 25]]
#
# The best backwards path is [83, 48, 96, 60] with a sum of 287
#  60 is the picked number in the next row
#
# Current Path Sum= 2415 after row 36
#
#
#
#
# Original Cone of choices
# [[47, 96], [81, 48, 16], [70, 83, 42, 88], [67, 53, 93, 93, 77]]
#
# The best backwards path is [93, 83, 48, 96] with a sum of 320
#  96 is the picked number in the next row
#
# Current Path Sum= 2511 after row 37
#
#
#
#
# Original Cone of choices
# [[48, 16], [83, 42, 88], [53, 93, 93, 77], [45, 60, 70, 38, 31]]
#
# The best backwards path is [70, 93, 83, 48] with a sum of 294
#  48 is the picked number in the next row
#
# Current Path Sum= 2559 after row 38
#
#
#
#
# Original Cone of choices
# [[83, 42], [53, 93, 93], [45, 60, 70, 38], [11, 58, 97, 56, 89]]
#
# The best backwards path is [97, 70, 93, 83] with a sum of 343
#  83 is the picked number in the next row
#
# Current Path Sum= 2642 after row 39
#
#
#
#
# Original Cone of choices
# [[53, 93], [45, 60, 70], [11, 58, 97, 56], [62, 59, 12, 25, 88]]
#
# The best backwards path is [88, 56, 70, 93] with a sum of 307
#  93 is the picked number in the next row
#
# Current Path Sum= 2735 after row 40
#
#
#
#
# Original Cone of choices
# [[60, 70], [58, 97, 56], [59, 12, 25, 88], [36, 62, 99, 55, 29]]
#
# The best backwards path is [99, 25, 97, 70] with a sum of 291
#  70 is the picked number in the next row
#
# Current Path Sum= 2805 after row 41
#
#
#
#
# Original Cone of choices
# [[97, 56], [12, 25, 88], [62, 99, 55, 29], [37, 29, 24, 96, 3]]
#
# The best backwards path is [96, 55, 88, 56] with a sum of 295
#  56 is the picked number in the next row
#
# Current Path Sum= 2861 after row 42
#
#
#
#
# Original Cone of choices
# [[25, 88], [99, 55, 29], [29, 24, 96, 3], [50, 45, 71, 6, 30]]
#
# The best backwards path is [71, 96, 55, 88] with a sum of 310
#  88 is the picked number in the next row
#
# Current Path Sum= 2949 after row 43
#
#
#
#
# Original Cone of choices
# [[55, 29], [24, 96, 3], [45, 71, 6, 30], [64, 2, 94, 49, 60]]
#
# The best backwards path is [94, 71, 96, 55] with a sum of 316
#  55 is the picked number in the next row
#
# Current Path Sum= 3004 after row 44
#
#
#
#
# Original Cone of choices
# [[24, 96], [45, 71, 6], [64, 2, 94, 49], [4, 42, 2, 45, 15]]
#
# The best backwards path is [45, 94, 71, 96] with a sum of 306
#  96 is the picked number in the next row
#
# Current Path Sum= 3100 after row 45
#
#
#
#
# Original Cone of choices
# [[71, 6], [2, 94, 49], [42, 2, 45, 15], [22, 11, 41, 58, 99]]
#
# The best backwards path is [58, 45, 94, 71] with a sum of 268
#  71 is the picked number in the next row
#
# Current Path Sum= 3171 after row 46
#
#
#
#
# Original Cone of choices
# [[2, 94], [42, 2, 45], [22, 11, 41, 58], [14, 26, 35, 17, 12]]
#
# The best backwards path is [35, 41, 45, 94] with a sum of 215
#  94 is the picked number in the next row
#
# Current Path Sum= 3265 after row 47
#
#
#
#
# Original Cone of choices
# [[2, 45], [11, 41, 58], [26, 35, 17, 12], [12, 36, 20, 39, 40]]
#
# The best backwards path is [39, 17, 58, 45] with a sum of 159
#  45 is the picked number in the next row
#
# Current Path Sum= 3310 after row 48
#
#
#
#
# Original Cone of choices
# [[41, 58], [35, 17, 12], [36, 20, 39, 40], [96, 76, 83, 87, 90]]
#
# The best backwards path is [96, 36, 35, 41] with a sum of 208
#  41 is the picked number in the next row
#
# Current Path Sum= 3351 after row 49
#
#
#
#
# Original Cone of choices
# [[35, 17], [36, 20, 39], [96, 76, 83, 87], [37, 62, 3, 24, 48]]
#
# The best backwards path is [62, 96, 36, 35] with a sum of 229
#  35 is the picked number in the next row
#
# Current Path Sum= 3386 after row 50
#
#
#
#
# Original Cone of choices
# [[36, 20], [96, 76, 83], [37, 62, 3, 24], [77, 31, 58, 56, 93]]
#
# The best backwards path is [58, 62, 96, 36] with a sum of 252
#  36 is the picked number in the next row
#
# Current Path Sum= 3422 after row 51
#
#
#
#
# Original Cone of choices
# [[96, 76], [37, 62, 3], [77, 31, 58, 56], [61, 50, 14, 53, 93]]
#
# The best backwards path is [61, 77, 37, 96] with a sum of 271
#  96 is the picked number in the next row
#
# Current Path Sum= 3518 after row 52
#
#
#
#
# Original Cone of choices
# [[37, 62], [77, 31, 58], [61, 50, 14, 53], [91, 43, 40, 12, 52]]
#
# The best backwards path is [91, 61, 77, 37] with a sum of 266
#  37 is the picked number in the next row
#
# Current Path Sum= 3555 after row 53
#
#
#
#
# Original Cone of choices
# [[77, 31], [61, 50, 14], [91, 43, 40, 12], [18, 70, 4, 79, 96]]
#
# The best backwards path is [70, 91, 61, 77] with a sum of 299
#  77 is the picked number in the next row
#
# Current Path Sum= 3632 after row 54
#
#
#
#
# Original Cone of choices
# [[61, 50], [91, 43, 40], [18, 70, 4, 79], [20, 44, 10, 92, 17]]
#
# The best backwards path is [44, 70, 91, 61] with a sum of 266
#  61 is the picked number in the next row
#
# Current Path Sum= 3693 after row 55
#
#
#
#
# Original Cone of choices
# [[91, 43], [18, 70, 4], [20, 44, 10, 92], [17, 70, 83, 96, 93]]
#
# The best backwards path is [83, 44, 70, 91] with a sum of 288
#  91 is the picked number in the next row
#
# Current Path Sum= 3784 after row 56
#
#
#
#
# Original Cone of choices
# [[18, 70], [20, 44, 10], [17, 70, 83, 96], [69, 40, 68, 36, 69]]
#
# The best backwards path is [68, 83, 44, 70] with a sum of 265
#  70 is the picked number in the next row
#
# Current Path Sum= 3854 after row 57
#
#
#
#
# Original Cone of choices
# [[44, 10], [70, 83, 96], [40, 68, 36, 69], [43, 38, 55, 17, 44]]
#
# The best backwards path is [55, 68, 83, 44] with a sum of 250
#  44 is the picked number in the next row
#
# Current Path Sum= 3898 after row 58
#
#
#
#
# Original Cone of choices
# [[70, 83], [40, 68, 36], [43, 38, 55, 17], [32, 72, 84, 17, 8]]
#
# The best backwards path is [84, 55, 68, 83] with a sum of 290
#  83 is the picked number in the next row
#
# Current Path Sum= 3981 after row 59
#
#
#
#
# Original Cone of choices
# [[68, 36], [38, 55, 17], [72, 84, 17, 8], [45, 33, 4, 64, 55]]
#
# The best backwards path is [33, 84, 55, 68] with a sum of 240
#  68 is the picked number in the next row
#
# Current Path Sum= 4049 after row 60
#
#
#
#
# Original Cone of choices
# [[38, 55], [72, 84, 17], [45, 33, 4, 64], [26, 91, 24, 6, 21]]
#
# The best backwards path is [91, 33, 84, 55] with a sum of 263
#  55 is the picked number in the next row
#
# Current Path Sum= 4104 after row 61
#
#
#
#
# Original Cone of choices
# [[84, 17], [33, 4, 64], [91, 24, 6, 21], [71, 66, 30, 19, 57]]
#
# The best backwards path is [71, 91, 33, 84] with a sum of 279
#  84 is the picked number in the next row
#
# Current Path Sum= 4188 after row 62
#
#
#
#
# Original Cone of choices
# [[33, 4], [91, 24, 6], [71, 66, 30, 19], [7, 18, 64, 57, 80]]
#
# The best backwards path is [64, 66, 91, 33] with a sum of 254
#  33 is the picked number in the next row
#
# Current Path Sum= 4221 after row 63
#
#
#
#
# Original Cone of choices
# [[91, 24], [71, 66, 30], [7, 18, 64, 57], [99, 98, 30, 94, 91]]
#
# The best backwards path is [94, 64, 66, 91] with a sum of 315
#  91 is the picked number in the next row
#
# Current Path Sum= 4312 after row 64
#
#
#
#
# Original Cone of choices
# [[71, 66], [7, 18, 64], [99, 98, 30, 94], [46, 64, 41, 56, 44]]
#
# The best backwards path is [56, 94, 64, 66] with a sum of 280
#  66 is the picked number in the next row
#
# Current Path Sum= 4378 after row 65
#
#
#
#
# Original Cone of choices
# [[18, 64], [98, 30, 94], [64, 41, 56, 44], [21, 23, 54, 35, 90]]
#
# The best backwards path is [90, 44, 94, 64] with a sum of 292
#  64 is the picked number in the next row
#
# Current Path Sum= 4442 after row 66
#
#
#
#
# Original Cone of choices
# [[30, 94], [41, 56, 44], [23, 54, 35, 90], [80, 41, 90, 22, 82]]
#
# The best backwards path is [82, 90, 44, 94] with a sum of 310
#  94 is the picked number in the next row
#
# Current Path Sum= 4536 after row 67
#
#
#
#
# Original Cone of choices
# [[56, 44], [54, 35, 90], [41, 90, 22, 82], [22, 95, 43, 62, 11]]
#
# The best backwards path is [95, 90, 54, 56] with a sum of 295
#  56 is the picked number in the next row
#
# Current Path Sum= 4592 after row 68
#
#
#
#
# Original Cone of choices
# [[54, 35], [41, 90, 22], [22, 95, 43, 62], [64, 65, 89, 7, 79]]
#
# The best backwards path is [89, 95, 90, 54] with a sum of 328
#  54 is the picked number in the next row
#
# Current Path Sum= 4646 after row 69
#
#
#
#
# Original Cone of choices
# [[41, 90], [22, 95, 43], [64, 65, 89, 7], [82, 80, 48, 56, 20]]
#
# The best backwards path is [56, 89, 95, 90] with a sum of 330
#  90 is the picked number in the next row
#
# Current Path Sum= 4736 after row 70
#
#
#
#
# Original Cone of choices
# [[95, 43], [65, 89, 7], [80, 48, 56, 20], [66, 73, 44, 30, 74]]
#
# The best backwards path is [73, 80, 65, 95] with a sum of 313
#  95 is the picked number in the next row
#
# Current Path Sum= 4831 after row 71
#
#
#
#
# Original Cone of choices
# [[65, 89], [80, 48, 56], [66, 73, 44, 30], [58, 33, 90, 15, 22]]
#
# The best backwards path is [90, 73, 80, 65] with a sum of 308
#  65 is the picked number in the next row
#
# Current Path Sum= 4896 after row 72
#
#
#
#
# Original Cone of choices
# [[80, 48], [66, 73, 44], [58, 33, 90, 15], [86, 54, 85, 34, 28]]
#
# The best backwards path is [85, 90, 73, 80] with a sum of 328
#  80 is the picked number in the next row
#
# Current Path Sum= 4976 after row 73
#
#
#
#
# Original Cone of choices
# [[66, 73], [58, 33, 90], [86, 54, 85, 34], [72, 96, 81, 22, 8]]
#
# The best backwards path is [81, 85, 90, 73] with a sum of 329
#  73 is the picked number in the next row
#
# Current Path Sum= 5049 after row 74
#
#
#
#
# Original Cone of choices
# [[33, 90], [54, 85, 34], [96, 81, 22, 8], [90, 90, 8, 48, 19]]
#
# The best backwards path is [90, 81, 85, 90] with a sum of 346
#  90 is the picked number in the next row
#
# Current Path Sum= 5139 after row 75
#
#
#
#
# Original Cone of choices
# [[85, 34], [81, 22, 8], [90, 8, 48, 19], [70, 51, 22, 15, 92]]
#
# The best backwards path is [70, 90, 81, 85] with a sum of 326
#  85 is the picked number in the next row
#
# Current Path Sum= 5224 after row 76
#
#
#
#
# Original Cone of choices
# [[81, 22], [90, 8, 48], [70, 51, 22, 15], [15, 76, 74, 70, 84]]
#
# The best backwards path is [76, 70, 90, 81] with a sum of 317
#  81 is the picked number in the next row
#
# Current Path Sum= 5305 after row 77
#
#
#
#
# Original Cone of choices
# [[90, 8], [70, 51, 22], [15, 76, 74, 70], [12, 30, 24, 62, 84]]
#
# The best backwards path is [62, 74, 51, 90] with a sum of 277
#  90 is the picked number in the next row
#
# Current Path Sum= 5395 after row 78
#
#
#
#
# Original Cone of choices
# [[70, 51], [15, 76, 74], [12, 30, 24, 62], [13, 15, 66, 61, 68]]
#
# The best backwards path is [68, 62, 74, 51] with a sum of 255
#  51 is the picked number in the next row
#
# Current Path Sum= 5446 after row 79
#
#
#
#
# Original Cone of choices
# [[76, 74], [30, 24, 62], [15, 66, 61, 68], [72, 26, 88, 54, 36]]
#
# The best backwards path is [88, 61, 62, 74] with a sum of 285
#  74 is the picked number in the next row
#
# Current Path Sum= 5520 after row 80
#
#
#
#
# Original Cone of choices
# [[24, 62], [66, 61, 68], [26, 88, 54, 36], [59, 27, 44, 77, 94]]
#
# The best backwards path is [77, 54, 68, 62] with a sum of 261
#  62 is the picked number in the next row
#
# Current Path Sum= 5582 after row 81
#
#
#
#
# Original Cone of choices
# [[61, 68], [88, 54, 36], [27, 44, 77, 94], [65, 40, 48, 23, 19]]
#
# The best backwards path is [48, 77, 54, 68] with a sum of 247
#  68 is the picked number in the next row
#
# Current Path Sum= 5650 after row 82
#
#
#
#
# Original Cone of choices
# [[54, 36], [44, 77, 94], [40, 48, 23, 19], [31, 78, 9, 65, 50]]
#
# The best backwards path is [78, 48, 77, 54] with a sum of 257
#  54 is the picked number in the next row
#
# Current Path Sum= 5704 after row 83
#
#
#
#
# Original Cone of choices
# [[44, 77], [40, 48, 23], [31, 78, 9, 65], [58, 23, 98, 9, 37]]
#
# The best backwards path is [98, 78, 48, 77] with a sum of 301
#  77 is the picked number in the next row
#
# Current Path Sum= 5781 after row 84
#
#
#
#
# Original Cone of choices
# [[48, 23], [78, 9, 65], [23, 98, 9, 37], [80, 56, 98, 30, 51]]
#
# The best backwards path is [98, 98, 78, 48] with a sum of 322
#  48 is the picked number in the next row
#
# Current Path Sum= 5829 after row 85
#
#
#
#
# Original Cone of choices
# [[78, 9], [23, 98, 9], [80, 56, 98, 30], [56, 12, 1, 58, 37]]
#
# The best backwards path is [58, 98, 98, 78] with a sum of 332
#  78 is the picked number in the next row
#
# Current Path Sum= 5907 after row 86
#
#
#
#
# Original Cone of choices
# [[23, 98], [80, 56, 98], [56, 12, 1, 58], [44, 61, 77, 67, 50]]
#
# The best backwards path is [67, 58, 98, 98] with a sum of 321
#  98 is the picked number in the next row
#
# Current Path Sum= 6005 after row 87
#
#
#
#
# Original Cone of choices
# [[56, 98], [12, 1, 58], [61, 77, 67, 50], [27, 88, 46, 86, 94]]
#
# The best backwards path is [86, 67, 58, 98] with a sum of 309
#  98 is the picked number in the next row
#
# Current Path Sum= 6103 after row 88
#
#
#
#
# Original Cone of choices
# [[1, 58], [77, 67, 50], [88, 46, 86, 94], [57, 33, 22, 76, 46]]
#
# The best backwards path is [76, 86, 67, 58] with a sum of 287
#  58 is the picked number in the next row
#
# Current Path Sum= 6161 after row 89
#
#
#
#
# Original Cone of choices
# [[67, 50], [46, 86, 94], [33, 22, 76, 46], [36, 96, 68, 9, 64]]
# The best backwards path is [68, 76, 86, 67] with a sum of 297
#  67 is the picked number in the next row
#
# Current Path Sum= 6228 after row 90
#
#
#
#
# Original Cone of choices
# [[46, 86], [33, 22, 76], [36, 96, 68, 9], [33, 73, 73, 75, 52]]
#
# The best backwards path is [75, 68, 76, 86] with a sum of 305
#  86 is the picked number in the next row
#
# Current Path Sum= 6314 after row 91
#
#
#
#
# Original Cone of choices
# [[22, 76], [96, 68, 9], [73, 73, 75, 52], [37, 74, 32, 20, 69]]
#
# The best backwards path is [74, 73, 68, 76] with a sum of 291
#  76 is the picked number in the next row
#
# Current Path Sum= 6390 after row 92
#
#
#
#
# Original Cone of choices
# [[68, 9], [73, 75, 52], [74, 32, 20, 69], [48, 94, 74, 76, 64]]
#
# The best backwards path is [94, 74, 73, 68] with a sum of 309
#  68 is the picked number in the next row
#
# Current Path Sum= 6458 after row 93
#
#
#
#
# Original Cone of choices
# [[73, 75], [74, 32, 20], [48, 94, 74, 76], [46, 86, 35, 97, 27]]
#
# The best backwards path is [86, 94, 74, 73] with a sum of 327
#  73 is the picked number in the next row
#
# Current Path Sum= 6531 after row 94
#
#
#
#
# Original Cone of choices
# [[74, 32], [48, 94, 74], [46, 86, 35, 97], [5, 26, 38, 40, 16]]
#
# The best backwards path is [38, 86, 94, 74] with a sum of 292
#  74 is the picked number in the next row
#
# Current Path Sum= 6605 after row 95
#
#
#
#
# Original Cone of choices
# [[48, 94], [46, 86, 35], [5, 26, 38, 40], [16, 69, 57, 87, 83]]
#
# The best backwards path is [87, 38, 86, 94] with a sum of 305
#  94 is the picked number in the next row
#
# Current Path Sum= 6699 after row 96
#
#
#
#
# Adding in 305 for the final 4 rows, and the grand total of 7004
# [[59], [73], [52], [53], [87], [57], [92], [81], [81], [79], [81], [32], [86], [82], [75], [55], [75], [98], [28], [81], [70], [14], [79], [50], [78], [91], [63], [13], [62], [98], [57], [27], [64], [82], [4], [96], [60], [96], [48], [83], [93], [70], [56], [88], [55], [96], [71], [94], [45], [41], [35], [36], [96], [37], [77], [61], [91], [70], [44], [83], [68], [55], [84], [33], [91], [66], [64], [94], [56], [54], [90], [95], [65], [80], [73], [90], [85], [81], [90], [51], [74], [62], [68], [54], [77], [48], [78], [98], [98], [58], [67], [86], [76], [68], [73], [74], [94], [86, 35], [26, 38, 40], [69, 57, 87, 83]]
