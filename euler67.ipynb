# %%
from pprint import pprint
import copy

# %%
def fileReader():
    tempList=[]   
    with open(r"/Users/aaronSmith/Documents/p067_triangle.txt","r") as f:
        lines = list(map(lambda l: l.strip(), f.readlines()))
        for i in range(len(lines)):
            for j in lines[i].split(","):

                tempList.append(j.split(" "))
                
    triangleList=[]
    for l in tempList:
        l=list(map(int,l))
        triangleList.append(l)
    
    return triangleList

# %%
def plinko(choices):
    try:
        listOfLists=[]
        while True:
            tempList=[]
            shrinkingChoices=copy.deepcopy(choices)

            if len(choices[3])>=len(choices[4]):
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(choices[3].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(2,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[2])>=len(choices[3]):
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(choices[2].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(1,-1,-1):
                    tempList.append(shrinkingChoices[i].pop(-1))
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[1])>=len(choices[2]):
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(choices[1].pop())
                shrinkingChoices=copy.deepcopy(choices)
                tempList.append(shrinkingChoices[0].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[0])>=len(choices[1]):
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(shrinkingChoices[1].pop())
                tempList.append(choices[0].pop())
                shrinkingChoices=copy.deepcopy(choices)
                listOfLists.append(tempList)
                tempList=[]
                continue
                
            else:
                i=4
                tempList.append(choices[i].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(3,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
 
    except IndexError:
#         listOfLists.pop()
        return listOfLists

# %%
triangleList=fileReader()
iY=0
finalPathSum=triangleList[0][0]
print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")


for i in range(len(triangleList)-5):
    testList=copy.deepcopy(triangleList[iY+1:iY+6])
    choices=copy.deepcopy(testList)

    allLists=[]
    listOfLists=plinko(choices)
    allLists.extend(listOfLists)

    reverseChoices=copy.deepcopy(testList)
    for i in range(len(reverseChoices)):
        reverseChoices[i].reverse()

    listOfLists=plinko(reverseChoices)
    allLists.extend(listOfLists)

    sumList=[]
    for l in allLists:
        sumList.append(sum(l)) 
    pickedNumber=allLists[sumList.index(max(sumList))][-1]
    finalPathSum+=pickedNumber
    print("\nOriginal Cone of choices")
    pprint(testList)
    print("\nThe best backwards path is", allLists[sumList.index(max(sumList))], "with a sum of", max(sumList),
          "\n",pickedNumber,"is the picked number in the next row\n")
    iY+=1
    if testList[0].index(pickedNumber)==0:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop()
    else:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop(0)
    print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")
finalPathSum+=max(sumList)
print("\nAdding in", max(sumList), "for the final 5 rows, and the grand total of", finalPathSum)

# finalAnswer supposed to be 7273
# Out:
# Current Path Sum= 59 after row 0
#
#
#
#
# Original Cone of choices
# [[73, 41],
#  [52, 40, 9],
#  [26, 53, 6, 34],
#  [10, 51, 87, 86, 81],
#  [61, 95, 66, 57, 25, 68]]
#
# The best backwards path is [95, 51, 53, 52, 73] with a sum of 324
#  73 is the picked number in the next row
#
# Current Path Sum= 132 after row 1
#
#
#
#
# Original Cone of choices
# [[52, 40],
#  [26, 53, 6],
#  [10, 51, 87, 86],
#  [61, 95, 66, 57, 25],
#  [90, 81, 80, 38, 92, 67]]
#
# The best backwards path is [92, 57, 87, 53, 52] with a sum of 341
#  52 is the picked number in the next row
#
# Current Path Sum= 184 after row 2
#
#
#
#
# Original Cone of choices
# [[26, 53],
#  [10, 51, 87],
#  [61, 95, 66, 57],
#  [90, 81, 80, 38, 92],
#  [30, 28, 51, 76, 81, 18]]
#
# The best backwards path is [81, 92, 57, 87, 53] with a sum of 370
#  53 is the picked number in the next row
#
# Current Path Sum= 237 after row 3
#
#
#
#
# Original Cone of choices
# [[51, 87],
#  [95, 66, 57],
#  [81, 80, 38, 92],
#  [28, 51, 76, 81, 18],
#  [14, 95, 87, 62, 81, 17]]
#
# The best backwards path is [81, 81, 92, 57, 87] with a sum of 398
#  87 is the picked number in the next row
#
# Current Path Sum= 324 after row 4
#
#
#
#
# Original Cone of choices
# [[66, 57],
#  [80, 38, 92],
#  [51, 76, 81, 18],
#  [95, 87, 62, 81, 17],
#  [71, 58, 2, 79, 62, 39]]
#
# The best backwards path is [62, 81, 81, 92, 57] with a sum of 373
#  57 is the picked number in the next row
#
# Current Path Sum= 381 after row 5
#
#
#
#
# Original Cone of choices
# [[38, 92],
#  [76, 81, 18],
#  [87, 62, 81, 17],
#  [58, 2, 79, 62, 39],
#  [53, 78, 31, 81, 18, 90]]
#
# The best backwards path is [31, 79, 81, 81, 92] with a sum of 364
#  92 is the picked number in the next row
#
# Current Path Sum= 473 after row 6
#
#
#
#
# Original Cone of choices
# [[81, 18],
#  [62, 81, 17],
#  [2, 79, 62, 39],
#  [78, 31, 81, 18, 90],
#  [84, 93, 32, 13, 97, 11]]
#
# The best backwards path is [93, 31, 79, 81, 81] with a sum of 365
#  81 is the picked number in the next row
#
# Current Path Sum= 554 after row 7
#
#
#
#
# Original Cone of choices
# [[62, 81],
#  [2, 79, 62],
#  [78, 31, 81, 18],
#  [84, 93, 32, 13, 97],
#  [5, 18, 78, 86, 13, 30]]
#
# The best backwards path is [78, 93, 31, 79, 81] with a sum of 362
#  81 is the picked number in the next row
#
# Current Path Sum= 635 after row 8
#
#
#
#
# Original Cone of choices
# [[79, 62],
#  [31, 81, 18],
#  [93, 32, 13, 97],
#  [18, 78, 86, 13, 30],
#  [38, 42, 17, 82, 87, 58]]
#
# The best backwards path is [82, 86, 32, 81, 79] with a sum of 360
#  79 is the picked number in the next row
#
# Current Path Sum= 714 after row 9
#
#
#
#
# Original Cone of choices
# [[31, 81],
#  [93, 32, 13],
#  [18, 78, 86, 13],
#  [38, 42, 17, 82, 87],
#  [93, 9, 7, 75, 97, 95]]
#
# The best backwards path is [97, 82, 86, 32, 81] with a sum of 378
#  81 is the picked number in the next row
#
# Current Path Sum= 795 after row 10
#
#
#
#
# Original Cone of choices
# [[32, 13],
#  [78, 86, 13],
#  [42, 17, 82, 87],
#  [9, 7, 75, 97, 95],
#  [94, 65, 55, 77, 55, 34]]
#
# The best backwards path is [77, 97, 82, 86, 32] with a sum of 374
#  32 is the picked number in the next row
#
# Current Path Sum= 827 after row 11
#
#
#
#
# Original Cone of choices
# [[78, 86],
#  [42, 17, 82],
#  [9, 7, 75, 97],
#  [94, 65, 55, 77, 55],
#  [9, 42, 75, 69, 23, 97]]
#
# The best backwards path is [97, 55, 97, 82, 86] with a sum of 417
#  86 is the picked number in the next row
#
# Current Path Sum= 913 after row 12
#
#
#
#
# Original Cone of choices
# [[17, 82],
#  [7, 75, 97],
#  [65, 55, 77, 55],
#  [42, 75, 69, 23, 97],
#  [84, 98, 60, 13, 12, 36]]
#
# The best backwards path is [98, 75, 55, 75, 82] with a sum of 385
#  82 is the picked number in the next row
#
# Current Path Sum= 995 after row 13
#
#
#
#
# Original Cone of choices
# [[75, 97],
#  [55, 77, 55],
#  [75, 69, 23, 97],
#  [98, 60, 13, 12, 36],
#  [28, 22, 34, 35, 62, 62]]
#
# The best backwards path is [62, 36, 97, 55, 97] with a sum of 347
#  97 is the picked number in the next row
#
# Current Path Sum= 1092 after row 14
#
#
#
#
# Original Cone of choices
# [[77, 55],
#  [69, 23, 97],
#  [60, 13, 12, 36],
#  [22, 34, 35, 62, 62],
#  [81, 62, 40, 65, 54, 62]]
#
# The best backwards path is [62, 62, 36, 97, 55] with a sum of 312
#  55 is the picked number in the next row
#
# Current Path Sum= 1147 after row 15
#
#
#
#
# Original Cone of choices
# [[23, 97],
#  [13, 12, 36],
#  [34, 35, 62, 62],
#  [62, 40, 65, 54, 62],
#  [70, 26, 2, 90, 45, 13]]
#
# The best backwards path is [45, 62, 62, 36, 97] with a sum of 302
#  97 is the picked number in the next row
#
# Current Path Sum= 1244 after row 16
#
#
#
#
# Original Cone of choices
# [[12, 36],
#  [35, 62, 62],
#  [40, 65, 54, 62],
#  [26, 2, 90, 45, 13],
#  [58, 84, 93, 96, 17, 9]]
#
# The best backwards path is [93, 90, 65, 62, 36] with a sum of 346
#  36 is the picked number in the next row
#
# Current Path Sum= 1280 after row 17
#
#
#
#
# Original Cone of choices
# [[62, 62],
#  [65, 54, 62],
#  [2, 90, 45, 13],
#  [84, 93, 96, 17, 9],
#  [39, 95, 88, 87, 43, 39]]
#
# The best backwards path is [95, 93, 90, 65, 62] with a sum of 405
#  62 is the picked number in the next row
#
# Current Path Sum= 1342 after row 18
#
#
#
#
# Original Cone of choices
# [[65, 54],
#  [2, 90, 45],
#  [84, 93, 96, 17],
#  [39, 95, 88, 87, 43],
#  [45, 9, 54, 52, 27, 95]]
#
# The best backwards path is [52, 88, 96, 90, 65] with a sum of 391
#  65 is the picked number in the next row
#
# Current Path Sum= 1407 after row 19
#
#
#
#
# Original Cone of choices
# [[2, 90],
#  [84, 93, 96],
#  [39, 95, 88, 87],
#  [45, 9, 54, 52, 27],
#  [35, 62, 71, 19, 23, 65]]
#
# The best backwards path is [71, 54, 95, 93, 90] with a sum of 403
#  90 is the picked number in the next row
#
# Current Path Sum= 1497 after row 20
#
#
#
#
# Original Cone of choices
# [[93, 96],
#  [95, 88, 87],
#  [9, 54, 52, 27],
#  [62, 71, 19, 23, 65],
#  [57, 7, 77, 98, 52, 80]]
#
# The best backwards path is [77, 71, 54, 88, 96] with a sum of 386
#  96 is the picked number in the next row
#
# Current Path Sum= 1593 after row 21
#
#
#
#
# Original Cone of choices
# [[88, 87],
#  [54, 52, 27],
#  [71, 19, 23, 65],
#  [7, 77, 98, 52, 80],
#  [24, 68, 5, 57, 7, 54]]
#
# The best backwards path is [68, 77, 71, 54, 88] with a sum of 358
#  88 is the picked number in the next row
#
# Current Path Sum= 1681 after row 22
#
#
#
#
# Original Cone of choices
# [[54, 52],
#  [71, 19, 23],
#  [7, 77, 98, 52],
#  [24, 68, 5, 57, 7],
#  [24, 30, 71, 8, 88, 70]]
#
# The best backwards path is [88, 57, 98, 23, 52] with a sum of 318
#  52 is the picked number in the next row
#
# Current Path Sum= 1733 after row 23
#
#
#
#
# Original Cone of choices
# [[19, 23],
#  [77, 98, 52],
#  [68, 5, 57, 7],
#  [30, 71, 8, 88, 70],
#  [90, 29, 94, 26, 41, 89]]
#
# The best backwards path is [41, 88, 57, 98, 23] with a sum of 307
#  23 is the picked number in the next row
#
# Current Path Sum= 1756 after row 24
#
#
#
#
# Original Cone of choices
# [[98, 52],
#  [5, 57, 7],
#  [71, 8, 88, 70],
#  [29, 94, 26, 41, 89],
#  [17, 8, 19, 54, 89, 29]]
#
# The best backwards path is [89, 41, 88, 57, 98] with a sum of 373
#  98 is the picked number in the next row
#
# Current Path Sum= 1854 after row 25
#
#
#
#
# Original Cone of choices
# [[5, 57],
#  [71, 8, 88],
#  [29, 94, 26, 41],
#  [17, 8, 19, 54, 89],
#  [43, 89, 30, 39, 15, 2]]
#
# The best backwards path is [15, 89, 41, 88, 57] with a sum of 290
#  57 is the picked number in the next row
#
# Current Path Sum= 1911 after row 26
#
#
#
#
# Original Cone of choices
# [[8, 88],
#  [94, 26, 41],
#  [8, 19, 54, 89],
#  [89, 30, 39, 15, 2],
#  [69, 54, 4, 13, 7, 85]]
#
# The best backwards path is [85, 2, 89, 41, 88] with a sum of 305
#  88 is the picked number in the next row
#
# Current Path Sum= 1999 after row 27
#
#
#
#
# Original Cone of choices
# [[26, 41],
#  [19, 54, 89],
#  [30, 39, 15, 2],
#  [54, 4, 13, 7, 85],
#  [73, 42, 21, 23, 22, 51]]
#
# The best backwards path is [51, 85, 2, 89, 41] with a sum of 268
#  41 is the picked number in the next row
#
# Current Path Sum= 2040 after row 28
#
#
#
#
# Original Cone of choices
# [[54, 89],
#  [39, 15, 2],
#  [4, 13, 7, 85],
#  [42, 21, 23, 22, 51],
#  [52, 90, 27, 8, 65, 78]]
#
# The best backwards path is [78, 51, 85, 2, 89] with a sum of 305
#  89 is the picked number in the next row
#
# Current Path Sum= 2129 after row 29
#
#
#
#
# Original Cone of choices
# [[15, 2],
#  [13, 7, 85],
#  [21, 23, 22, 51],
#  [90, 27, 8, 65, 78],
#  [39, 84, 89, 69, 84, 46]]
#
# The best backwards path is [84, 78, 51, 85, 2] with a sum of 300
#  2 is the picked number in the next row
#
# Current Path Sum= 2131 after row 30
#
#
#
#
# Original Cone of choices
# [[7, 85],
#  [23, 22, 51],
#  [27, 8, 65, 78],
#  [84, 89, 69, 84, 46],
#  [45, 91, 20, 50, 56, 10]]
#
# The best backwards path is [56, 84, 78, 51, 85] with a sum of 354
#  85 is the picked number in the next row
#
# Current Path Sum= 2216 after row 31
#
#
#
#
# Original Cone of choices
# [[22, 51],
#  [8, 65, 78],
#  [89, 69, 84, 46],
#  [91, 20, 50, 56, 10],
#  [18, 31, 71, 50, 84, 63]]
#
# The best backwards path is [84, 56, 84, 78, 51] with a sum of 353
#  51 is the picked number in the next row
#
# Current Path Sum= 2267 after row 32
#
#
#
#
# Original Cone of choices
# [[65, 78],
#  [69, 84, 46],
#  [20, 50, 56, 10],
#  [31, 71, 50, 84, 63],
#  [7, 71, 60, 42, 72, 94]]
#
# The best backwards path is [72, 84, 56, 84, 78] with a sum of 374
#  78 is the picked number in the next row
#
# Current Path Sum= 2345 after row 33
#
#
#
#
# Original Cone of choices
# [[84, 46],
#  [50, 56, 10],
#  [71, 50, 84, 63],
#  [71, 60, 42, 72, 94],
#  [72, 93, 22, 34, 98, 20]]
#
# The best backwards path is [98, 72, 84, 56, 84] with a sum of 394
#  84 is the picked number in the next row
#
# Current Path Sum= 2429 after row 34
#
#
#
#
# Original Cone of choices
# [[50, 56],
#  [71, 50, 84],
#  [71, 60, 42, 72],
#  [72, 93, 22, 34, 98],
#  [65, 94, 80, 44, 61, 84]]
#
# The best backwards path is [84, 98, 72, 84, 56] with a sum of 394
#  56 is the picked number in the next row
#
# Current Path Sum= 2485 after row 35
#
#
#
#
# Original Cone of choices
# [[50, 84],
#  [60, 42, 72],
#  [93, 22, 34, 98],
#  [94, 80, 44, 61, 84],
#  [53, 18, 43, 77, 40, 78]]
#
# The best backwards path is [78, 84, 98, 72, 84] with a sum of 416
#  84 is the picked number in the next row
#
# Current Path Sum= 2569 after row 36
#
#
#
#
# Original Cone of choices
# [[42, 72],
#  [22, 34, 98],
#  [80, 44, 61, 84],
#  [18, 43, 77, 40, 78],
#  [69, 84, 14, 22, 56, 43]]
#
# The best backwards path is [56, 78, 84, 98, 72] with a sum of 388
#  72 is the picked number in the next row
#
# Current Path Sum= 2641 after row 37
#
#
#
#
# Original Cone of choices
# [[34, 98],
#  [44, 61, 84],
#  [43, 77, 40, 78],
#  [84, 14, 22, 56, 43],
#  [73, 8, 20, 36, 47, 81]]
#
# The best backwards path is [81, 43, 78, 84, 98] with a sum of 384
#  98 is the picked number in the next row
#
# Current Path Sum= 2739 after row 38
#
#
#
#
# Original Cone of choices
# [[61, 84],
#  [77, 40, 78],
#  [14, 22, 56, 43],
#  [8, 20, 36, 47, 81],
#  [92, 79, 87, 51, 21, 77]]
#
# The best backwards path is [77, 81, 43, 78, 84] with a sum of 363
#  84 is the picked number in the next row
#
# Current Path Sum= 2823 after row 39
#
#
#
#
# Original Cone of choices
# [[40, 78],
#  [22, 56, 43],
#  [20, 36, 47, 81],
#  [79, 87, 51, 21, 77],
#  [50, 66, 19, 82, 75, 12]]
#
# The best backwards path is [75, 77, 81, 43, 78] with a sum of 354
#  78 is the picked number in the next row
#
# Current Path Sum= 2901 after row 40
#
#
#
#
# Original Cone of choices
# [[56, 43],
#  [36, 47, 81],
#  [87, 51, 21, 77],
#  [66, 19, 82, 75, 12],
#  [59, 88, 43, 20, 66, 15]]
#
# The best backwards path is [66, 75, 77, 81, 43] with a sum of 342
#  43 is the picked number in the next row
#
# Current Path Sum= 2944 after row 41
#
#
#
#
# Original Cone of choices
# [[47, 81],
#  [51, 21, 77],
#  [19, 82, 75, 12],
#  [88, 43, 20, 66, 15],
#  [67, 18, 46, 66, 63, 1]]
#
# The best backwards path is [63, 66, 75, 77, 81] with a sum of 362
#  81 is the picked number in the next row
#
# Current Path Sum= 3025 after row 42
#
#
#
#
# Original Cone of choices
# [[21, 77],
#  [82, 75, 12],
#  [43, 20, 66, 15],
#  [18, 46, 66, 63, 1],
#  [25, 24, 96, 18, 2, 5]]
#
# The best backwards path is [96, 66, 66, 75, 77] with a sum of 380
#  77 is the picked number in the next row
#
# Current Path Sum= 3102 after row 43
#
#
#
#
# Original Cone of choices
# [[75, 12],
#  [20, 66, 15],
#  [46, 66, 63, 1],
#  [24, 96, 18, 2, 5],
#  [88, 98, 21, 67, 84, 79]]
#
# The best backwards path is [98, 96, 66, 66, 75] with a sum of 401
#  75 is the picked number in the next row
#
# Current Path Sum= 3177 after row 44
#
#
#
#
# Original Cone of choices
# [[20, 66],
#  [46, 66, 63],
#  [24, 96, 18, 2],
#  [88, 98, 21, 67, 84],
#  [36, 23, 15, 72, 16, 84]]
#
# The best backwards path is [23, 98, 96, 66, 66] with a sum of 349
#  66 is the picked number in the next row
#
# Current Path Sum= 3243 after row 45
#
#
#
#
# Original Cone of choices
# [[66, 63],
#  [96, 18, 2],
#  [98, 21, 67, 84],
#  [23, 15, 72, 16, 84],
#  [28, 84, 80, 67, 75, 62]]
#
# The best backwards path is [84, 23, 98, 96, 66] with a sum of 367
#  66 is the picked number in the next row
#
# Current Path Sum= 3309 after row 46
#
#
#
#
# Original Cone of choices
# [[96, 18],
#  [98, 21, 67],
#  [23, 15, 72, 16],
#  [28, 84, 80, 67, 75],
#  [8, 15, 56, 88, 86, 1]]
#
# The best backwards path is [88, 80, 15, 98, 96] with a sum of 377
#  96 is the picked number in the next row
#
# Current Path Sum= 3405 after row 47
#
#
#
#
# Original Cone of choices
# [[98, 21],
#  [23, 15, 72],
#  [28, 84, 80, 67],
#  [8, 15, 56, 88, 86],
#  [73, 51, 69, 9, 79, 94]]
#
# The best backwards path is [79, 88, 80, 15, 98] with a sum of 360
#  98 is the picked number in the next row
#
# Current Path Sum= 3503 after row 48
#
#
#
#
# Original Cone of choices
# [[23, 15],
#  [28, 84, 80],
#  [8, 15, 56, 88],
#  [73, 51, 69, 9, 79],
#  [33, 67, 9, 16, 96, 68]]
#
# The best backwards path is [96, 79, 88, 80, 15] with a sum of 358
#  15 is the picked number in the next row
#
# Current Path Sum= 3518 after row 49
#
#
#
#
# Original Cone of choices
# [[84, 80],
#  [15, 56, 88],
#  [51, 69, 9, 79],
#  [67, 9, 16, 96, 68],
#  [75, 25, 82, 39, 50, 65]]
#
# The best backwards path is [50, 96, 79, 88, 80] with a sum of 393
#  80 is the picked number in the next row
#
# Current Path Sum= 3598 after row 50
# Original Cone of choices
# [[56, 88],
#  [69, 9, 79],
#  [9, 16, 96, 68],
#  [25, 82, 39, 50, 65],
#  [48, 20, 10, 72, 60, 61]]
#
# The best backwards path is [60, 50, 96, 79, 88] with a sum of 373
#  88 is the picked number in the next row
#
# Current Path Sum= 3686 after row 51
#
#
#
#
# Original Cone of choices
# [[9, 79],
#  [16, 96, 68],
#  [82, 39, 50, 65],
#  [20, 10, 72, 60, 61],
#  [71, 37, 92, 40, 47, 99]]
#
# The best backwards path is [92, 72, 50, 96, 79] with a sum of 389
#  79 is the picked number in the next row
#
# Current Path Sum= 3765 after row 52
#
#
#
#
# Original Cone of choices
# [[96, 68],
#  [39, 50, 65],
#  [10, 72, 60, 61],
#  [37, 92, 40, 47, 99],
#  [31, 50, 92, 79, 23, 47]]
#
# The best backwards path is [92, 92, 72, 50, 68] with a sum of 374
#  68 is the picked number in the next row
#
# Current Path Sum= 3833 after row 53
#
#
#
#
# Original Cone of choices
# [[50, 65],
#  [72, 60, 61],
#  [92, 40, 47, 99],
#  [50, 92, 79, 23, 47],
#  [91, 1, 30, 63, 15, 49]]
#
# The best backwards path is [91, 50, 92, 72, 50] with a sum of 355
#  50 is the picked number in the next row
#
# Current Path Sum= 3883 after row 54
#
#
#
#
# Original Cone of choices
# [[72, 60],
#  [92, 40, 47],
#  [50, 92, 79, 23],
#  [91, 1, 30, 63, 15],
#  [72, 99, 14, 50, 98, 92]]
#
# The best backwards path is [99, 91, 50, 92, 72] with a sum of 404
#  72 is the picked number in the next row
#
# Current Path Sum= 3955 after row 55
#
#
#
#
# Original Cone of choices
# [[92, 40],
#  [50, 92, 79],
#  [91, 1, 30, 63],
#  [72, 99, 14, 50, 98],
#  [90, 13, 40, 44, 71, 90]]
#
# The best backwards path is [90, 72, 91, 50, 92] with a sum of 395
#  92 is the picked number in the next row
#
# Current Path Sum= 4047 after row 56
#
#
#
#
# Original Cone of choices
# [[50, 92],
#  [91, 1, 30],
#  [72, 99, 14, 50],
#  [90, 13, 40, 44, 71],
#  [24, 23, 29, 96, 51, 55]]
#
# The best backwards path is [96, 40, 99, 91, 50] with a sum of 376
#  50 is the picked number in the next row
#
# Current Path Sum= 4097 after row 57
#
#
#
#
# Original Cone of choices
# [[91, 1],
#  [72, 99, 14],
#  [90, 13, 40, 44],
#  [24, 23, 29, 96, 51],
#  [36, 48, 54, 56, 56, 27]]
#
# The best backwards path is [56, 96, 40, 99, 91] with a sum of 382
#  91 is the picked number in the next row
#
# Current Path Sum= 4188 after row 58
#
#
#
#
# Original Cone of choices
# [[72, 99],
#  [90, 13, 40],
#  [24, 23, 29, 96],
#  [36, 48, 54, 56, 56],
#  [84, 23, 44, 89, 72, 35]]
#
# The best backwards path is [72, 56, 96, 40, 99] with a sum of 363
#  99 is the picked number in the next row
#
# Current Path Sum= 4287 after row 59
#
#
#
#
# Original Cone of choices
# [[13, 40],
#  [23, 29, 96],
#  [48, 54, 56, 56],
#  [23, 44, 89, 72, 35],
#  [3, 64, 56, 97, 87, 63]]
#
# The best backwards path is [87, 72, 56, 96, 40] with a sum of 351
#  40 is the picked number in the next row
#
# Current Path Sum= 4327 after row 60
#
#
#
#
# Original Cone of choices
# [[29, 96],
#  [54, 56, 56],
#  [44, 89, 72, 35],
#  [64, 56, 97, 87, 63],
#  [77, 56, 41, 18, 14, 87]]
#
# The best backwards path is [41, 97, 89, 56, 96] with a sum of 379
#  96 is the picked number in the next row
#
# Current Path Sum= 4423 after row 61
#
#
#
#
# Original Cone of choices
# [[56, 56],
#  [89, 72, 35],
#  [56, 97, 87, 63],
#  [56, 41, 18, 14, 87],
#  [97, 32, 64, 29, 41, 7]]
#
# The best backwards path is [97, 56, 56, 89, 56] with a sum of 354
#  56 is the picked number in the next row
#
# Current Path Sum= 4479 after row 62
#
#
#
#
# Original Cone of choices
# [[89, 72],
#  [56, 97, 87],
#  [56, 41, 18, 14],
#  [97, 32, 64, 29, 41],
#  [66, 99, 21, 41, 95, 80]]
#
# The best backwards path is [99, 97, 56, 56, 89] with a sum of 397
#  89 is the picked number in the next row
#
# Current Path Sum= 4568 after row 63
#
#
#
#
# Original Cone of choices
# [[56, 97],
#  [56, 41, 18],
#  [97, 32, 64, 29],
#  [66, 99, 21, 41, 95],
#  [22, 28, 76, 69, 46, 48]]
#
# The best backwards path is [76, 99, 32, 41, 97] with a sum of 345
#  97 is the picked number in the next row
#
# Current Path Sum= 4665 after row 64
#
#
#
#
# Original Cone of choices
# [[41, 18],
#  [32, 64, 29],
#  [99, 21, 41, 95],
#  [28, 76, 69, 46, 48],
#  [55, 66, 84, 65, 42, 98]]
#
# The best backwards path is [66, 76, 99, 32, 41] with a sum of 314
#  41 is the picked number in the next row
#
# Current Path Sum= 4706 after row 65
#
#
#
#
# Original Cone of choices
# [[32, 64],
#  [99, 21, 41],
#  [28, 76, 69, 46],
#  [55, 66, 84, 65, 42],
#  [57, 23, 65, 67, 40, 72]]
#
# The best backwards path is [67, 84, 76, 99, 32] with a sum of 358
#  32 is the picked number in the next row
#
# Current Path Sum= 4738 after row 66
#
#
#
#
# Original Cone of choices
# [[99, 21],
#  [28, 76, 69],
#  [55, 66, 84, 65],
#  [57, 23, 65, 67, 40],
#  [16, 70, 85, 19, 25, 59]]
#
# The best backwards path is [25, 67, 84, 76, 99] with a sum of 351
#  99 is the picked number in the next row
#
# Current Path Sum= 4837 after row 67
#
#
#
#
# Original Cone of choices
# [[28, 76],
#  [55, 66, 84],
#  [57, 23, 65, 67],
#  [16, 70, 85, 19, 25],
#  [72, 7, 5, 27, 61, 24]]
#
# The best backwards path is [5, 85, 65, 84, 76] with a sum of 315
#  76 is the picked number in the next row
#
# Current Path Sum= 4913 after row 68
#
#
#
#
# Original Cone of choices
# [[66, 84],
#  [23, 65, 67],
#  [70, 85, 19, 25],
#  [7, 5, 27, 61, 24],
#  [9, 48, 44, 80, 90, 22]]
#
# The best backwards path is [90, 61, 25, 67, 84] with a sum of 327
#  84 is the picked number in the next row
#
# Current Path Sum= 4997 after row 69
#
#
#
#
# Original Cone of choices
# [[65, 67],
#  [85, 19, 25],
#  [5, 27, 61, 24],
#  [48, 44, 80, 90, 22],
#  [91, 39, 75, 75, 18, 58]]
#
# The best backwards path is [75, 80, 27, 85, 65] with a sum of 332
#  65 is the picked number in the next row
#
# Current Path Sum= 5062 after row 70
#
#
#
#
# Original Cone of choices
# [[85, 19],
#  [5, 27, 61],
#  [48, 44, 80, 90],
#  [91, 39, 75, 75, 18],
#  [61, 36, 27, 28, 46, 98]]
#
# The best backwards path is [46, 75, 80, 27, 85] with a sum of 313
#  85 is the picked number in the next row
#
# Current Path Sum= 5147 after row 71
#
#
#
#
# Original Cone of choices
# [[5, 27],
#  [48, 44, 80],
#  [91, 39, 75, 75],
#  [61, 36, 27, 28, 46],
#  [22, 48, 90, 20, 5, 96]]
#
# The best backwards path is [96, 46, 75, 80, 27] with a sum of 324
#  27 is the picked number in the next row
#
# Current Path Sum= 5174 after row 72
#
#
#
#
# Original Cone of choices
# [[44, 80],
#  [39, 75, 75],
#  [36, 27, 28, 46],
#  [48, 90, 20, 5, 96],
#  [89, 34, 96, 91, 48, 76]]
#
# The best backwards path is [76, 96, 46, 75, 80] with a sum of 373
#  80 is the picked number in the next row
#
# Current Path Sum= 5254 after row 73
#
#
#
#
# Original Cone of choices
# [[75, 75],
#  [27, 28, 46],
#  [90, 20, 5, 96],
#  [34, 96, 91, 48, 76],
#  [7, 9, 49, 34, 31, 77]]
#
# The best backwards path is [77, 76, 96, 46, 75] with a sum of 370
#  75 is the picked number in the next row
#
# Current Path Sum= 5329 after row 74
#
#
#
#
# Original Cone of choices
# [[27, 28],
#  [90, 20, 5],
#  [34, 96, 91, 48],
#  [7, 9, 49, 34, 31],
#  [10, 98, 65, 83, 21, 5]]
#
# The best backwards path is [83, 49, 96, 90, 27] with a sum of 345
#  27 is the picked number in the next row
#
# Current Path Sum= 5356 after row 75
#
#
#
#
# Original Cone of choices
# [[90, 20],
#  [34, 96, 91],
#  [7, 9, 49, 34],
#  [10, 98, 65, 83, 21],
#  [28, 81, 5, 99, 66, 81]]
#
# The best backwards path is [99, 83, 49, 96, 90] with a sum of 417
#  90 is the picked number in the next row
#
# Current Path Sum= 5446 after row 76
#
#
#
#
# Original Cone of choices
# [[34, 96],
#  [7, 9, 49],
#  [10, 98, 65, 83],
#  [28, 81, 5, 99, 66],
#  [65, 97, 86, 9, 50, 94]]
#
# The best backwards path is [94, 66, 83, 49, 96] with a sum of 388
#  96 is the picked number in the next row
#
# Current Path Sum= 5542 after row 77
#
#
#
#
# Original Cone of choices
# [[9, 49],
#  [98, 65, 83],
#  [81, 5, 99, 66],
#  [97, 86, 9, 50, 94],
#  [8, 28, 33, 40, 94, 76]]
#
# The best backwards path is [94, 94, 66, 83, 49] with a sum of 386
#  49 is the picked number in the next row
#
# Current Path Sum= 5591 after row 78
#
#
#
#
# Original Cone of choices
# [[65, 83],
#  [5, 99, 66],
#  [86, 9, 50, 94],
#  [28, 33, 40, 94, 76],
#  [94, 34, 40, 68, 87, 84]]
#
# The best backwards path is [87, 94, 94, 66, 83] with a sum of 424
#  83 is the picked number in the next row
#
# Current Path Sum= 5674 after row 79
#
#
#
#
# Original Cone of choices
# [[99, 66],
#  [9, 50, 94],
#  [33, 40, 94, 76],
#  [34, 40, 68, 87, 84],
#  [64, 83, 58, 85, 17, 76]]
#
# The best backwards path is [85, 87, 94, 50, 99] with a sum of 415
#  99 is the picked number in the next row
#
# Current Path Sum= 5773 after row 80
#
#
#
#
# Original Cone of choices
# [[9, 50],
#  [33, 40, 94],
#  [34, 40, 68, 87],
#  [64, 83, 58, 85, 17],
#  [99, 79, 34, 65, 79, 27]]
#
# The best backwards path is [79, 85, 87, 94, 50] with a sum of 395
#  50 is the picked number in the next row
#
# Current Path Sum= 5823 after row 81
#
#
#
#
# Original Cone of choices
# [[40, 94],
#  [40, 68, 87],
#  [83, 58, 85, 17],
#  [79, 34, 65, 79, 27],
#  [15, 80, 97, 44, 78, 49]]
#
# The best backwards path is [97, 65, 85, 87, 94] with a sum of 428
#  94 is the picked number in the next row
#
# Current Path Sum= 5917 after row 82
#
#
#
#
# Original Cone of choices
# [[68, 87],
#  [58, 85, 17],
#  [34, 65, 79, 27],
#  [80, 97, 44, 78, 49],
#  [45, 25, 10, 28, 19, 6]]
#
# The best backwards path is [25, 97, 65, 85, 87] with a sum of 359
#  87 is the picked number in the next row
#
# Current Path Sum= 6004 after row 83
#
#
#
#
# Original Cone of choices
# [[85, 17],
#  [65, 79, 27],
#  [97, 44, 78, 49],
#  [25, 10, 28, 19, 6],
#  [35, 53, 18, 35, 45, 54]]
#
# The best backwards path is [53, 25, 97, 65, 85] with a sum of 325
#  85 is the picked number in the next row
#
# Current Path Sum= 6089 after row 84
#
#
#
#
# Original Cone of choices
# [[65, 79],
#  [97, 44, 78],
#  [25, 10, 28, 19],
#  [35, 53, 18, 35, 45],
#  [45, 18, 69, 96, 88, 36]]
#
# The best backwards path is [88, 45, 19, 78, 79] with a sum of 309
#  79 is the picked number in the next row
#
# Current Path Sum= 6168 after row 85
#
#
#
#
# Original Cone of choices
# [[44, 78],
#  [10, 28, 19],
#  [53, 18, 35, 45],
#  [18, 69, 96, 88, 36],
#  [73, 5, 93, 48, 17, 31]]
#
# The best backwards path is [93, 96, 35, 28, 78] with a sum of 330
#  78 is the picked number in the next row
#
# Current Path Sum= 6246 after row 86
#
#
#
#
# Original Cone of choices
# [[28, 19],
#  [18, 35, 45],
#  [69, 96, 88, 36],
#  [5, 93, 48, 17, 31],
#  [51, 4, 83, 99, 75, 90]]
#
# The best backwards path is [83, 93, 96, 35, 19] with a sum of 326
#  19 is the picked number in the next row
#
# Current Path Sum= 6265 after row 87
#
#
#
#
# Original Cone of choices
# [[35, 45],
#  [96, 88, 36],
#  [93, 48, 17, 31],
#  [4, 83, 99, 75, 90],
#  [99, 76, 49, 18, 72, 66]]
#
# The best backwards path is [76, 83, 93, 96, 35] with a sum of 383
#  35 is the picked number in the next row
#
# Current Path Sum= 6300 after row 88
#
#
#
#
# Original Cone of choices
# [[96, 88],
#  [93, 48, 17],
#  [4, 83, 99, 75],
#  [99, 76, 49, 18, 72],
#  [32, 14, 6, 35, 78, 20]]
#
# The best backwards path is [14, 76, 83, 93, 96] with a sum of 362
#  96 is the picked number in the next row
#
# Current Path Sum= 6396 after row 89
#
#
#
#
# Original Cone of choices
# [[93, 48],
#  [4, 83, 99],
#  [99, 76, 49, 18],
#  [32, 14, 6, 35, 78],
#  [90, 65, 1, 87, 42, 47]]
#
# The best backwards path is [87, 35, 49, 83, 93] with a sum of 347
#  93 is the picked number in the next row
#
# Current Path Sum= 6489 after row 90
#
#
#
#
# Original Cone of choices
# [[4, 83],
#  [99, 76, 49],
#  [32, 14, 6, 35],
#  [90, 65, 1, 87, 42],
#  [85, 85, 80, 53, 34, 87]]
#
# The best backwards path is [85, 65, 14, 76, 83] with a sum of 323
#  83 is the picked number in the next row
#
# Current Path Sum= 6572 after row 91
#
#
#
#
# Original Cone of choices
# [[76, 49],
#  [14, 6, 35],
#  [65, 1, 87, 42],
#  [85, 80, 53, 34, 87],
#  [83, 15, 75, 99, 1, 89]]
#
# The best backwards path is [83, 85, 65, 14, 76] with a sum of 323
#  76 is the picked number in the next row
#
# Current Path Sum= 6648 after row 92
#
#
#
#
# Original Cone of choices
# [[14, 6],
#  [65, 1, 87],
#  [85, 80, 53, 34],
#  [83, 15, 75, 99, 1],
#  [39, 50, 31, 42, 64, 70]]
#
# The best backwards path is [64, 99, 53, 87, 6] with a sum of 309
#  6 is the picked number in the next row
#
# Current Path Sum= 6654 after row 93
#
#
#
#
# Original Cone of choices
# [[1, 87],
#  [80, 53, 34],
#  [15, 75, 99, 1],
#  [50, 31, 42, 64, 70],
#  [69, 4, 85, 57, 77, 35]]
#
# The best backwards path is [77, 64, 99, 53, 87] with a sum of 380
#  87 is the picked number in the next row
#
# Current Path Sum= 6741 after row 94
#
#
#
#
# Original Cone of choices
# [[53, 34],
#  [75, 99, 1],
#  [31, 42, 64, 70],
#  [4, 85, 57, 77, 35],
#  [51, 56, 59, 63, 7, 25]]
#
# The best backwards path is [63, 77, 64, 99, 53] with a sum of 356
#  53 is the picked number in the next row
#
# Current Path Sum= 6794 after row 95
#
#
#
#
# Adding in 356 for the final 5 rows, and the grand total of 7150
