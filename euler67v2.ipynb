# %%
from pprint import pprint
import copy

# %%
def fileReader():
    tempList=[]   
    with open(r"/Users/aaronSmith/Documents/p067_triangle.txt","r") as f:
        lines = list(map(lambda l: l.strip(), f.readlines()))
        for i in range(len(lines)):
            for j in lines[i].split(","):

                tempList.append(j.split(" "))
                
    triangleList=[]
    for l in tempList:
        l=list(map(int,l))
        triangleList.append(l)
    
    return triangleList

# %%
def plinko(choices):
    try:
        listOfLists=[]
        while True:
            tempList=[]
            shrinkingChoices=copy.deepcopy(choices)

            if len(choices[4])>=len(choices[5]):
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(choices[4].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(3,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue
            
            if len(choices[3])>=len(choices[4]):
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(choices[3].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(2,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[2])>=len(choices[3]):
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(choices[2].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(1,-1,-1):
                    tempList.append(shrinkingChoices[i].pop(-1))
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[1])>=len(choices[2]):
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(choices[1].pop())
                shrinkingChoices=copy.deepcopy(choices)
                tempList.append(shrinkingChoices[0].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[0])>=len(choices[1]):
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(shrinkingChoices[1].pop())
                tempList.append(choices[0].pop())
                shrinkingChoices=copy.deepcopy(choices)
                listOfLists.append(tempList)
                tempList=[]
                continue
                
            else:
                tempList.append(choices[5].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(4,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
 
    except IndexError:
#         listOfLists.pop()
        return listOfLists

# %%
triangleList=fileReader()
iY=0
finalPathSum=triangleList[0][0]
print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")


for i in range(len(triangleList)-6):
    testList=copy.deepcopy(triangleList[iY+1:iY+7])
    choices=copy.deepcopy(testList)

    allLists=[]
    listOfLists=plinko(choices)
    allLists.extend(listOfLists)

    reverseChoices=copy.deepcopy(testList)
    for i in range(len(reverseChoices)):
        reverseChoices[i].reverse()

    listOfLists=plinko(reverseChoices)
    allLists.extend(listOfLists)

    sumList=[]
    for l in allLists:
        sumList.append(sum(l)) 
    pickedNumber=allLists[sumList.index(max(sumList))][-1]
    finalPathSum+=pickedNumber
    print("\nOriginal Cone of choices")
    pprint(testList)
    print("\nThe best backwards path is", allLists[sumList.index(max(sumList))], "with a sum of", max(sumList),
          "\n",pickedNumber,"is the picked number in the next row\n")
    iY+=1
    if testList[0].index(pickedNumber)==0:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop()
    else:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop(0)
    print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")
finalPathSum+=max(sumList)
print("\nAdding in", max(sumList), "for the final 6 rows, and the grand total of", finalPathSum)
print(triangleList)
# finalAnswer supposed to be 7273
# Out:
# Current Path Sum= 59 after row 0
#
#
#
#
# Original Cone of choices
# [[73, 41],
#  [52, 40, 9],
#  [26, 53, 6, 34],
#  [10, 51, 87, 86, 81],
#  [61, 95, 66, 57, 25, 68],
#  [90, 81, 80, 38, 92, 67, 73]]
#
# The best backwards path is [92, 57, 87, 53, 52, 73] with a sum of 414
#  73 is the picked number in the next row
#
# Current Path Sum= 132 after row 1
#
#
#
#
# Original Cone of choices
# [[52, 40],
#  [26, 53, 6],
#  [10, 51, 87, 86],
#  [61, 95, 66, 57, 25],
#  [90, 81, 80, 38, 92, 67],
#  [30, 28, 51, 76, 81, 18, 75]]
#
# The best backwards path is [81, 92, 57, 87, 53, 52] with a sum of 422
#  52 is the picked number in the next row
#
# Current Path Sum= 184 after row 2
#
#
#
#
# Original Cone of choices
# [[26, 53],
#  [10, 51, 87],
#  [61, 95, 66, 57],
#  [90, 81, 80, 38, 92],
#  [30, 28, 51, 76, 81, 18],
#  [84, 14, 95, 87, 62, 81, 17]]
#
# The best backwards path is [81, 81, 92, 57, 87, 53] with a sum of 451
#  53 is the picked number in the next row
#
# Current Path Sum= 237 after row 3
#
#
#
#
# Original Cone of choices
# [[51, 87],
#  [95, 66, 57],
#  [81, 80, 38, 92],
#  [28, 51, 76, 81, 18],
#  [14, 95, 87, 62, 81, 17],
#  [46, 71, 58, 2, 79, 62, 39]]
#
# The best backwards path is [62, 81, 81, 92, 57, 87] with a sum of 460
#  87 is the picked number in the next row
#
# Current Path Sum= 324 after row 4
#
#
#
#
# Original Cone of choices
# [[66, 57],
#  [80, 38, 92],
#  [51, 76, 81, 18],
#  [95, 87, 62, 81, 17],
#  [71, 58, 2, 79, 62, 39],
#  [35, 53, 78, 31, 81, 18, 90]]
#
# The best backwards path is [81, 79, 62, 76, 80, 66] with a sum of 444
#  66 is the picked number in the next row
#
# Current Path Sum= 390 after row 5
#
#
#
#
# Original Cone of choices
# [[80, 38],
#  [51, 76, 81],
#  [95, 87, 62, 81],
#  [71, 58, 2, 79, 62],
#  [35, 53, 78, 31, 81, 18],
#  [4, 21, 84, 93, 32, 13, 97]]
#
# The best backwards path is [84, 78, 58, 87, 76, 38] with a sum of 421
#  38 is the picked number in the next row
#
# Current Path Sum= 428 after row 6
#
#
#
#
# Original Cone of choices
# [[76, 81],
#  [87, 62, 81],
#  [58, 2, 79, 62],
#  [53, 78, 31, 81, 18],
#  [21, 84, 93, 32, 13, 97],
#  [79, 5, 18, 78, 86, 13, 30]]
#
# The best backwards path is [86, 32, 81, 79, 62, 76] with a sum of 416
#  76 is the picked number in the next row
#
# Current Path Sum= 504 after row 7
#
#
#
#
# Original Cone of choices
# [[87, 62],
#  [58, 2, 79],
#  [53, 78, 31, 81],
#  [21, 84, 93, 32, 13],
#  [79, 5, 18, 78, 86, 13],
#  [28, 3, 38, 42, 17, 82, 87]]
#
# The best backwards path is [82, 86, 32, 81, 79, 62] with a sum of 422
#  62 is the picked number in the next row
#
# Current Path Sum= 566 after row 8
#
#
#
#
# Original Cone of choices
# [[2, 79],
#  [78, 31, 81],
#  [84, 93, 32, 13],
#  [5, 18, 78, 86, 13],
#  [3, 38, 42, 17, 82, 87],
#  [7, 93, 9, 7, 75, 97, 95]]
#
# The best backwards path is [97, 82, 86, 32, 81, 79] with a sum of 457
#  79 is the picked number in the next row
#
# Current Path Sum= 645 after row 9
#
#
#
#
# Original Cone of choices
# [[31, 81],
#  [93, 32, 13],
#  [18, 78, 86, 13],
#  [38, 42, 17, 82, 87],
#  [93, 9, 7, 75, 97, 95],
#  [99, 94, 65, 55, 77, 55, 34]]
#
# The best backwards path is [55, 97, 82, 86, 32, 81] with a sum of 433
#  81 is the picked number in the next row
#
# Current Path Sum= 726 after row 10
#
#
#
#
# Original Cone of choices
# [[32, 13],
#  [78, 86, 13],
#  [42, 17, 82, 87],
#  [9, 7, 75, 97, 95],
#  [94, 65, 55, 77, 55, 34],
#  [9, 42, 75, 69, 23, 97, 30]]
#
# The best backwards path is [97, 55, 97, 82, 86, 32] with a sum of 449
#  32 is the picked number in the next row
#
# Current Path Sum= 758 after row 11
#
#
#
#
# Original Cone of choices
# [[78, 86],
#  [42, 17, 82],
#  [9, 7, 75, 97],
#  [94, 65, 55, 77, 55],
#  [9, 42, 75, 69, 23, 97],
#  [32, 84, 98, 60, 13, 12, 36]]
#
# The best backwards path is [98, 75, 55, 75, 82, 86] with a sum of 471
#  86 is the picked number in the next row
#
# Current Path Sum= 844 after row 12
#
#
#
#
# Original Cone of choices
# [[17, 82],
#  [7, 75, 97],
#  [65, 55, 77, 55],
#  [42, 75, 69, 23, 97],
#  [84, 98, 60, 13, 12, 36],
#  [48, 28, 22, 34, 35, 62, 62]]
#
# The best backwards path is [62, 36, 97, 55, 97, 82] with a sum of 429
#  82 is the picked number in the next row
#
# Current Path Sum= 926 after row 13
#
#
#
#
# Original Cone of choices
# [[75, 97],
#  [55, 77, 55],
#  [75, 69, 23, 97],
#  [98, 60, 13, 12, 36],
#  [28, 22, 34, 35, 62, 62],
#  [34, 81, 62, 40, 65, 54, 62]]
#
# The best backwards path is [81, 28, 98, 75, 55, 75] with a sum of 412
#  75 is the picked number in the next row
#
# Current Path Sum= 1001 after row 14
#
#
#
#
# Original Cone of choices
# [[55, 77],
#  [75, 69, 23],
#  [98, 60, 13, 12],
#  [28, 22, 34, 35, 62],
#  [34, 81, 62, 40, 65, 54],
#  [36, 14, 70, 26, 2, 90, 45]]
#
# The best backwards path is [70, 81, 22, 60, 69, 77] with a sum of 379
#  77 is the picked number in the next row
#
# Current Path Sum= 1078 after row 15
#
#
#
#
# Original Cone of choices
# [[69, 23],
#  [60, 13, 12],
#  [22, 34, 35, 62],
#  [81, 62, 40, 65, 54],
#  [14, 70, 26, 2, 90, 45],
#  [42, 14, 58, 84, 93, 96, 17]]
#
# The best backwards path is [96, 90, 65, 35, 13, 69] with a sum of 368
#  69 is the picked number in the next row
#
# Current Path Sum= 1147 after row 16
#
#
#
#
# Original Cone of choices
# [[60, 13],
#  [22, 34, 35],
#  [81, 62, 40, 65],
#  [14, 70, 26, 2, 90],
#  [42, 14, 58, 84, 93, 96],
#  [73, 79, 15, 39, 95, 88, 87]]
#
# The best backwards path is [88, 96, 90, 65, 35, 13] with a sum of 387
#  13 is the picked number in the next row
#
# Current Path Sum= 1160 after row 17
#
#
#
#
# Original Cone of choices
# [[34, 35],
#  [62, 40, 65],
#  [70, 26, 2, 90],
#  [14, 58, 84, 93, 96],
#  [79, 15, 39, 95, 88, 87],
#  [50, 2, 45, 9, 54, 52, 27]]
#
# The best backwards path is [52, 88, 96, 90, 65, 35] with a sum of 426
#  35 is the picked number in the next row
#
# Current Path Sum= 1195 after row 18
#
#
#
#
# Original Cone of choices
# [[40, 65],
#  [26, 2, 90],
#  [58, 84, 93, 96],
#  [15, 39, 95, 88, 87],
#  [2, 45, 9, 54, 52, 27],
#  [19, 35, 62, 71, 19, 23, 65]]
#
# The best backwards path is [65, 27, 87, 96, 90, 65] with a sum of 430
#  65 is the picked number in the next row
#
# Current Path Sum= 1260 after row 19
#
#
#
#
# Original Cone of choices
# [[2, 90],
#  [84, 93, 96],
#  [39, 95, 88, 87],
#  [45, 9, 54, 52, 27],
#  [35, 62, 71, 19, 23, 65],
#  [46, 57, 7, 77, 98, 52, 80]]
#
# The best backwards path is [80, 65, 27, 87, 96, 90] with a sum of 445
#  90 is the picked number in the next row
#
# Current Path Sum= 1350 after row 20
#
#
#
#
# Original Cone of choices
# [[93, 96],
#  [95, 88, 87],
#  [9, 54, 52, 27],
#  [62, 71, 19, 23, 65],
#  [57, 7, 77, 98, 52, 80],
#  [31, 24, 68, 5, 57, 7, 54]]
#
# The best backwards path is [68, 77, 71, 54, 88, 96] with a sum of 454
#  96 is the picked number in the next row
#
# Current Path Sum= 1446 after row 21
#
#
#
#
# Original Cone of choices
# [[88, 87],
#  [54, 52, 27],
#  [71, 19, 23, 65],
#  [7, 77, 98, 52, 80],
#  [24, 68, 5, 57, 7, 54],
#  [24, 30, 71, 8, 88, 70, 72]]
#
# The best backwards path is [88, 57, 98, 23, 52, 88] with a sum of 406
#  88 is the picked number in the next row
#
# Current Path Sum= 1534 after row 22
#
#
#
#
# Original Cone of choices
# [[54, 52],
#  [71, 19, 23],
#  [7, 77, 98, 52],
#  [24, 68, 5, 57, 7],
#  [24, 30, 71, 8, 88, 70],
#  [30, 90, 29, 94, 26, 41, 89]]
#
# The best backwards path is [90, 30, 68, 77, 71, 54] with a sum of 390
#  54 is the picked number in the next row
#
# Current Path Sum= 1588 after row 23
#
#
#
#
# Original Cone of choices
# [[71, 19],
#  [7, 77, 98],
#  [24, 68, 5, 57],
#  [24, 30, 71, 8, 88],
#  [30, 90, 29, 94, 26, 41],
#  [62, 13, 17, 8, 19, 54, 89]]
#
# The best backwards path is [19, 94, 71, 68, 77, 71] with a sum of 400
#  71 is the picked number in the next row
#
# Current Path Sum= 1659 after row 24
#
#
#
#
# Original Cone of choices
# [[7, 77],
#  [24, 68, 5],
#  [24, 30, 71, 8],
#  [30, 90, 29, 94, 26],
#  [62, 13, 17, 8, 19, 54],
#  [9, 30, 43, 89, 30, 39, 15]]
#
# The best backwards path is [39, 19, 94, 71, 68, 77] with a sum of 368
#  77 is the picked number in the next row
#
# Current Path Sum= 1736 after row 25
#
#
#
#
# Original Cone of choices
# [[68, 5],
#  [30, 71, 8],
#  [90, 29, 94, 26],
#  [13, 17, 8, 19, 54],
#  [30, 43, 89, 30, 39, 15],
#  [26, 82, 69, 54, 4, 13, 7]]
#
# The best backwards path is [69, 89, 8, 94, 71, 5] with a sum of 336
#  5 is the picked number in the next row
#
# Current Path Sum= 1741 after row 26
#
#
#
#
# Original Cone of choices
# [[71, 8],
#  [29, 94, 26],
#  [17, 8, 19, 54],
#  [43, 89, 30, 39, 15],
#  [82, 69, 54, 4, 13, 7],
#  [36, 20, 73, 42, 21, 23, 22]]
#
# The best backwards path is [20, 69, 89, 8, 94, 71] with a sum of 351
#  71 is the picked number in the next row
#
# Current Path Sum= 1812 after row 27
#
#
#
#
# Original Cone of choices
# [[29, 94],
#  [17, 8, 19],
#  [43, 89, 30, 39],
#  [82, 69, 54, 4, 13],
#  [36, 20, 73, 42, 21, 23],
#  [72, 11, 46, 52, 90, 27, 8]]
#
# The best backwards path is [46, 73, 69, 89, 8, 94] with a sum of 379
#  94 is the picked number in the next row
#
# Current Path Sum= 1906 after row 28
#
#
#
#
# Original Cone of choices
# [[8, 19],
#  [89, 30, 39],
#  [69, 54, 4, 13],
#  [20, 73, 42, 21, 23],
#  [11, 46, 52, 90, 27, 8],
#  [98, 39, 15, 39, 84, 89, 69]]
#
# The best backwards path is [84, 90, 42, 54, 89, 8] with a sum of 367
#  8 is the picked number in the next row
#
# Current Path Sum= 1914 after row 29
#
#
#
#
# Original Cone of choices
# [[89, 30],
#  [69, 54, 4],
#  [20, 73, 42, 21],
#  [11, 46, 52, 90, 27],
#  [98, 39, 15, 39, 84, 89],
#  [96, 47, 90, 90, 45, 91, 20]]
#
# The best backwards path is [91, 84, 90, 42, 54, 89] with a sum of 450
#  89 is the picked number in the next row
#
# Current Path Sum= 2003 after row 30
#
#
#
#
# Original Cone of choices
# [[69, 54],
#  [20, 73, 42],
#  [11, 46, 52, 90],
#  [98, 39, 15, 39, 84],
#  [96, 47, 90, 90, 45, 91],
#  [69, 68, 33, 75, 84, 18, 31]]
#
# The best backwards path is [84, 90, 39, 52, 73, 69] with a sum of 407
#  69 is the picked number in the next row
#
# Current Path Sum= 2072 after row 31
#
#
#
#
# Original Cone of choices
# [[20, 73],
#  [11, 46, 52],
#  [98, 39, 15, 39],
#  [96, 47, 90, 90, 45],
#  [69, 68, 33, 75, 84, 18],
#  [99, 34, 21, 32, 47, 52, 7]]
#
# The best backwards path is [99, 69, 96, 98, 11, 20] with a sum of 393
#  20 is the picked number in the next row
#
# Current Path Sum= 2092 after row 32
#
#
#
#
# Original Cone of choices
# [[11, 46],
#  [98, 39, 15],
#  [96, 47, 90, 90],
#  [69, 68, 33, 75, 84],
#  [99, 34, 21, 32, 47, 52],
#  [16, 53, 88, 37, 52, 69, 95]]
#
# The best backwards path is [53, 99, 69, 96, 98, 11] with a sum of 426
#  11 is the picked number in the next row
#
# Current Path Sum= 2103 after row 33
#
#
#
#
# Original Cone of choices
# [[98, 39],
#  [96, 47, 90],
#  [69, 68, 33, 75],
#  [99, 34, 21, 32, 47],
#  [16, 53, 88, 37, 52, 69],
#  [42, 88, 25, 53, 51, 30, 15]]
#
# The best backwards path is [88, 53, 99, 69, 96, 98] with a sum of 503
#  98 is the picked number in the next row
#
# Current Path Sum= 2201 after row 34
#
#
#
#
# Original Cone of choices
# [[96, 47],
#  [69, 68, 33],
#  [99, 34, 21, 32],
#  [16, 53, 88, 37, 52],
#  [42, 88, 25, 53, 51, 30],
#  [93, 93, 77, 47, 67, 39, 72]]
#
# The best backwards path is [93, 88, 53, 99, 69, 96] with a sum of 498
#  96 is the picked number in the next row
#
# Current Path Sum= 2297 after row 35
#
#
#
#
# Original Cone of choices
# [[69, 68],
#  [99, 34, 21],
#  [16, 53, 88, 37],
#  [42, 88, 25, 53, 51],
#  [93, 93, 77, 47, 67, 39],
#  [60, 70, 38, 31, 85, 65, 61]]
#
# The best backwards path is [70, 93, 88, 53, 99, 69] with a sum of 472
#  69 is the picked number in the next row
#
# Current Path Sum= 2366 after row 36
#
#
#
#
# Original Cone of choices
# [[99, 34],
#  [16, 53, 88],
#  [42, 88, 25, 53],
#  [93, 93, 77, 47, 67],
#  [60, 70, 38, 31, 85, 65],
#  [58, 97, 56, 89, 31, 77, 45]]
#
# The best backwards path is [97, 70, 93, 88, 53, 99] with a sum of 500
#  99 is the picked number in the next row
#
# Current Path Sum= 2465 after row 37
#
#
#
#
# Original Cone of choices
# [[16, 53],
#  [42, 88, 25],
#  [93, 93, 77, 47],
#  [60, 70, 38, 31, 85],
#  [58, 97, 56, 89, 31, 77],
#  [59, 12, 25, 88, 28, 91, 50]]
#
# The best backwards path is [25, 97, 70, 93, 88, 53] with a sum of 426
#  53 is the picked number in the next row
#
# Current Path Sum= 2518 after row 38
#
#
#
#
# Original Cone of choices
# [[88, 25],
#  [93, 77, 47],
#  [70, 38, 31, 85],
#  [97, 56, 89, 31, 77],
#  [12, 25, 88, 28, 91, 50],
#  [62, 99, 55, 29, 53, 42, 12]]
#
# The best backwards path is [99, 25, 97, 70, 93, 88] with a sum of 472
#  88 is the picked number in the next row
#
# Current Path Sum= 2606 after row 39
#
#
#
#
# Original Cone of choices
# [[93, 77],
#  [70, 38, 31],
#  [97, 56, 89, 31],
#  [12, 25, 88, 28, 91],
#  [62, 99, 55, 29, 53, 42],
#  [37, 29, 24, 96, 3, 27, 70]]
#
# The best backwards path is [29, 99, 25, 97, 70, 93] with a sum of 413
#  93 is the picked number in the next row
#
# Current Path Sum= 2699 after row 40
#
#
#
#
# Original Cone of choices
# [[70, 38],
#  [97, 56, 89],
#  [12, 25, 88, 28],
#  [62, 99, 55, 29, 53],
#  [37, 29, 24, 96, 3, 27],
#  [91, 50, 45, 71, 6, 30, 67]]
#
# The best backwards path is [6, 96, 55, 88, 56, 70] with a sum of 371
#  70 is the picked number in the next row
#
# Current Path Sum= 2769 after row 41
#
#
#
#
# Original Cone of choices
# [[97, 56],
#  [12, 25, 88],
#  [62, 99, 55, 29],
#  [37, 29, 24, 96, 3],
#  [91, 50, 45, 71, 6, 30],
#  [55, 53, 64, 2, 94, 49, 60]]
#
# The best backwards path is [94, 71, 96, 55, 25, 97] with a sum of 438
#  97 is the picked number in the next row
#
# Current Path Sum= 2866 after row 42
#
#
#
#
# Original Cone of choices
# [[12, 25],
#  [62, 99, 55],
#  [37, 29, 24, 96],
#  [91, 50, 45, 71, 6],
#  [55, 53, 64, 2, 94, 49],
#  [85, 1, 4, 42, 2, 45, 15]]
#
# The best backwards path is [45, 94, 71, 96, 55, 25] with a sum of 386
#  25 is the picked number in the next row
#
# Current Path Sum= 2891 after row 43
#
#
#
#
# Original Cone of choices
# [[99, 55],
#  [29, 24, 96],
#  [50, 45, 71, 6],
#  [53, 64, 2, 94, 49],
#  [1, 4, 42, 2, 45, 15],
#  [49, 21, 22, 11, 41, 58, 99]]
#
# The best backwards path is [58, 45, 94, 71, 96, 55] with a sum of 419
#  55 is the picked number in the next row
#
# Current Path Sum= 2946 after row 44
#
#
#
#
# Original Cone of choices
# [[24, 96],
#  [45, 71, 6],
#  [64, 2, 94, 49],
#  [4, 42, 2, 45, 15],
#  [21, 22, 11, 41, 58, 99],
#  [87, 14, 26, 35, 17, 12, 98]]
#
# The best backwards path is [12, 58, 45, 94, 71, 96] with a sum of 376
#  96 is the picked number in the next row
#
# Current Path Sum= 3042 after row 45
#
#
#
#
# Original Cone of choices
# [[71, 6],
#  [2, 94, 49],
#  [42, 2, 45, 15],
#  [22, 11, 41, 58, 99],
#  [14, 26, 35, 17, 12, 98],
#  [57, 12, 36, 20, 39, 40, 55]]
#
# The best backwards path is [39, 17, 58, 45, 94, 71] with a sum of 324
#  71 is the picked number in the next row
#
# Current Path Sum= 3113 after row 46
#
#
#
#
# Original Cone of choices
# [[2, 94],
#  [42, 2, 45],
#  [22, 11, 41, 58],
#  [14, 26, 35, 17, 12],
#  [57, 12, 36, 20, 39, 40],
#  [53, 13, 96, 76, 83, 87, 90]]
#
# The best backwards path is [96, 36, 35, 41, 45, 94] with a sum of 347
#  94 is the picked number in the next row
#
# Current Path Sum= 3207 after row 47
#
#
#
#
# Original Cone of choices
# [[2, 45],
#  [11, 41, 58],
#  [26, 35, 17, 12],
#  [12, 36, 20, 39, 40],
#  [13, 96, 76, 83, 87, 90],
#  [39, 37, 62, 3, 24, 48, 54]]
#
# The best backwards path is [62, 96, 36, 35, 41, 45] with a sum of 315
#  45 is the picked number in the next row
#
# Current Path Sum= 3252 after row 48
#
#
#
#
# Original Cone of choices
# [[41, 58],
#  [35, 17, 12],
#  [36, 20, 39, 40],
#  [96, 76, 83, 87, 90],
#  [37, 62, 3, 24, 48, 54],
#  [77, 31, 58, 56, 93, 75, 68]]
#
# The best backwards path is [75, 54, 90, 40, 12, 58] with a sum of 329
#  58 is the picked number in the next row
#
# Current Path Sum= 3310 after row 49
#
#
#
#
# Original Cone of choices
# [[17, 12],
#  [20, 39, 40],
#  [76, 83, 87, 90],
#  [62, 3, 24, 48, 54],
#  [31, 58, 56, 93, 75, 68],
#  [50, 14, 53, 93, 64, 67, 37]]
#
# The best backwards path is [64, 93, 48, 87, 39, 17] with a sum of 348
#  17 is the picked number in the next row
#
# Current Path Sum= 3327 after row 50
#
#
#
#
# Original Cone of choices
# [[20, 39],
#  [76, 83, 87],
#  [62, 3, 24, 48],
#  [31, 58, 56, 93, 75],
#  [50, 14, 53, 93, 64, 67],
#  [43, 40, 12, 52, 29, 99, 7]]
#
# The best backwards path is [99, 64, 93, 48, 87, 39] with a sum of 430
#  39 is the picked number in the next row
#
# Current Path Sum= 3366 after row 51
#
#
#
#
# Original Cone of choices
# [[83, 87],
#  [3, 24, 48],
#  [58, 56, 93, 75],
#  [14, 53, 93, 64, 67],
#  [40, 12, 52, 29, 99, 7],
#  [4, 79, 96, 3, 31, 45, 71]]
#
# The best backwards path is [96, 52, 93, 93, 48, 87] with a sum of 469
#  87 is the picked number in the next row
#
# Current Path Sum= 3453 after row 52
#
#
#
#
# Original Cone of choices
# [[24, 48],
#  [56, 93, 75],
#  [53, 93, 64, 67],
#  [12, 52, 29, 99, 7],
#  [79, 96, 3, 31, 45, 71],
#  [92, 17, 71, 95, 52, 14, 77]]
#
# The best backwards path is [71, 96, 52, 93, 93, 48] with a sum of 453
#  48 is the picked number in the next row
#
# Current Path Sum= 3501 after row 53
#
#
#
#
# Original Cone of choices
# [[93, 75],
#  [93, 64, 67],
#  [52, 29, 99, 7],
#  [96, 3, 31, 45, 71],
#  [17, 71, 95, 52, 14, 77],
#  [93, 6, 4, 78, 47, 80, 6]]
#
# The best backwards path is [93, 17, 96, 52, 93, 93] with a sum of 444
#  93 is the picked number in the next row
#
# Current Path Sum= 3594 after row 54
#
#
#
#
# Original Cone of choices
# [[93, 64],
#  [52, 29, 99],
#  [96, 3, 31, 45],
#  [17, 71, 95, 52, 14],
#  [93, 6, 4, 78, 47, 80],
#  [69, 75, 78, 75, 60, 3, 32]]
#
# The best backwards path is [75, 93, 17, 96, 52, 93] with a sum of 426
#  93 is the picked number in the next row
#
# Current Path Sum= 3687 after row 55
#
#
#
#
# Original Cone of choices
# [[52, 29],
#  [96, 3, 31],
#  [17, 71, 95, 52],
#  [93, 6, 4, 78, 47],
#  [69, 75, 78, 75, 60, 3],
#  [17, 44, 93, 42, 21, 55, 14]]
#
# The best backwards path is [44, 75, 93, 17, 96, 52] with a sum of 377
#  52 is the picked number in the next row
#
# Current Path Sum= 3739 after row 56
#
#
#
#
# Original Cone of choices
# [[96, 3],
#  [17, 71, 95],
#  [93, 6, 4, 78],
#  [69, 75, 78, 75, 60],
#  [17, 44, 93, 42, 21, 55],
#  [17, 8, 87, 36, 3, 60, 31]]
#
# The best backwards path is [87, 93, 78, 4, 95, 3] with a sum of 360
#  3 is the picked number in the next row
#
# Current Path Sum= 3742 after row 57
#
#
#
#
# Original Cone of choices
# [[71, 95],
#  [6, 4, 78],
#  [75, 78, 75, 60],
#  [44, 93, 42, 21, 55],
#  [8, 87, 36, 3, 60, 31],
#  [64, 55, 78, 68, 88, 47, 31]]
#
# The best backwards path is [78, 87, 93, 78, 4, 95] with a sum of 435
#  95 is the picked number in the next row
#
# Current Path Sum= 3837 after row 58
#
#
#
#
# Original Cone of choices
# [[4, 78],
#  [78, 75, 60],
#  [93, 42, 21, 55],
#  [87, 36, 3, 60, 31],
#  [55, 78, 68, 88, 47, 31],
#  [21, 14, 67, 76, 30, 46, 14]]
#
# The best backwards path is [67, 78, 36, 42, 75, 78] with a sum of 376
#  78 is the picked number in the next row
#
# Current Path Sum= 3915 after row 59
#
#
#
#
# Original Cone of choices
# [[75, 60],
#  [42, 21, 55],
#  [36, 3, 60, 31],
#  [78, 68, 88, 47, 31],
#  [14, 67, 76, 30, 46, 14],
#  [57, 90, 33, 1, 60, 61, 14]]
#
# The best backwards path is [90, 67, 78, 36, 42, 75] with a sum of 388
#  75 is the picked number in the next row
#
# Current Path Sum= 3990 after row 60
#
#
#
#
# Original Cone of choices
# [[42, 21],
#  [36, 3, 60],
#  [78, 68, 88, 47],
#  [14, 67, 76, 30, 46],
#  [57, 90, 33, 1, 60, 61],
#  [80, 21, 12, 71, 83, 94, 60]]
#
# The best backwards path is [94, 60, 30, 88, 60, 21] with a sum of 353
#  21 is the picked number in the next row
#
# Current Path Sum= 4011 after row 61
#
#
#
#
# Original Cone of choices
# [[3, 60],
#  [68, 88, 47],
#  [67, 76, 30, 46],
#  [90, 33, 1, 60, 61],
#  [21, 12, 71, 83, 94, 60],
#  [26, 62, 73, 45, 12, 87, 73]]
#
# The best backwards path is [87, 94, 60, 30, 88, 60] with a sum of 419
#  60 is the picked number in the next row
#
# Current Path Sum= 4071 after row 62
#
#
#
#
# Original Cone of choices
# [[88, 47],
#  [76, 30, 46],
#  [33, 1, 60, 61],
#  [12, 71, 83, 94, 60],
#  [62, 73, 45, 12, 87, 73],
#  [26, 81, 51, 31, 45, 85, 87]]
#
# The best backwards path is [85, 87, 94, 60, 30, 88] with a sum of 444
#  88 is the picked number in the next row
#
# Current Path Sum= 4159 after row 63
#
#
#
#
# Original Cone of choices
# [[76, 30],
#  [33, 1, 60],
#  [12, 71, 83, 94],
#  [62, 73, 45, 12, 87],
#  [26, 81, 51, 31, 45, 85],
#  [78, 16, 93, 13, 37, 88, 54]]
#
# The best backwards path is [88, 85, 87, 94, 60, 30] with a sum of 444
#  30 is the picked number in the next row
#
# Current Path Sum= 4189 after row 64
#
#
#
#
# Original Cone of choices
# [[1, 60],
#  [71, 83, 94],
#  [73, 45, 12, 87],
#  [81, 51, 31, 45, 85],
#  [16, 93, 13, 37, 88, 54],
#  [52, 29, 12, 18, 56, 10, 8]]
#
# The best backwards path is [10, 88, 85, 87, 94, 60] with a sum of 424
#  60 is the picked number in the next row
#
# Current Path Sum= 4249 after row 65
#
#
#
#
# Original Cone of choices
# [[83, 94],
#  [45, 12, 87],
#  [51, 31, 45, 85],
#  [93, 13, 37, 88, 54],
#  [29, 12, 18, 56, 10, 8],
#  [68, 29, 17, 40, 26, 44, 25]]
#
# The best backwards path is [44, 10, 88, 85, 87, 94] with a sum of 408
#  94 is the picked number in the next row
#
# Current Path Sum= 4343 after row 66
#
#
#
#
# Original Cone of choices
# [[12, 87],
#  [31, 45, 85],
#  [13, 37, 88, 54],
#  [12, 18, 56, 10, 8],
#  [29, 17, 40, 26, 44, 25],
#  [19, 56, 36, 42, 30, 23, 69]]
#
# The best backwards path is [36, 40, 56, 88, 85, 87] with a sum of 392
#  87 is the picked number in the next row
#
# Current Path Sum= 4430 after row 67
#
#
#
#
# Original Cone of choices
# [[45, 85],
#  [37, 88, 54],
#  [18, 56, 10, 8],
#  [17, 40, 26, 44, 25],
#  [56, 36, 42, 30, 23, 69],
#  [18, 25, 50, 95, 90, 31, 77]]
#
# The best backwards path is [50, 42, 40, 56, 88, 85] with a sum of 361
#  85 is the picked number in the next row
#
# Current Path Sum= 4515 after row 68
#
#
#
#
# Original Cone of choices
# [[88, 54],
#  [56, 10, 8],
#  [40, 26, 44, 25],
#  [36, 42, 30, 23, 69],
#  [25, 50, 95, 90, 31, 77],
#  [5, 9, 97, 70, 1, 60, 46]]
#
# The best backwards path is [97, 95, 30, 44, 10, 54] with a sum of 330
#  54 is the picked number in the next row
#
# Current Path Sum= 4569 after row 69
#
#
#
#
# Original Cone of choices
# [[10, 8],
#  [26, 44, 25],
#  [42, 30, 23, 69],
#  [50, 95, 90, 31, 77],
#  [9, 97, 70, 1, 60, 46],
#  [55, 6, 35, 47, 82, 52, 33]]
#
# The best backwards path is [35, 97, 95, 30, 44, 8] with a sum of 309
#  8 is the picked number in the next row
#
# Current Path Sum= 4577 after row 70
#
#
#
#
# Original Cone of choices
# [[44, 25],
#  [30, 23, 69],
#  [95, 90, 31, 77],
#  [97, 70, 1, 60, 46],
#  [6, 35, 47, 82, 52, 33],
#  [62, 47, 41, 82, 87, 99, 22]]
#
# The best backwards path is [99, 52, 60, 77, 69, 25] with a sum of 382
#  25 is the picked number in the next row
#
# Current Path Sum= 4602 after row 71
#
#
#
#
# Original Cone of choices
# [[23, 69],
#  [90, 31, 77],
#  [70, 1, 60, 46],
#  [35, 47, 82, 52, 33],
#  [47, 41, 82, 87, 99, 22],
#  [79, 31, 16, 64, 59, 21, 89]]
#
# The best backwards path is [16, 82, 82, 60, 77, 69] with a sum of 386
#  69 is the picked number in the next row
#
# Current Path Sum= 4671 after row 72
#
#
#
#
# Original Cone of choices
# [[31, 77],
#  [1, 60, 46],
#  [47, 82, 52, 33],
#  [41, 82, 87, 99, 22],
#  [31, 16, 64, 59, 21, 89],
#  [26, 65, 96, 50, 68, 22, 7]]
#
# The best backwards path is [96, 64, 87, 82, 60, 77] with a sum of 466
#  77 is the picked number in the next row
#
# Current Path Sum= 4748 after row 73
#
#
#
#
# Original Cone of choices
# [[60, 46],
#  [82, 52, 33],
#  [82, 87, 99, 22],
#  [16, 64, 59, 21, 89],
#  [65, 96, 50, 68, 22, 7],
#  [11, 11, 65, 31, 66, 10, 98]]
#
# The best backwards path is [66, 68, 59, 87, 82, 60] with a sum of 422
#  60 is the picked number in the next row
#
# Current Path Sum= 4808 after row 74
#
#
#
#
# Original Cone of choices
# [[82, 52],
#  [82, 87, 99],
#  [16, 64, 59, 21],
#  [65, 96, 50, 68, 22],
#  [11, 11, 65, 31, 66, 10],
#  [78, 14, 41, 47, 89, 28, 81]]
#
# The best backwards path is [89, 66, 68, 59, 87, 82] with a sum of 451
#  82 is the picked number in the next row
#
# Current Path Sum= 4890 after row 75
#
#
#
#
# Original Cone of choices
# [[82, 87],
#  [16, 64, 59],
#  [65, 96, 50, 68],
#  [11, 11, 65, 31, 66],
#  [78, 14, 41, 47, 89, 28],
#  [99, 52, 13, 94, 6, 65, 97]]
#
# The best backwards path is [65, 89, 66, 68, 59, 87] with a sum of 434
#  87 is the picked number in the next row
#
# Current Path Sum= 4977 after row 76
#
#
#
#
# Original Cone of choices
# [[64, 59],
#  [96, 50, 68],
#  [11, 65, 31, 66],
#  [14, 41, 47, 89, 28],
#  [52, 13, 94, 6, 65, 97],
#  [63, 99, 85, 41, 56, 8, 28]]
#
# The best backwards path is [85, 94, 47, 65, 50, 59] with a sum of 400
#  59 is the picked number in the next row
#
# Current Path Sum= 5036 after row 77
#
#
#
#
# Original Cone of choices
# [[50, 68],
#  [65, 31, 66],
#  [41, 47, 89, 28],
#  [13, 94, 6, 65, 97],
#  [99, 85, 41, 56, 8, 28],
#  [46, 51, 55, 78, 22, 94, 34]]
#
# The best backwards path is [51, 85, 94, 47, 65, 50] with a sum of 392
#  50 is the picked number in the next row
#
# Current Path Sum= 5086 after row 78
#
#
#
#
# Original Cone of choices
# [[65, 31],
#  [41, 47, 89],
#  [13, 94, 6, 65],
#  [99, 85, 41, 56, 8],
#  [46, 51, 55, 78, 22, 94],
#  [9, 87, 94, 37, 40, 83, 64]]
#
# The best backwards path is [87, 51, 85, 94, 47, 65] with a sum of 429
#  65 is the picked number in the next row
#
# Current Path Sum= 5151 after row 79
#
#
#
#
# Original Cone of choices
# [[41, 47],
#  [13, 94, 6],
#  [99, 85, 41, 56],
#  [46, 51, 55, 78, 22],
#  [9, 87, 94, 37, 40, 83],
#  [65, 65, 37, 32, 65, 76, 99]]
#
# The best backwards path is [65, 87, 51, 85, 94, 47] with a sum of 429
#  47 is the picked number in the next row
#
# Current Path Sum= 5198 after row 80
#
#
#
#
# Original Cone of choices
# [[94, 6],
#  [85, 41, 56],
#  [51, 55, 78, 22],
#  [87, 94, 37, 40, 83],
#  [65, 37, 32, 65, 76, 99],
#  [7, 65, 27, 21, 23, 14, 15]]
#
# The best backwards path is [65, 65, 87, 51, 85, 94] with a sum of 447
#  94 is the picked number in the next row
#
# Current Path Sum= 5292 after row 81
#
#
#
#
# Original Cone of choices
# [[85, 41],
#  [51, 55, 78],
#  [87, 94, 37, 40],
#  [65, 37, 32, 65, 76],
#  [7, 65, 27, 21, 23, 14],
#  [12, 66, 50, 29, 99, 86, 72]]
#
# The best backwards path is [66, 65, 65, 87, 51, 85] with a sum of 419
#  85 is the picked number in the next row
#
# Current Path Sum= 5377 after row 82
#
#
#
#
# Original Cone of choices
# [[51, 55],
#  [87, 94, 37],
#  [65, 37, 32, 65],
#  [7, 65, 27, 21, 23],
#  [12, 66, 50, 29, 99, 86],
#  [30, 91, 91, 4, 22, 27, 73]]
#
# The best backwards path is [91, 66, 65, 65, 87, 51] with a sum of 425
#  51 is the picked number in the next row
#
# Current Path Sum= 5428 after row 83
#
#
#
#
# Original Cone of choices
# [[87, 94],
#  [65, 37, 32],
#  [7, 65, 27, 21],
#  [12, 66, 50, 29, 99],
#  [30, 91, 91, 4, 22, 27],
#  [66, 83, 25, 19, 4, 96, 41]]
#
# The best backwards path is [83, 91, 66, 65, 65, 87] with a sum of 457
#  87 is the picked number in the next row
#
# Current Path Sum= 5515 after row 84
#
#
#
#
# Original Cone of choices
# [[65, 37],
#  [7, 65, 27],
#  [12, 66, 50, 29],
#  [30, 91, 91, 4, 22],
#  [66, 83, 25, 19, 4, 96],
#  [55, 53, 72, 17, 46, 62, 25]]
#
# The best backwards path is [53, 83, 91, 66, 65, 65] with a sum of 423
#  65 is the picked number in the next row
#
# Current Path Sum= 5580 after row 85
#
#
#
#
# Original Cone of choices
# [[7, 65],
#  [12, 66, 50],
#  [30, 91, 91, 4],
#  [66, 83, 25, 19, 4],
#  [55, 53, 72, 17, 46, 62],
#  [54, 23, 24, 14, 10, 94, 21]]
#
# The best backwards path is [24, 72, 83, 91, 66, 65] with a sum of 401
#  65 is the picked number in the next row
#
# Current Path Sum= 5645 after row 86
#
#
#
#
# Original Cone of choices
# [[66, 50],
#  [91, 91, 4],
#  [83, 25, 19, 4],
#  [53, 72, 17, 46, 62],
#  [23, 24, 14, 10, 94, 21],
#  [61, 65, 98, 9, 16, 69, 4]]
#
# The best backwards path is [65, 24, 72, 83, 91, 66] with a sum of 401
#  66 is the picked number in the next row
#
# Current Path Sum= 5711 after row 87
#
#
#
#
# Original Cone of choices
# [[91, 91],
#  [83, 25, 19],
#  [53, 72, 17, 46],
#  [23, 24, 14, 10, 94],
#  [61, 65, 98, 9, 16, 69],
#  [88, 35, 54, 89, 96, 58, 66]]
#
# The best backwards path is [88, 61, 23, 53, 83, 91] with a sum of 399
#  91 is the picked number in the next row
#
# Current Path Sum= 5802 after row 88
#
#
#
#
# Original Cone of choices
# [[83, 25],
#  [53, 72, 17],
#  [23, 24, 14, 10],
#  [61, 65, 98, 9, 16],
#  [88, 35, 54, 89, 96, 58],
#  [11, 12, 26, 53, 5, 26, 26]]
#
# The best backwards path is [5, 89, 98, 24, 72, 83] with a sum of 371
#  83 is the picked number in the next row
#
# Current Path Sum= 5885 after row 89
#
#
#
#
# Original Cone of choices
# [[53, 72],
#  [23, 24, 14],
#  [61, 65, 98, 9],
#  [88, 35, 54, 89, 96],
#  [11, 12, 26, 53, 5, 26],
#  [3, 97, 91, 68, 82, 44, 19]]
#
# The best backwards path is [82, 53, 89, 98, 24, 53] with a sum of 399
#  53 is the picked number in the next row
#
# Current Path Sum= 5938 after row 90
#
#
#
#
# Original Cone of choices
# [[23, 24],
#  [61, 65, 98],
#  [88, 35, 54, 89],
#  [11, 12, 26, 53, 5],
#  [3, 97, 91, 68, 82, 44],
#  [64, 58, 74, 25, 96, 57, 14]]
#
# The best backwards path is [57, 82, 53, 89, 98, 24] with a sum of 403
#  24 is the picked number in the next row
#
# Current Path Sum= 5962 after row 91
#
#
#
#
# Original Cone of choices
# [[65, 98],
#  [35, 54, 89],
#  [12, 26, 53, 5],
#  [97, 91, 68, 82, 44],
#  [58, 74, 25, 96, 57, 14],
#  [58, 4, 65, 30, 58, 99, 12]]
#
# The best backwards path is [99, 57, 82, 53, 89, 98] with a sum of 478
#  98 is the picked number in the next row
#
# Current Path Sum= 6060 after row 92
#
#
#
#
# Original Cone of choices
# [[54, 89],
#  [26, 53, 5],
#  [91, 68, 82, 44],
#  [74, 25, 96, 57, 14],
#  [4, 65, 30, 58, 99, 12],
#  [45, 99, 18, 38, 98, 24, 21]]
#
# The best backwards path is [98, 99, 57, 82, 53, 54] with a sum of 443
#  54 is the picked number in the next row
#
# Current Path Sum= 6114 after row 93
#
#
#
#
# Original Cone of choices
# [[26, 53],
#  [91, 68, 82],
#  [74, 25, 96, 57],
#  [4, 65, 30, 58, 99],
#  [45, 99, 18, 38, 98, 24],
#  [3, 93, 70, 81, 47, 95, 77]]
#
# The best backwards path is [95, 98, 99, 57, 82, 53] with a sum of 484
#  53 is the picked number in the next row
#
# Current Path Sum= 6167 after row 94
#
#
#
#
# Adding in 484 for the final 6 rows, and the grand total of 6651
# [[59], [73], [52], [53], [87], [66], [38], [76], [62], [79], [81], [32], [86], [82], [75], [77], [69], [13], [35], [65], [90], [96], [88], [54], [71], [77], [5], [71], [94], [8], [89], [69], [20], [11], [98], [96], [69], [99], [53], [88], [93], [70], [97], [25], [55], [96], [71], [94], [45], [58], [17], [39], [87], [48], [93], [93], [52], [3], [95], [78], [75], [21], [60], [88], [30], [60], [94], [87], [85], [54], [8], [25], [69], [77], [60], [82], [87], [59], [50], [65], [47], [94], [85], [51], [87], [65], [65], [66], [91], [83], [53], [24], [98], [54], [53], [68, 82], [25, 96, 57], [65, 30, 58, 99], [99, 18, 38, 98, 24], [93, 70, 81, 47, 95, 77]]
