# %%
from pprint import pprint
import copy

# %%
def fileReader():
    tempList=[]   
    with open(r"/Users/aaronSmith/Documents/p067_triangle.txt","r") as f:
        lines = list(map(lambda l: l.strip(), f.readlines()))
        for i in range(len(lines)):
            for j in lines[i].split(","):

                tempList.append(j.split(" "))
                
    triangleList=[]
    for l in tempList:
        l=list(map(int,l))
        triangleList.append(l)
    
    return triangleList

# %%
def plinko(choices):
    try:
        listOfLists=[]
        while True:
            tempList=[]
            shrinkingChoices=copy.deepcopy(choices)

            if len(choices[5])>=len(choices[6]):
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(choices[5].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(4,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue
            
            if len(choices[4])>=len(choices[5]):
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(choices[4].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(3,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue
            
            if len(choices[3])>=len(choices[4]):
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(choices[3].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(2,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[2])>=len(choices[3]):
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(choices[2].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(1,-1,-1):
                    tempList.append(shrinkingChoices[i].pop(-1))
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[1])>=len(choices[2]):
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(choices[1].pop())
                shrinkingChoices=copy.deepcopy(choices)
                tempList.append(shrinkingChoices[0].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[0])>=len(choices[1]):
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(shrinkingChoices[1].pop())
                tempList.append(choices[0].pop())
                shrinkingChoices=copy.deepcopy(choices)
                listOfLists.append(tempList)
                tempList=[]
                continue
                
            else:
                tempList.append(choices[6].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(5,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
 
    except IndexError:
#         listOfLists.pop()
        return listOfLists

# %%
triangleList=fileReader()
iY=0
finalPathSum=triangleList[0][0]
print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")


for i in range(len(triangleList)-7):
    testList=copy.deepcopy(triangleList[iY+1:iY+8])
    choices=copy.deepcopy(testList)

    allLists=[]
    listOfLists=plinko(choices)
    allLists.extend(listOfLists)

    reverseChoices=copy.deepcopy(testList)
    for i in range(len(reverseChoices)):
        reverseChoices[i].reverse()

    listOfLists=plinko(reverseChoices)
    allLists.extend(listOfLists)

    sumList=[]
    for l in allLists:
        sumList.append(sum(l)) 
    pickedNumber=allLists[sumList.index(max(sumList))][-1]
    finalPathSum+=pickedNumber
    print("\nOriginal Cone of choices")
    pprint(testList)
    print("\nThe best backwards path is", allLists[sumList.index(max(sumList))], "with a sum of", max(sumList),
          "\n",pickedNumber,"is the picked number in the next row\n")
    iY+=1
    if testList[0].index(pickedNumber)==0:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop()
    else:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop(0)
    print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")
finalPathSum+=max(sumList)
print("\nAdding in", max(sumList), "for the final 7 rows, and the grand total of", finalPathSum)
print(triangleList)
# finalAnswer supposed to be 7273
# Out:
# Current Path Sum= 59 after row 0
#
#
#
#
# Original Cone of choices
# [[73, 41],
#  [52, 40, 9],
#  [26, 53, 6, 34],
#  [10, 51, 87, 86, 81],
#  [61, 95, 66, 57, 25, 68],
#  [90, 81, 80, 38, 92, 67, 73],
#  [30, 28, 51, 76, 81, 18, 75, 44]]
#
# The best backwards path is [28, 81, 95, 51, 53, 52, 73] with a sum of 433
#  73 is the picked number in the next row
#
# Current Path Sum= 132 after row 1
#
#
#
#
# Original Cone of choices
# [[52, 40],
#  [26, 53, 6],
#  [10, 51, 87, 86],
#  [61, 95, 66, 57, 25],
#  [90, 81, 80, 38, 92, 67],
#  [30, 28, 51, 76, 81, 18, 75],
#  [84, 14, 95, 87, 62, 81, 17, 78]]
#
# The best backwards path is [81, 81, 92, 57, 87, 53, 52] with a sum of 503
#  52 is the picked number in the next row
#
# Current Path Sum= 184 after row 2
#
#
#
#
# Original Cone of choices
# [[26, 53],
#  [10, 51, 87],
#  [61, 95, 66, 57],
#  [90, 81, 80, 38, 92],
#  [30, 28, 51, 76, 81, 18],
#  [84, 14, 95, 87, 62, 81, 17],
#  [21, 46, 71, 58, 2, 79, 62, 39]]
#
# The best backwards path is [62, 81, 81, 92, 57, 87, 53] with a sum of 513
#  53 is the picked number in the next row
#
# Current Path Sum= 237 after row 3
#
#
#
#
# Original Cone of choices
# [[51, 87],
#  [95, 66, 57],
#  [81, 80, 38, 92],
#  [28, 51, 76, 81, 18],
#  [14, 95, 87, 62, 81, 17],
#  [46, 71, 58, 2, 79, 62, 39],
#  [34, 35, 53, 78, 31, 81, 18, 90]]
#
# The best backwards path is [81, 79, 62, 76, 80, 95, 51] with a sum of 524
#  51 is the picked number in the next row
#
# Current Path Sum= 288 after row 4
#
#
#
#
# Original Cone of choices
# [[95, 66],
#  [81, 80, 38],
#  [28, 51, 76, 81],
#  [14, 95, 87, 62, 81],
#  [46, 71, 58, 2, 79, 62],
#  [34, 35, 53, 78, 31, 81, 18],
#  [53, 4, 21, 84, 93, 32, 13, 97]]
#
# The best backwards path is [32, 81, 79, 62, 76, 80, 95] with a sum of 505
#  95 is the picked number in the next row
#
# Current Path Sum= 383 after row 5
#
#
#
#
# Original Cone of choices
# [[81, 80],
#  [28, 51, 76],
#  [14, 95, 87, 62],
#  [46, 71, 58, 2, 79],
#  [34, 35, 53, 78, 31, 81],
#  [53, 4, 21, 84, 93, 32, 13],
#  [3, 81, 79, 5, 18, 78, 86, 13]]
#
# The best backwards path is [78, 93, 78, 58, 95, 51, 81] with a sum of 534
#  81 is the picked number in the next row
#
# Current Path Sum= 464 after row 6
#
#
#
#
# Original Cone of choices
# [[28, 51],
#  [14, 95, 87],
#  [46, 71, 58, 2],
#  [34, 35, 53, 78, 31],
#  [53, 4, 21, 84, 93, 32],
#  [3, 81, 79, 5, 18, 78, 86],
#  [87, 96, 28, 3, 38, 42, 17, 82]]
#
# The best backwards path is [42, 78, 93, 78, 58, 95, 28] with a sum of 472
#  28 is the picked number in the next row
#
# Current Path Sum= 492 after row 7
#
#
#
#
# Original Cone of choices
# [[14, 95],
#  [46, 71, 58],
#  [34, 35, 53, 78],
#  [53, 4, 21, 84, 93],
#  [3, 81, 79, 5, 18, 78],
#  [87, 96, 28, 3, 38, 42, 17],
#  [17, 51, 17, 7, 93, 9, 7, 75]]
#
# The best backwards path is [75, 17, 78, 93, 78, 58, 95] with a sum of 494
#  95 is the picked number in the next row
#
# Current Path Sum= 587 after row 8
#
#
#
#
# Original Cone of choices
# [[71, 58],
#  [35, 53, 78],
#  [4, 21, 84, 93],
#  [81, 79, 5, 18, 78],
#  [96, 28, 3, 38, 42, 17],
#  [51, 17, 7, 93, 9, 7, 75],
#  [59, 60, 88, 99, 94, 65, 55, 77]]
#
# The best backwards path is [77, 75, 17, 78, 93, 78, 58] with a sum of 476
#  58 is the picked number in the next row
#
# Current Path Sum= 645 after row 9
#
#
#
#
# Original Cone of choices
# [[53, 78],
#  [21, 84, 93],
#  [79, 5, 18, 78],
#  [28, 3, 38, 42, 17],
#  [17, 7, 93, 9, 7, 75],
#  [60, 88, 99, 94, 65, 55, 77],
#  [4, 87, 16, 9, 42, 75, 69, 23]]
#
# The best backwards path is [69, 77, 75, 17, 78, 93, 78] with a sum of 487
#  78 is the picked number in the next row
#
# Current Path Sum= 723 after row 10
#
#
#
#
# Original Cone of choices
# [[84, 93],
#  [5, 18, 78],
#  [3, 38, 42, 17],
#  [7, 93, 9, 7, 75],
#  [88, 99, 94, 65, 55, 77],
#  [87, 16, 9, 42, 75, 69, 23],
#  [21, 36, 32, 84, 98, 60, 13, 12]]
#
# The best backwards path is [13, 69, 77, 75, 17, 78, 93] with a sum of 422
#  93 is the picked number in the next row
#
# Current Path Sum= 816 after row 11
#
#
#
#
# Original Cone of choices
# [[18, 78],
#  [38, 42, 17],
#  [93, 9, 7, 75],
#  [99, 94, 65, 55, 77],
#  [16, 9, 42, 75, 69, 23],
#  [36, 32, 84, 98, 60, 13, 12],
#  [27, 38, 48, 28, 22, 34, 35, 62]]
#
# The best backwards path is [48, 84, 42, 94, 9, 42, 78] with a sum of 397
#  78 is the picked number in the next row
#
# Current Path Sum= 894 after row 12
#
#
#
#
# Original Cone of choices
# [[42, 17],
#  [9, 7, 75],
#  [94, 65, 55, 77],
#  [9, 42, 75, 69, 23],
#  [32, 84, 98, 60, 13, 12],
#  [38, 48, 28, 22, 34, 35, 62],
#  [34, 34, 34, 81, 62, 40, 65, 54]]
#
# The best backwards path is [34, 28, 98, 75, 55, 75, 17] with a sum of 382
#  17 is the picked number in the next row
#
# Current Path Sum= 911 after row 13
#
#
#
#
# Original Cone of choices
# [[7, 75],
#  [65, 55, 77],
#  [42, 75, 69, 23],
#  [84, 98, 60, 13, 12],
#  [48, 28, 22, 34, 35, 62],
#  [34, 34, 81, 62, 40, 65, 54],
#  [53, 36, 14, 70, 26, 2, 90, 45]]
#
# The best backwards path is [14, 81, 28, 98, 75, 55, 75] with a sum of 426
#  75 is the picked number in the next row
#
# Current Path Sum= 986 after row 14
#
#
#
#
# Original Cone of choices
# [[55, 77],
#  [75, 69, 23],
#  [98, 60, 13, 12],
#  [28, 22, 34, 35, 62],
#  [34, 81, 62, 40, 65, 54],
#  [36, 14, 70, 26, 2, 90, 45],
#  [37, 42, 14, 58, 84, 93, 96, 17]]
#
# The best backwards path is [96, 90, 65, 35, 13, 69, 77] with a sum of 445
#  77 is the picked number in the next row
#
# Current Path Sum= 1063 after row 15
#
#
#
#
# Original Cone of choices
# [[69, 23],
#  [60, 13, 12],
#  [22, 34, 35, 62],
#  [81, 62, 40, 65, 54],
#  [14, 70, 26, 2, 90, 45],
#  [42, 14, 58, 84, 93, 96, 17],
#  [73, 79, 15, 39, 95, 88, 87, 43]]
#
# The best backwards path is [88, 96, 90, 65, 35, 13, 69] with a sum of 456
#  69 is the picked number in the next row
#
# Current Path Sum= 1132 after row 16
#
#
#
#
# Original Cone of choices
# [[60, 13],
#  [22, 34, 35],
#  [81, 62, 40, 65],
#  [14, 70, 26, 2, 90],
#  [42, 14, 58, 84, 93, 96],
#  [73, 79, 15, 39, 95, 88, 87],
#  [37, 50, 2, 45, 9, 54, 52, 27]]
#
# The best backwards path is [52, 88, 96, 90, 65, 35, 13] with a sum of 439
#  13 is the picked number in the next row
#
# Current Path Sum= 1145 after row 17
#
#
#
#
# Original Cone of choices
# [[34, 35],
#  [62, 40, 65],
#  [70, 26, 2, 90],
#  [14, 58, 84, 93, 96],
#  [79, 15, 39, 95, 88, 87],
#  [50, 2, 45, 9, 54, 52, 27],
#  [78, 19, 35, 62, 71, 19, 23, 65]]
#
# The best backwards path is [65, 27, 87, 96, 90, 65, 35] with a sum of 465
#  35 is the picked number in the next row
#
# Current Path Sum= 1180 after row 18
#
#
#
#
# Original Cone of choices
# [[40, 65],
#  [26, 2, 90],
#  [58, 84, 93, 96],
#  [15, 39, 95, 88, 87],
#  [2, 45, 9, 54, 52, 27],
#  [19, 35, 62, 71, 19, 23, 65],
#  [54, 46, 57, 7, 77, 98, 52, 80]]
#
# The best backwards path is [80, 65, 27, 87, 96, 90, 65] with a sum of 510
#  65 is the picked number in the next row
#
# Current Path Sum= 1245 after row 19
#
#
#
#
# Original Cone of choices
# [[2, 90],
#  [84, 93, 96],
#  [39, 95, 88, 87],
#  [45, 9, 54, 52, 27],
#  [35, 62, 71, 19, 23, 65],
#  [46, 57, 7, 77, 98, 52, 80],
#  [51, 31, 24, 68, 5, 57, 7, 54]]
#
# The best backwards path is [54, 80, 65, 27, 87, 96, 90] with a sum of 499
#  90 is the picked number in the next row
#
# Current Path Sum= 1335 after row 20
#
#
#
#
# Original Cone of choices
# [[93, 96],
#  [95, 88, 87],
#  [9, 54, 52, 27],
#  [62, 71, 19, 23, 65],
#  [57, 7, 77, 98, 52, 80],
#  [31, 24, 68, 5, 57, 7, 54],
#  [9, 24, 30, 71, 8, 88, 70, 72]]
#
# The best backwards path is [88, 57, 98, 19, 54, 95, 93] with a sum of 504
#  93 is the picked number in the next row
#
# Current Path Sum= 1428 after row 21
#
#
#
#
# Original Cone of choices
# [[95, 88],
#  [9, 54, 52],
#  [62, 71, 19, 23],
#  [57, 7, 77, 98, 52],
#  [31, 24, 68, 5, 57, 7],
#  [9, 24, 30, 71, 8, 88, 70],
#  [61, 30, 90, 29, 94, 26, 41, 89]]
#
# The best backwards path is [90, 30, 68, 77, 71, 54, 88] with a sum of 478
#  88 is the picked number in the next row
#
# Current Path Sum= 1516 after row 22
#
#
#
#
# Original Cone of choices
# [[54, 52],
#  [71, 19, 23],
#  [7, 77, 98, 52],
#  [24, 68, 5, 57, 7],
#  [24, 30, 71, 8, 88, 70],
#  [30, 90, 29, 94, 26, 41, 89],
#  [62, 13, 17, 8, 19, 54, 89, 29]]
#
# The best backwards path is [89, 41, 88, 57, 98, 23, 52] with a sum of 448
#  52 is the picked number in the next row
#
# Current Path Sum= 1568 after row 23
#
#
#
#
# Original Cone of choices
# [[19, 23],
#  [77, 98, 52],
#  [68, 5, 57, 7],
#  [30, 71, 8, 88, 70],
#  [90, 29, 94, 26, 41, 89],
#  [13, 17, 8, 19, 54, 89, 29],
#  [30, 43, 89, 30, 39, 15, 2, 44]]
#
# The best backwards path is [15, 89, 41, 88, 57, 98, 19] with a sum of 407
#  19 is the picked number in the next row
#
# Current Path Sum= 1587 after row 24
#
#
#
#
# Original Cone of choices
# [[77, 98],
#  [68, 5, 57],
#  [30, 71, 8, 88],
#  [90, 29, 94, 26, 41],
#  [13, 17, 8, 19, 54, 89],
#  [30, 43, 89, 30, 39, 15, 2],
#  [26, 82, 69, 54, 4, 13, 7, 85]]
#
# The best backwards path is [85, 2, 89, 41, 88, 57, 98] with a sum of 460
#  98 is the picked number in the next row
#
# Current Path Sum= 1685 after row 25
#
#
#
#
# Original Cone of choices
# [[5, 57],
#  [71, 8, 88],
#  [29, 94, 26, 41],
#  [17, 8, 19, 54, 89],
#  [43, 89, 30, 39, 15, 2],
#  [82, 69, 54, 4, 13, 7, 85],
#  [36, 20, 73, 42, 21, 23, 22, 51]]
#
# The best backwards path is [51, 85, 2, 89, 41, 88, 57] with a sum of 413
#  57 is the picked number in the next row
#
# Current Path Sum= 1742 after row 26
#
#
#
#
# Original Cone of choices
# [[8, 88],
#  [94, 26, 41],
#  [8, 19, 54, 89],
#  [89, 30, 39, 15, 2],
#  [69, 54, 4, 13, 7, 85],
#  [20, 73, 42, 21, 23, 22, 51],
#  [11, 46, 52, 90, 27, 8, 65, 78]]
#
# The best backwards path is [78, 51, 85, 2, 89, 41, 88] with a sum of 434
#  88 is the picked number in the next row
#
# Current Path Sum= 1830 after row 27
#
#
#
#
# Original Cone of choices
# [[26, 41],
#  [19, 54, 89],
#  [30, 39, 15, 2],
#  [54, 4, 13, 7, 85],
#  [73, 42, 21, 23, 22, 51],
#  [46, 52, 90, 27, 8, 65, 78],
#  [39, 15, 39, 84, 89, 69, 84, 46]]
#
# The best backwards path is [84, 78, 51, 85, 2, 89, 41] with a sum of 430
#  41 is the picked number in the next row
#
# Current Path Sum= 1871 after row 28
#
#
#
#
# Original Cone of choices
# [[54, 89],
#  [39, 15, 2],
#  [4, 13, 7, 85],
#  [42, 21, 23, 22, 51],
#  [52, 90, 27, 8, 65, 78],
#  [15, 39, 84, 89, 69, 84, 46],
#  [90, 90, 45, 91, 20, 50, 56, 10]]
#
# The best backwards path is [56, 84, 78, 51, 85, 2, 89] with a sum of 445
#  89 is the picked number in the next row
#
# Current Path Sum= 1960 after row 29
#
#
#
#
# Original Cone of choices
# [[15, 2],
#  [13, 7, 85],
#  [21, 23, 22, 51],
#  [90, 27, 8, 65, 78],
#  [39, 84, 89, 69, 84, 46],
#  [90, 45, 91, 20, 50, 56, 10],
#  [75, 84, 18, 31, 71, 50, 84, 63]]
#
# The best backwards path is [84, 56, 84, 78, 51, 85, 2] with a sum of 440
#  2 is the picked number in the next row
#
# Current Path Sum= 1962 after row 30
#
#
#
#
# Original Cone of choices
# [[7, 85],
#  [23, 22, 51],
#  [27, 8, 65, 78],
#  [84, 89, 69, 84, 46],
#  [45, 91, 20, 50, 56, 10],
#  [84, 18, 31, 71, 50, 84, 63],
#  [47, 52, 7, 71, 60, 42, 72, 94]]
#
# The best backwards path is [72, 84, 56, 84, 78, 51, 85] with a sum of 510
#  85 is the picked number in the next row
#
# Current Path Sum= 2047 after row 31
#
#
#
#
# Original Cone of choices
# [[22, 51],
#  [8, 65, 78],
#  [89, 69, 84, 46],
#  [91, 20, 50, 56, 10],
#  [18, 31, 71, 50, 84, 63],
#  [52, 7, 71, 60, 42, 72, 94],
#  [69, 95, 72, 93, 22, 34, 98, 20]]
#
# The best backwards path is [98, 72, 84, 56, 84, 78, 51] with a sum of 523
#  51 is the picked number in the next row
#
# Current Path Sum= 2098 after row 32
#
#
#
#
# Original Cone of choices
# [[65, 78],
#  [69, 84, 46],
#  [20, 50, 56, 10],
#  [31, 71, 50, 84, 63],
#  [7, 71, 60, 42, 72, 94],
#  [95, 72, 93, 22, 34, 98, 20],
#  [15, 65, 94, 80, 44, 61, 84, 12]]
#
# The best backwards path is [84, 98, 72, 84, 56, 84, 78] with a sum of 556
#  78 is the picked number in the next row
#
# Current Path Sum= 2176 after row 33
#
#
#
#
# Original Cone of choices
# [[84, 46],
#  [50, 56, 10],
#  [71, 50, 84, 63],
#  [71, 60, 42, 72, 94],
#  [72, 93, 22, 34, 98, 20],
#  [65, 94, 80, 44, 61, 84, 12],
#  [94, 53, 18, 43, 77, 40, 78, 32]]
#
# The best backwards path is [78, 84, 98, 72, 84, 56, 84] with a sum of 556
#  84 is the picked number in the next row
#
# Current Path Sum= 2260 after row 34
#
#
#
#
# Original Cone of choices
# [[50, 56],
#  [71, 50, 84],
#  [71, 60, 42, 72],
#  [72, 93, 22, 34, 98],
#  [65, 94, 80, 44, 61, 84],
#  [94, 53, 18, 43, 77, 40, 78],
#  [64, 6, 69, 84, 14, 22, 56, 43]]
#
# The best backwards path is [56, 78, 84, 98, 72, 84, 56] with a sum of 528
#  56 is the picked number in the next row
#
# Current Path Sum= 2316 after row 35
#
#
#
#
# Original Cone of choices
# [[50, 84],
#  [60, 42, 72],
#  [93, 22, 34, 98],
#  [94, 80, 44, 61, 84],
#  [53, 18, 43, 77, 40, 78],
#  [6, 69, 84, 14, 22, 56, 43],
#  [96, 12, 73, 8, 20, 36, 47, 81]]
#
# The best backwards path is [81, 43, 78, 84, 98, 72, 84] with a sum of 540
#  84 is the picked number in the next row
#
# Current Path Sum= 2400 after row 36
#
#
#
#
# Original Cone of choices
# [[42, 72],
#  [22, 34, 98],
#  [80, 44, 61, 84],
#  [18, 43, 77, 40, 78],
#  [69, 84, 14, 22, 56, 43],
#  [12, 73, 8, 20, 36, 47, 81],
#  [22, 99, 92, 79, 87, 51, 21, 77]]
#
# The best backwards path is [77, 81, 43, 78, 84, 98, 72] with a sum of 533
#  72 is the picked number in the next row
#
# Current Path Sum= 2472 after row 37
#
#
#
#
# Original Cone of choices
# [[34, 98],
#  [44, 61, 84],
#  [43, 77, 40, 78],
#  [84, 14, 22, 56, 43],
#  [73, 8, 20, 36, 47, 81],
#  [99, 92, 79, 87, 51, 21, 77],
#  [58, 89, 50, 66, 19, 82, 75, 12]]
#
# The best backwards path is [75, 77, 81, 43, 78, 84, 98] with a sum of 536
#  98 is the picked number in the next row
#
# Current Path Sum= 2570 after row 38
#
#
#
#
# Original Cone of choices
# [[61, 84],
#  [77, 40, 78],
#  [14, 22, 56, 43],
#  [8, 20, 36, 47, 81],
#  [92, 79, 87, 51, 21, 77],
#  [89, 50, 66, 19, 82, 75, 12],
#  [45, 47, 59, 88, 43, 20, 66, 15]]
#
# The best backwards path is [66, 75, 77, 81, 43, 78, 84] with a sum of 504
#  84 is the picked number in the next row
#
# Current Path Sum= 2654 after row 39
#
#
#
#
# Original Cone of choices
# [[40, 78],
#  [22, 56, 43],
#  [20, 36, 47, 81],
#  [79, 87, 51, 21, 77],
#  [50, 66, 19, 82, 75, 12],
#  [47, 59, 88, 43, 20, 66, 15],
#  [56, 80, 67, 18, 46, 66, 63, 1]]
#
# The best backwards path is [63, 66, 75, 77, 81, 43, 78] with a sum of 483
#  78 is the picked number in the next row
#
# Current Path Sum= 2732 after row 40
#
#
#
#
# Original Cone of choices
# [[56, 43],
#  [36, 47, 81],
#  [87, 51, 21, 77],
#  [66, 19, 82, 75, 12],
#  [59, 88, 43, 20, 66, 15],
#  [80, 67, 18, 46, 66, 63, 1],
#  [82, 96, 25, 24, 96, 18, 2, 5]]
#
# The best backwards path is [96, 67, 88, 66, 87, 36, 56] with a sum of 496
#  56 is the picked number in the next row
#
# Current Path Sum= 2788 after row 41
#
#
#
#
# Original Cone of choices
# [[36, 47],
#  [87, 51, 21],
#  [66, 19, 82, 75],
#  [59, 88, 43, 20, 66],
#  [80, 67, 18, 46, 66, 63],
#  [82, 96, 25, 24, 96, 18, 2],
#  [25, 74, 81, 88, 98, 21, 67, 84]]
#
# The best backwards path is [74, 96, 67, 88, 66, 87, 36] with a sum of 514
#  36 is the picked number in the next row
#
# Current Path Sum= 2824 after row 42
#
#
#
#
# Original Cone of choices
# [[87, 51],
#  [66, 19, 82],
#  [59, 88, 43, 20],
#  [80, 67, 18, 46, 66],
#  [82, 96, 25, 24, 96, 18],
#  [25, 74, 81, 88, 98, 21, 67],
#  [17, 24, 52, 36, 23, 15, 72, 16]]
#
# The best backwards path is [24, 74, 96, 67, 88, 66, 87] with a sum of 502
#  87 is the picked number in the next row
#
# Current Path Sum= 2911 after row 43
#
#
#
#
# Original Cone of choices
# [[66, 19],
#  [59, 88, 43],
#  [80, 67, 18, 46],
#  [82, 96, 25, 24, 96],
#  [25, 74, 81, 88, 98, 21],
#  [17, 24, 52, 36, 23, 15, 72],
#  [78, 18, 98, 27, 28, 84, 80, 67]]
#
# The best backwards path is [98, 52, 81, 96, 67, 88, 19] with a sum of 501
#  19 is the picked number in the next row
#
# Current Path Sum= 2930 after row 44
#
#
#
#
# Original Cone of choices
# [[88, 43],
#  [67, 18, 46],
#  [96, 25, 24, 96],
#  [74, 81, 88, 98, 21],
#  [24, 52, 36, 23, 15, 72],
#  [18, 98, 27, 28, 84, 80, 67],
#  [31, 38, 26, 8, 15, 56, 88, 86]]
#
# The best backwards path is [38, 98, 52, 81, 96, 67, 88] with a sum of 520
#  88 is the picked number in the next row
#
# Current Path Sum= 3018 after row 45
#
#
#
#
# Original Cone of choices
# [[67, 18],
#  [96, 25, 24],
#  [74, 81, 88, 98],
#  [24, 52, 36, 23, 15],
#  [18, 98, 27, 28, 84, 80],
#  [31, 38, 26, 8, 15, 56, 88],
#  [22, 78, 91, 73, 51, 69, 9, 79]]
#
# The best backwards path is [78, 38, 98, 52, 81, 96, 67] with a sum of 510
#  67 is the picked number in the next row
#
# Current Path Sum= 3085 after row 46
#
#
#
#
# Original Cone of choices
# [[96, 25],
#  [74, 81, 88],
#  [24, 52, 36, 23],
#  [18, 98, 27, 28, 84],
#  [31, 38, 26, 8, 15, 56],
#  [22, 78, 91, 73, 51, 69, 9],
#  [82, 71, 78, 33, 67, 9, 16, 96]]
#
# The best backwards path is [71, 78, 38, 98, 52, 81, 96] with a sum of 514
#  96 is the picked number in the next row
#
# Current Path Sum= 3181 after row 47
#
#
#
#
# Original Cone of choices
# [[74, 81],
#  [24, 52, 36],
#  [18, 98, 27, 28],
#  [31, 38, 26, 8, 15],
#  [22, 78, 91, 73, 51, 69],
#  [82, 71, 78, 33, 67, 9, 16],
#  [36, 69, 53, 90, 75, 25, 82, 39]]
#
# The best backwards path is [53, 78, 91, 38, 98, 52, 81] with a sum of 491
#  81 is the picked number in the next row
#
# Current Path Sum= 3262 after row 48
#
#
#
#
# Original Cone of choices
# [[52, 36],
#  [98, 27, 28],
#  [38, 26, 8, 15],
#  [78, 91, 73, 51, 69],
#  [71, 78, 33, 67, 9, 16],
#  [69, 53, 90, 75, 25, 82, 39],
#  [10, 84, 42, 70, 48, 20, 10, 72]]
#
# The best backwards path is [84, 53, 78, 91, 38, 98, 52] with a sum of 494
#  52 is the picked number in the next row
#
# Current Path Sum= 3314 after row 49
#
#
#
#
# Original Cone of choices
# [[98, 27],
#  [38, 26, 8],
#  [78, 91, 73, 51],
#  [71, 78, 33, 67, 9],
#  [69, 53, 90, 75, 25, 82],
#  [10, 84, 42, 70, 48, 20, 10],
#  [60, 25, 1, 7, 61, 71, 37, 92]]
#
# The best backwards path is [25, 84, 53, 78, 91, 38, 98] with a sum of 467
#  98 is the picked number in the next row
#
# Current Path Sum= 3412 after row 50
#
#
#
#
# Original Cone of choices
# [[38, 26],
#  [78, 91, 73],
#  [71, 78, 33, 67],
#  [69, 53, 90, 75, 25],
#  [10, 84, 42, 70, 48, 20],
#  [60, 25, 1, 7, 61, 71, 37],
#  [81, 6, 14, 18, 17, 5, 31, 50]]
#
# The best backwards path is [5, 61, 70, 90, 78, 91, 38] with a sum of 433
#  38 is the picked number in the next row
#
# Current Path Sum= 3450 after row 51
#
#
#
#
# Original Cone of choices
# [[78, 91],
#  [71, 78, 33],
#  [69, 53, 90, 75],
#  [10, 84, 42, 70, 48],
#  [60, 25, 1, 7, 61, 71],
#  [81, 6, 14, 18, 17, 5, 31],
#  [77, 13, 24, 55, 11, 65, 26, 91]]
#
# The best backwards path is [65, 17, 61, 70, 90, 78, 78] with a sum of 459
#  78 is the picked number in the next row
#
# Current Path Sum= 3528 after row 52
#
#
#
#
# Original Cone of choices
# [[71, 78],
#  [69, 53, 90],
#  [10, 84, 42, 70],
#  [60, 25, 1, 7, 61],
#  [81, 6, 14, 18, 17, 5],
#  [77, 13, 24, 55, 11, 65, 26],
#  [80, 6, 23, 84, 75, 23, 87, 72]]
#
# The best backwards path is [87, 65, 17, 61, 70, 90, 78] with a sum of 468
#  78 is the picked number in the next row
#
# Current Path Sum= 3606 after row 53
#
#
#
#
# Original Cone of choices
# [[53, 90],
#  [84, 42, 70],
#  [25, 1, 7, 61],
#  [6, 14, 18, 17, 5],
#  [13, 24, 55, 11, 65, 26],
#  [6, 23, 84, 75, 23, 87, 72],
#  [32, 39, 24, 74, 47, 26, 90, 13]]
#
# The best backwards path is [90, 87, 65, 17, 61, 70, 90] with a sum of 480
#  90 is the picked number in the next row
#
# Current Path Sum= 3696 after row 54
#
#
#
#
# Original Cone of choices
# [[42, 70],
#  [1, 7, 61],
#  [14, 18, 17, 5],
#  [24, 55, 11, 65, 26],
#  [23, 84, 75, 23, 87, 72],
#  [39, 24, 74, 47, 26, 90, 13],
#  [47, 34, 55, 16, 49, 24, 23, 29]]
#
# The best backwards path is [23, 90, 87, 65, 17, 61, 70] with a sum of 413
#  70 is the picked number in the next row
#
# Current Path Sum= 3766 after row 55
#
#
#
#
# Original Cone of choices
# [[7, 61],
#  [18, 17, 5],
#  [55, 11, 65, 26],
#  [84, 75, 23, 87, 72],
#  [24, 74, 47, 26, 90, 13],
#  [34, 55, 16, 49, 24, 23, 29],
#  [36, 81, 26, 97, 36, 48, 54, 56]]
#
# The best backwards path is [54, 23, 90, 87, 65, 17, 61] with a sum of 397
#  61 is the picked number in the next row
#
# Current Path Sum= 3827 after row 56
#
#
#
#
# Original Cone of choices
# [[17, 5],
#  [11, 65, 26],
#  [75, 23, 87, 72],
#  [74, 47, 26, 90, 13],
#  [55, 16, 49, 24, 23, 29],
#  [81, 26, 97, 36, 48, 54, 56],
#  [68, 87, 3, 84, 23, 44, 89, 72]]
#
# The best backwards path is [89, 54, 23, 90, 87, 65, 17] with a sum of 425
#  17 is the picked number in the next row
#
# Current Path Sum= 3844 after row 57
#
#
#
#
# Original Cone of choices
# [[11, 65],
#  [75, 23, 87],
#  [74, 47, 26, 90],
#  [55, 16, 49, 24, 23],
#  [81, 26, 97, 36, 48, 54],
#  [68, 87, 3, 84, 23, 44, 89],
#  [35, 89, 89, 41, 3, 64, 56, 97]]
#
# The best backwards path is [97, 89, 54, 23, 90, 87, 65] with a sum of 505
#  65 is the picked number in the next row
#
# Current Path Sum= 3909 after row 58
#
#
#
#
# Original Cone of choices
# [[23, 87],
#  [47, 26, 90],
#  [16, 49, 24, 23],
#  [26, 97, 36, 48, 54],
#  [87, 3, 84, 23, 44, 89],
#  [89, 89, 41, 3, 64, 56, 97],
#  [12, 90, 99, 32, 77, 56, 41, 18]]
#
# The best backwards path is [99, 41, 84, 97, 49, 26, 87] with a sum of 483
#  87 is the picked number in the next row
#
# Current Path Sum= 3996 after row 59
#
#
#
#
# Original Cone of choices
# [[26, 90],
#  [49, 24, 23],
#  [97, 36, 48, 54],
#  [3, 84, 23, 44, 89],
#  [89, 41, 3, 64, 56, 97],
#  [90, 99, 32, 77, 56, 41, 18],
#  [73, 79, 73, 19, 97, 32, 64, 29]]
#
# The best backwards path is [79, 99, 41, 84, 97, 49, 26] with a sum of 475
#  26 is the picked number in the next row
#
# Current Path Sum= 4022 after row 60
#
#
#
#
# Original Cone of choices
# [[49, 24],
#  [97, 36, 48],
#  [3, 84, 23, 44],
#  [89, 41, 3, 64, 56],
#  [90, 99, 32, 77, 56, 41],
#  [73, 79, 73, 19, 97, 32, 64],
#  [47, 27, 1, 88, 66, 99, 21, 41]]
#
# The best backwards path is [99, 97, 77, 3, 84, 97, 49] with a sum of 506
#  49 is the picked number in the next row
#
# Current Path Sum= 4071 after row 61
#
#
#
#
# Original Cone of choices
# [[97, 36],
#  [3, 84, 23],
#  [89, 41, 3, 64],
#  [90, 99, 32, 77, 56],
#  [73, 79, 73, 19, 97, 32],
#  [47, 27, 1, 88, 66, 99, 21],
#  [87, 9, 81, 95, 22, 28, 76, 69]]
#
# The best backwards path is [76, 99, 97, 77, 3, 84, 97] with a sum of 533
#  97 is the picked number in the next row
#
# Current Path Sum= 4168 after row 62
#
#
#
#
# Original Cone of choices
# [[3, 84],
#  [89, 41, 3],
#  [90, 99, 32, 77],
#  [73, 79, 73, 19, 97],
#  [47, 27, 1, 88, 66, 99],
#  [87, 9, 81, 95, 22, 28, 76],
#  [54, 19, 86, 67, 68, 55, 66, 84]]
#
# The best backwards path is [84, 76, 99, 97, 77, 3, 84] with a sum of 520
#  84 is the picked number in the next row
#
# Current Path Sum= 4252 after row 63
#
#
#
#
# Original Cone of choices
# [[41, 3],
#  [99, 32, 77],
#  [79, 73, 19, 97],
#  [27, 1, 88, 66, 99],
#  [9, 81, 95, 22, 28, 76],
#  [19, 86, 67, 68, 55, 66, 84],
#  [8, 35, 14, 37, 57, 23, 65, 67]]
#
# The best backwards path is [67, 84, 76, 99, 97, 77, 3] with a sum of 503
#  3 is the picked number in the next row
#
# Current Path Sum= 4255 after row 64
#
#
#
#
# Original Cone of choices
# [[32, 77],
#  [73, 19, 97],
#  [1, 88, 66, 99],
#  [81, 95, 22, 28, 76],
#  [86, 67, 68, 55, 66, 84],
#  [35, 14, 37, 57, 23, 65, 67],
#  [25, 71, 87, 16, 70, 85, 19, 25]]
#
# The best backwards path is [25, 67, 84, 76, 99, 97, 77] with a sum of 525
#  77 is the picked number in the next row
#
# Current Path Sum= 4332 after row 65
#
#
#
#
# Original Cone of choices
# [[19, 97],
#  [88, 66, 99],
#  [95, 22, 28, 76],
#  [67, 68, 55, 66, 84],
#  [14, 37, 57, 23, 65, 67],
#  [71, 87, 16, 70, 85, 19, 25],
#  [69, 73, 72, 7, 5, 27, 61, 24]]
#
# The best backwards path is [61, 25, 67, 84, 76, 99, 97] with a sum of 509
#  97 is the picked number in the next row
#
# Current Path Sum= 4429 after row 66
#
#
#
#
# Original Cone of choices
# [[66, 99],
#  [22, 28, 76],
#  [68, 55, 66, 84],
#  [37, 57, 23, 65, 67],
#  [87, 16, 70, 85, 19, 25],
#  [73, 72, 7, 5, 27, 61, 24],
#  [77, 8, 9, 48, 44, 80, 90, 22]]
#
# The best backwards path is [90, 61, 25, 67, 84, 76, 99] with a sum of 502
#  99 is the picked number in the next row
#
# Current Path Sum= 4528 after row 67
#
#
#
#
# Original Cone of choices
# [[28, 76],
#  [55, 66, 84],
#  [57, 23, 65, 67],
#  [16, 70, 85, 19, 25],
#  [72, 7, 5, 27, 61, 24],
#  [8, 9, 48, 44, 80, 90, 22],
#  [46, 37, 91, 39, 75, 75, 18, 58]]
#
# The best backwards path is [91, 48, 5, 85, 65, 84, 76] with a sum of 454
#  76 is the picked number in the next row
#
# Current Path Sum= 4604 after row 68
#
#
#
#
# Original Cone of choices
# [[66, 84],
#  [23, 65, 67],
#  [70, 85, 19, 25],
#  [7, 5, 27, 61, 24],
#  [9, 48, 44, 80, 90, 22],
#  [37, 91, 39, 75, 75, 18, 58],
#  [33, 61, 36, 27, 28, 46, 98, 14]]
#
# The best backwards path is [46, 75, 80, 27, 85, 65, 66] with a sum of 444
#  66 is the picked number in the next row
#
# Current Path Sum= 4670 after row 69
#
#
#
#
# Original Cone of choices
# [[23, 65],
#  [70, 85, 19],
#  [7, 5, 27, 61],
#  [9, 48, 44, 80, 90],
#  [37, 91, 39, 75, 75, 18],
#  [33, 61, 36, 27, 28, 46, 98],
#  [99, 22, 48, 90, 20, 5, 96, 75]]
#
# The best backwards path is [96, 46, 75, 80, 27, 85, 65] with a sum of 474
#  65 is the picked number in the next row
#
# Current Path Sum= 4735 after row 70
#
#
#
#
# Original Cone of choices
# [[85, 19],
#  [5, 27, 61],
#  [48, 44, 80, 90],
#  [91, 39, 75, 75, 18],
#  [61, 36, 27, 28, 46, 98],
#  [22, 48, 90, 20, 5, 96, 75],
#  [21, 89, 34, 96, 91, 48, 76, 43]]
#
# The best backwards path is [76, 96, 46, 75, 80, 27, 85] with a sum of 485
#  85 is the picked number in the next row
#
# Current Path Sum= 4820 after row 71
#
#
#
#
# Original Cone of choices
# [[5, 27],
#  [48, 44, 80],
#  [91, 39, 75, 75],
#  [61, 36, 27, 28, 46],
#  [22, 48, 90, 20, 5, 96],
#  [21, 89, 34, 96, 91, 48, 76],
#  [68, 22, 7, 9, 49, 34, 31, 77]]
#
# The best backwards path is [77, 76, 96, 46, 75, 80, 27] with a sum of 477
#  27 is the picked number in the next row
#
# Current Path Sum= 4847 after row 72
#
#
#
#
# Original Cone of choices
# [[44, 80],
#  [39, 75, 75],
#  [36, 27, 28, 46],
#  [48, 90, 20, 5, 96],
#  [89, 34, 96, 91, 48, 76],
#  [22, 7, 9, 49, 34, 31, 77],
#  [66, 10, 98, 65, 83, 21, 5, 56]]
#
# The best backwards path is [56, 77, 76, 96, 46, 75, 80] with a sum of 506
#  80 is the picked number in the next row
#
# Current Path Sum= 4927 after row 73
#
#
#
#
# Original Cone of choices
# [[75, 75],
#  [27, 28, 46],
#  [90, 20, 5, 96],
#  [34, 96, 91, 48, 76],
#  [7, 9, 49, 34, 31, 77],
#  [10, 98, 65, 83, 21, 5, 56],
#  [28, 81, 5, 99, 66, 81, 86, 38]]
#
# The best backwards path is [86, 56, 77, 76, 96, 46, 75] with a sum of 512
#  75 is the picked number in the next row
#
# Current Path Sum= 5002 after row 74
#
#
#
#
# Original Cone of choices
# [[27, 28],
#  [90, 20, 5],
#  [34, 96, 91, 48],
#  [7, 9, 49, 34, 31],
#  [10, 98, 65, 83, 21, 5],
#  [28, 81, 5, 99, 66, 81, 86],
#  [65, 97, 86, 9, 50, 94, 68, 69]]
#
# The best backwards path is [94, 66, 83, 49, 96, 90, 27] with a sum of 505
#  27 is the picked number in the next row
#
# Current Path Sum= 5029 after row 75
#
#
#
#
# Original Cone of choices
# [[90, 20],
#  [34, 96, 91],
#  [7, 9, 49, 34],
#  [10, 98, 65, 83, 21],
#  [28, 81, 5, 99, 66, 81],
#  [65, 97, 86, 9, 50, 94, 68],
#  [56, 8, 28, 33, 40, 94, 76, 90]]
#
# The best backwards path is [94, 94, 66, 83, 49, 96, 90] with a sum of 572
#  90 is the picked number in the next row
#
# Current Path Sum= 5119 after row 76
#
#
#
#
# Original Cone of choices
# [[34, 96],
#  [7, 9, 49],
#  [10, 98, 65, 83],
#  [28, 81, 5, 99, 66],
#  [65, 97, 86, 9, 50, 94],
#  [56, 8, 28, 33, 40, 94, 76],
#  [78, 22, 94, 34, 40, 68, 87, 84]]
#
# The best backwards path is [87, 94, 94, 66, 83, 49, 96] with a sum of 569
#  96 is the picked number in the next row
#
# Current Path Sum= 5215 after row 77
#
#
#
#
# Original Cone of choices
# [[9, 49],
#  [98, 65, 83],
#  [81, 5, 99, 66],
#  [97, 86, 9, 50, 94],
#  [8, 28, 33, 40, 94, 76],
#  [22, 94, 34, 40, 68, 87, 84],
#  [40, 83, 64, 83, 58, 85, 17, 76]]
#
# The best backwards path is [76, 84, 76, 94, 66, 83, 49] with a sum of 528
#  49 is the picked number in the next row
#
# Current Path Sum= 5264 after row 78
#
#
#
#
# Original Cone of choices
# [[65, 83],
#  [5, 99, 66],
#  [86, 9, 50, 94],
#  [28, 33, 40, 94, 76],
#  [94, 34, 40, 68, 87, 84],
#  [83, 64, 83, 58, 85, 17, 76],
#  [76, 99, 79, 34, 65, 79, 27, 55]]
#
# The best backwards path is [79, 85, 87, 94, 50, 99, 65] with a sum of 559
#  65 is the picked number in the next row
#
# Current Path Sum= 5329 after row 79
#
#
#
#
# Original Cone of choices
# [[5, 99],
#  [86, 9, 50],
#  [28, 33, 40, 94],
#  [94, 34, 40, 68, 87],
#  [83, 64, 83, 58, 85, 17],
#  [76, 99, 79, 34, 65, 79, 27],
#  [23, 14, 15, 80, 97, 44, 78, 49]]
#
# The best backwards path is [78, 79, 85, 87, 94, 50, 99] with a sum of 572
#  99 is the picked number in the next row
#
# Current Path Sum= 5428 after row 80
#
#
#
#
# Original Cone of choices
# [[9, 50],
#  [33, 40, 94],
#  [34, 40, 68, 87],
#  [64, 83, 58, 85, 17],
#  [99, 79, 34, 65, 79, 27],
#  [14, 15, 80, 97, 44, 78, 49],
#  [86, 72, 45, 25, 10, 28, 19, 6]]
#
# The best backwards path is [19, 78, 79, 85, 87, 94, 50] with a sum of 492
#  50 is the picked number in the next row
#
# Current Path Sum= 5478 after row 81
#
#
#
#
# Original Cone of choices
# [[40, 94],
#  [40, 68, 87],
#  [83, 58, 85, 17],
#  [79, 34, 65, 79, 27],
#  [15, 80, 97, 44, 78, 49],
#  [72, 45, 25, 10, 28, 19, 6],
#  [73, 17, 35, 53, 18, 35, 45, 54]]
#
# The best backwards path is [35, 25, 97, 65, 85, 87, 94] with a sum of 488
#  94 is the picked number in the next row
#
# Current Path Sum= 5572 after row 82
#
#
#
#
# Original Cone of choices
# [[68, 87],
#  [58, 85, 17],
#  [34, 65, 79, 27],
#  [80, 97, 44, 78, 49],
#  [45, 25, 10, 28, 19, 6],
#  [17, 35, 53, 18, 35, 45, 54],
#  [25, 45, 18, 69, 96, 88, 36, 93]]
#
# The best backwards path is [88, 45, 19, 78, 79, 85, 68] with a sum of 462
#  68 is the picked number in the next row
#
# Current Path Sum= 5640 after row 83
#
#
#
#
# Original Cone of choices
# [[58, 85],
#  [34, 65, 79],
#  [80, 97, 44, 78],
#  [45, 25, 10, 28, 19],
#  [17, 35, 53, 18, 35, 45],
#  [25, 45, 18, 69, 96, 88, 36],
#  [50, 99, 73, 5, 93, 48, 17, 31]]
#
# The best backwards path is [99, 45, 35, 25, 97, 65, 85] with a sum of 451
#  85 is the picked number in the next row
#
# Current Path Sum= 5725 after row 84
#
#
#
#
# Original Cone of choices
# [[65, 79],
#  [97, 44, 78],
#  [25, 10, 28, 19],
#  [35, 53, 18, 35, 45],
#  [45, 18, 69, 96, 88, 36],
#  [99, 73, 5, 93, 48, 17, 31],
#  [34, 23, 51, 4, 83, 99, 75, 90]]
#
# The best backwards path is [99, 48, 96, 18, 10, 97, 65] with a sum of 433
#  65 is the picked number in the next row
#
# Current Path Sum= 5790 after row 85
#
#
#
#
# Original Cone of choices
# [[97, 44],
#  [25, 10, 28],
#  [35, 53, 18, 35],
#  [45, 18, 69, 96, 88],
#  [99, 73, 5, 93, 48, 17],
#  [34, 23, 51, 4, 83, 99, 75],
#  [62, 65, 18, 99, 76, 49, 18, 72]]
#
# The best backwards path is [49, 83, 93, 69, 53, 25, 97] with a sum of 469
#  97 is the picked number in the next row
#
# Current Path Sum= 5887 after row 86
#
#
#
#
# Original Cone of choices
# [[25, 10],
#  [35, 53, 18],
#  [45, 18, 69, 96],
#  [99, 73, 5, 93, 48],
#  [34, 23, 51, 4, 83, 99],
#  [62, 65, 18, 99, 76, 49, 18],
#  [27, 88, 97, 32, 14, 6, 35, 78]]
#
# The best backwards path is [35, 49, 83, 93, 69, 53, 25] with a sum of 407
#  25 is the picked number in the next row
#
# Current Path Sum= 5912 after row 87
#
#
#
#
# Original Cone of choices
# [[35, 53],
#  [45, 18, 69],
#  [99, 73, 5, 93],
#  [34, 23, 51, 4, 83],
#  [62, 65, 18, 99, 76, 49],
#  [27, 88, 97, 32, 14, 6, 35],
#  [48, 61, 50, 90, 65, 1, 87, 42]]
#
# The best backwards path is [87, 35, 49, 83, 93, 69, 53] with a sum of 469
#  53 is the picked number in the next row
#
# Current Path Sum= 5965 after row 88
#
#
#
#
# Original Cone of choices
# [[18, 69],
#  [73, 5, 93],
#  [23, 51, 4, 83],
#  [65, 18, 99, 76, 49],
#  [88, 97, 32, 14, 6, 35],
#  [61, 50, 90, 65, 1, 87, 42],
#  [89, 28, 85, 85, 80, 53, 34, 87]]
#
# The best backwards path is [85, 90, 32, 99, 4, 93, 69] with a sum of 472
#  69 is the picked number in the next row
#
# Current Path Sum= 6034 after row 89
#
#
#
#
# Original Cone of choices
# [[5, 93],
#  [51, 4, 83],
#  [18, 99, 76, 49],
#  [97, 32, 14, 6, 35],
#  [50, 90, 65, 1, 87, 42],
#  [28, 85, 85, 80, 53, 34, 87],
#  [99, 28, 83, 15, 75, 99, 1, 89]]
#
# The best backwards path is [83, 85, 65, 14, 76, 83, 93] with a sum of 499
#  93 is the picked number in the next row
#
# Current Path Sum= 6127 after row 90
#
#
#
#
# Original Cone of choices
# [[4, 83],
#  [99, 76, 49],
#  [32, 14, 6, 35],
#  [90, 65, 1, 87, 42],
#  [85, 85, 80, 53, 34, 87],
#  [28, 83, 15, 75, 99, 1, 89],
#  [91, 39, 50, 31, 42, 64, 70, 4]]
#
# The best backwards path is [50, 83, 85, 65, 14, 76, 83] with a sum of 456
#  83 is the picked number in the next row
#
# Current Path Sum= 6210 after row 91
#
#
#
#
# Original Cone of choices
# [[76, 49],
#  [14, 6, 35],
#  [65, 1, 87, 42],
#  [85, 80, 53, 34, 87],
#  [83, 15, 75, 99, 1, 89],
#  [39, 50, 31, 42, 64, 70, 4],
#  [74, 69, 4, 85, 57, 77, 35, 58]]
#
# The best backwards path is [77, 64, 99, 53, 87, 6, 76] with a sum of 462
#  76 is the picked number in the next row
#
# Current Path Sum= 6286 after row 92
#
#
#
#
# Original Cone of choices
# [[14, 6],
#  [65, 1, 87],
#  [85, 80, 53, 34],
#  [83, 15, 75, 99, 1],
#  [39, 50, 31, 42, 64, 70],
#  [74, 69, 4, 85, 57, 77, 35],
#  [68, 39, 51, 56, 59, 63, 7, 25]]
#
# The best backwards path is [68, 74, 39, 83, 85, 65, 14] with a sum of 428
#  14 is the picked number in the next row
#
# Current Path Sum= 6300 after row 93
#
#
#
#
# Adding in 428 for the final 7 rows, and the grand total of 6728
# [[59], [73], [52], [53], [51], [95], [81], [28], [95], [58], [78], [93], [78], [17], [75], [77], [69], [13], [35], [65], [90], [93], [88], [52], [19], [98], [57], [88], [41], [89], [2], [85], [51], [78], [84], [56], [84], [72], [98], [84], [78], [56], [36], [87], [19], [88], [67], [96], [81], [52], [98], [38], [78], [78], [90], [70], [61], [17], [65], [87], [26], [49], [97], [84], [3], [77], [97], [99], [76], [66], [65], [85], [27], [80], [75], [27], [90], [96], [49], [65], [99], [50], [94], [68], [85], [65], [97], [25], [53], [69], [93], [83], [76], [14], [65, 1], [85, 80, 53], [83, 15, 75, 99], [39, 50, 31, 42, 64], [74, 69, 4, 85, 57, 77], [68, 39, 51, 56, 59, 63, 7]]
