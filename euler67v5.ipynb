# %%
from pprint import pprint
import copy

# %%
def fileReader():
    tempList=[]   
    with open(r"/Users/aaronSmith/Documents/p067_triangle.txt","r") as f:
        lines = list(map(lambda l: l.strip(), f.readlines()))
        for i in range(len(lines)):
            for j in lines[i].split(","):

                tempList.append(j.split(" "))
                
    triangleList=[]
    for l in tempList:
        l=list(map(int,l))
        triangleList.append(l)
    
    return triangleList

# %%
def plinko(choices):
    try:
        listOfLists=[]
        while True:
            tempList=[]
            shrinkingChoices=copy.deepcopy(choices)
            
            
            if len(choices[6])>=len(choices[7]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(choices[6].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(5,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue
            

            if len(choices[5])>=len(choices[6]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(choices[5].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(4,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue
            
            if len(choices[4])>=len(choices[5]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(choices[4].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(3,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue
            
            if len(choices[3])>=len(choices[4]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(choices[3].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(2,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[2])>=len(choices[3]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(choices[2].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(1,-1,-1):
                    tempList.append(shrinkingChoices[i].pop(-1))
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[1])>=len(choices[2]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(choices[1].pop())
                shrinkingChoices=copy.deepcopy(choices)
                tempList.append(shrinkingChoices[0].pop())
                listOfLists.append(tempList)
                tempList=[]
                continue

            if len(choices[0])>=len(choices[1]):
                tempList.append(shrinkingChoices[7].pop())
                tempList.append(shrinkingChoices[6].pop())
                tempList.append(shrinkingChoices[5].pop())
                tempList.append(shrinkingChoices[4].pop())
                tempList.append(shrinkingChoices[3].pop())
                tempList.append(shrinkingChoices[2].pop())
                tempList.append(shrinkingChoices[1].pop())
                tempList.append(choices[0].pop())
                shrinkingChoices=copy.deepcopy(choices)
                listOfLists.append(tempList)
                tempList=[]
                continue
                
            else:
                tempList.append(choices[7].pop())
                shrinkingChoices=copy.deepcopy(choices)
                for i in range(6,-1,-1):
                    tempList.append(shrinkingChoices[i].pop())
                listOfLists.append(tempList)
                tempList=[]
 
    except IndexError:
#         listOfLists.pop()
        return listOfLists

# %%
triangleList=fileReader()
iY=0
finalPathSum=triangleList[0][0]
print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")


for i in range(len(triangleList)-8):
    testList=copy.deepcopy(triangleList[iY+1:iY+9])
    choices=copy.deepcopy(testList)

    allLists=[]
    listOfLists=plinko(choices)
    allLists.extend(listOfLists)

    reverseChoices=copy.deepcopy(testList)
    for i in range(len(reverseChoices)):
        reverseChoices[i].reverse()

    listOfLists=plinko(reverseChoices)
    allLists.extend(listOfLists)

    sumList=[]
    for l in allLists:
        sumList.append(sum(l)) 
    pickedNumber=allLists[sumList.index(max(sumList))][-1]
    finalPathSum+=pickedNumber
    print("\nOriginal Cone of choices")
    pprint(testList)
    print("\nThe best backwards path is", allLists[sumList.index(max(sumList))], "with a sum of", max(sumList),
          "\n",pickedNumber,"is the picked number in the next row\n")
    iY+=1
    if testList[0].index(pickedNumber)==0:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop()
    else:
        for l in range(iY,len(triangleList)):
            triangleList[l].pop(0)
    print("Current Path Sum=",finalPathSum,"after row",iY,"\n\n\n")
finalPathSum+=max(sumList)
print("\nAdding in", max(sumList), "for the final 8 rows, and the grand total of", finalPathSum)
print(triangleList)
# finalAnswer supposed to be 7273
# Out:
# Current Path Sum= 59 after row 0
#
#
#
#
# Original Cone of choices
# [[73, 41],
#  [52, 40, 9],
#  [26, 53, 6, 34],
#  [10, 51, 87, 86, 81],
#  [61, 95, 66, 57, 25, 68],
#  [90, 81, 80, 38, 92, 67, 73],
#  [30, 28, 51, 76, 81, 18, 75, 44],
#  [84, 14, 95, 87, 62, 81, 17, 78, 58]]
#
# The best backwards path is [95, 51, 80, 66, 87, 53, 40, 41] with a sum of 513
#  41 is the picked number in the next row
#
# Current Path Sum= 100 after row 1
#
#
#
#
# Original Cone of choices
# [[40, 9],
#  [53, 6, 34],
#  [51, 87, 86, 81],
#  [95, 66, 57, 25, 68],
#  [81, 80, 38, 92, 67, 73],
#  [28, 51, 76, 81, 18, 75, 44],
#  [14, 95, 87, 62, 81, 17, 78, 58],
#  [46, 71, 58, 2, 79, 62, 39, 31, 9]]
#
# The best backwards path is [71, 95, 51, 80, 66, 87, 53, 40] with a sum of 543
#  40 is the picked number in the next row
#
# Current Path Sum= 140 after row 2
#
#
#
#
# Original Cone of choices
# [[53, 6],
#  [51, 87, 86],
#  [95, 66, 57, 25],
#  [81, 80, 38, 92, 67],
#  [28, 51, 76, 81, 18, 75],
#  [14, 95, 87, 62, 81, 17, 78],
#  [46, 71, 58, 2, 79, 62, 39, 31],
#  [34, 35, 53, 78, 31, 81, 18, 90, 93]]
#
# The best backwards path is [35, 71, 95, 51, 80, 66, 87, 53] with a sum of 538
#  53 is the picked number in the next row
#
# Current Path Sum= 193 after row 3
#
#
#
#
# Original Cone of choices
# [[51, 87],
#  [95, 66, 57],
#  [81, 80, 38, 92],
#  [28, 51, 76, 81, 18],
#  [14, 95, 87, 62, 81, 17],
#  [46, 71, 58, 2, 79, 62, 39],
#  [34, 35, 53, 78, 31, 81, 18, 90],
#  [53, 4, 21, 84, 93, 32, 13, 97, 11]]
#
# The best backwards path is [97, 18, 62, 81, 81, 92, 57, 87] with a sum of 575
#  87 is the picked number in the next row
#
# Current Path Sum= 280 after row 4
#
#
#
#
# Original Cone of choices
# [[66, 57],
#  [80, 38, 92],
#  [51, 76, 81, 18],
#  [95, 87, 62, 81, 17],
#  [71, 58, 2, 79, 62, 39],
#  [35, 53, 78, 31, 81, 18, 90],
#  [4, 21, 84, 93, 32, 13, 97, 11],
#  [81, 79, 5, 18, 78, 86, 13, 30, 63]]
#
# The best backwards path is [79, 21, 53, 58, 87, 76, 80, 66] with a sum of 520
#  66 is the picked number in the next row
#
# Current Path Sum= 346 after row 5
#
#
#
#
# Original Cone of choices
# [[80, 38],
#  [51, 76, 81],
#  [95, 87, 62, 81],
#  [71, 58, 2, 79, 62],
#  [35, 53, 78, 31, 81, 18],
#  [4, 21, 84, 93, 32, 13, 97],
#  [81, 79, 5, 18, 78, 86, 13, 30],
#  [96, 28, 3, 38, 42, 17, 82, 87, 58]]
#
# The best backwards path is [82, 86, 32, 81, 79, 62, 76, 80] with a sum of 578
#  80 is the picked number in the next row
#
# Current Path Sum= 426 after row 6
#
#
#
#
# Original Cone of choices
# [[51, 76],
#  [95, 87, 62],
#  [71, 58, 2, 79],
#  [35, 53, 78, 31, 81],
#  [4, 21, 84, 93, 32, 13],
#  [81, 79, 5, 18, 78, 86, 13],
#  [96, 28, 3, 38, 42, 17, 82, 87],
#  [51, 17, 7, 93, 9, 7, 75, 97, 95]]
#
# The best backwards path is [97, 82, 86, 32, 81, 79, 62, 76] with a sum of 595
#  76 is the picked number in the next row
#
# Current Path Sum= 502 after row 7
#
#
#
#
# Original Cone of choices
# [[87, 62],
#  [58, 2, 79],
#  [53, 78, 31, 81],
#  [21, 84, 93, 32, 13],
#  [79, 5, 18, 78, 86, 13],
#  [28, 3, 38, 42, 17, 82, 87],
#  [17, 7, 93, 9, 7, 75, 97, 95],
#  [60, 88, 99, 94, 65, 55, 77, 55, 34]]
#
# The best backwards path is [55, 97, 82, 86, 32, 81, 79, 62] with a sum of 574
#  62 is the picked number in the next row
#
# Current Path Sum= 564 after row 8
#
#
#
#
# Original Cone of choices
# [[2, 79],
#  [78, 31, 81],
#  [84, 93, 32, 13],
#  [5, 18, 78, 86, 13],
#  [3, 38, 42, 17, 82, 87],
#  [7, 93, 9, 7, 75, 97, 95],
#  [88, 99, 94, 65, 55, 77, 55, 34],
#  [87, 16, 9, 42, 75, 69, 23, 97, 30]]
#
# The best backwards path is [97, 55, 97, 82, 86, 32, 81, 79] with a sum of 609
#  79 is the picked number in the next row
#
# Current Path Sum= 643 after row 9
#
#
#
#
# Original Cone of choices
# [[31, 81],
#  [93, 32, 13],
#  [18, 78, 86, 13],
#  [38, 42, 17, 82, 87],
#  [93, 9, 7, 75, 97, 95],
#  [99, 94, 65, 55, 77, 55, 34],
#  [16, 9, 42, 75, 69, 23, 97, 30],
#  [36, 32, 84, 98, 60, 13, 12, 36, 16]]
#
# The best backwards path is [36, 97, 55, 97, 82, 86, 32, 81] with a sum of 566
#  81 is the picked number in the next row
#
# Current Path Sum= 724 after row 10
#
#
#
#
# Original Cone of choices
# [[32, 13],
#  [78, 86, 13],
#  [42, 17, 82, 87],
#  [9, 7, 75, 97, 95],
#  [94, 65, 55, 77, 55, 34],
#  [9, 42, 75, 69, 23, 97, 30],
#  [32, 84, 98, 60, 13, 12, 36, 16],
#  [38, 48, 28, 22, 34, 35, 62, 62, 15]]
#
# The best backwards path is [62, 36, 97, 55, 97, 82, 86, 32] with a sum of 547
#  32 is the picked number in the next row
#
# Current Path Sum= 756 after row 11
#
#
#
#
# Original Cone of choices
# [[78, 86],
#  [42, 17, 82],
#  [9, 7, 75, 97],
#  [94, 65, 55, 77, 55],
#  [9, 42, 75, 69, 23, 97],
#  [32, 84, 98, 60, 13, 12, 36],
#  [38, 48, 28, 22, 34, 35, 62, 62],
#  [34, 34, 34, 81, 62, 40, 65, 54, 62]]
#
# The best backwards path is [62, 62, 36, 97, 55, 97, 82, 86] with a sum of 577
#  86 is the picked number in the next row
#
# Current Path Sum= 842 after row 12
#
#
#
#
# Original Cone of choices
# [[17, 82],
#  [7, 75, 97],
#  [65, 55, 77, 55],
#  [42, 75, 69, 23, 97],
#  [84, 98, 60, 13, 12, 36],
#  [48, 28, 22, 34, 35, 62, 62],
#  [34, 34, 81, 62, 40, 65, 54, 62],
#  [53, 36, 14, 70, 26, 2, 90, 45, 13]]
#
# The best backwards path is [45, 62, 62, 36, 97, 55, 97, 82] with a sum of 536
#  82 is the picked number in the next row
#
# Current Path Sum= 924 after row 13
#
#
#
#
# Original Cone of choices
# [[75, 97],
#  [55, 77, 55],
#  [75, 69, 23, 97],
#  [98, 60, 13, 12, 36],
#  [28, 22, 34, 35, 62, 62],
#  [34, 81, 62, 40, 65, 54, 62],
#  [36, 14, 70, 26, 2, 90, 45, 13],
#  [37, 42, 14, 58, 84, 93, 96, 17, 9]]
#
# The best backwards path is [96, 90, 65, 35, 13, 69, 77, 75] with a sum of 520
#  75 is the picked number in the next row
#
# Current Path Sum= 999 after row 14
#
#
#
#
# Original Cone of choices
# [[55, 77],
#  [75, 69, 23],
#  [98, 60, 13, 12],
#  [28, 22, 34, 35, 62],
#  [34, 81, 62, 40, 65, 54],
#  [36, 14, 70, 26, 2, 90, 45],
#  [37, 42, 14, 58, 84, 93, 96, 17],
#  [84, 73, 79, 15, 39, 95, 88, 87, 43]]
#
# The best backwards path is [87, 96, 90, 65, 35, 13, 69, 77] with a sum of 532
#  77 is the picked number in the next row
#
# Current Path Sum= 1076 after row 15
#
#
#
#
# Original Cone of choices
# [[69, 23],
#  [60, 13, 12],
#  [22, 34, 35, 62],
#  [81, 62, 40, 65, 54],
#  [14, 70, 26, 2, 90, 45],
#  [42, 14, 58, 84, 93, 96, 17],
#  [73, 79, 15, 39, 95, 88, 87, 43],
#  [37, 50, 2, 45, 9, 54, 52, 27, 95]]
#
# The best backwards path is [52, 88, 96, 90, 65, 35, 13, 69] with a sum of 508
#  69 is the picked number in the next row
#
# Current Path Sum= 1145 after row 16
#
#
#
#
# Original Cone of choices
# [[60, 13],
#  [22, 34, 35],
#  [81, 62, 40, 65],
#  [14, 70, 26, 2, 90],
#  [42, 14, 58, 84, 93, 96],
#  [73, 79, 15, 39, 95, 88, 87],
#  [37, 50, 2, 45, 9, 54, 52, 27],
#  [99, 78, 19, 35, 62, 71, 19, 23, 65]]
#
# The best backwards path is [65, 27, 87, 96, 90, 65, 35, 13] with a sum of 478
#  13 is the picked number in the next row
#
# Current Path Sum= 1158 after row 17
#
#
#
#
# Original Cone of choices
# [[34, 35],
#  [62, 40, 65],
#  [70, 26, 2, 90],
#  [14, 58, 84, 93, 96],
#  [79, 15, 39, 95, 88, 87],
#  [50, 2, 45, 9, 54, 52, 27],
#  [78, 19, 35, 62, 71, 19, 23, 65],
#  [91, 54, 46, 57, 7, 77, 98, 52, 80]]
#
# The best backwards path is [80, 65, 27, 87, 96, 90, 65, 35] with a sum of 545
#  35 is the picked number in the next row
#
# Current Path Sum= 1193 after row 18
#
#
#
#
# Original Cone of choices
# [[40, 65],
#  [26, 2, 90],
#  [58, 84, 93, 96],
#  [15, 39, 95, 88, 87],
#  [2, 45, 9, 54, 52, 27],
#  [19, 35, 62, 71, 19, 23, 65],
#  [54, 46, 57, 7, 77, 98, 52, 80],
#  [49, 51, 31, 24, 68, 5, 57, 7, 54]]
#
# The best backwards path is [54, 80, 65, 27, 87, 96, 90, 65] with a sum of 564
#  65 is the picked number in the next row
#
# Current Path Sum= 1258 after row 19
#
#
#
#
# Original Cone of choices
# [[2, 90],
#  [84, 93, 96],
#  [39, 95, 88, 87],
#  [45, 9, 54, 52, 27],
#  [35, 62, 71, 19, 23, 65],
#  [46, 57, 7, 77, 98, 52, 80],
#  [51, 31, 24, 68, 5, 57, 7, 54],
#  [9, 9, 24, 30, 71, 8, 88, 70, 72]]
#
# The best backwards path is [72, 54, 80, 65, 27, 87, 96, 90] with a sum of 571
#  90 is the picked number in the next row
#
# Current Path Sum= 1348 after row 20
#
#
#
#
# Original Cone of choices
# [[93, 96],
#  [95, 88, 87],
#  [9, 54, 52, 27],
#  [62, 71, 19, 23, 65],
#  [57, 7, 77, 98, 52, 80],
#  [31, 24, 68, 5, 57, 7, 54],
#  [9, 24, 30, 71, 8, 88, 70, 72],
#  [61, 30, 90, 29, 94, 26, 41, 89, 4]]
#
# The best backwards path is [90, 30, 68, 77, 71, 54, 88, 96] with a sum of 574
#  96 is the picked number in the next row
#
# Current Path Sum= 1444 after row 21
#
#
#
#
# Original Cone of choices
# [[88, 87],
#  [54, 52, 27],
#  [71, 19, 23, 65],
#  [7, 77, 98, 52, 80],
#  [24, 68, 5, 57, 7, 54],
#  [24, 30, 71, 8, 88, 70, 72],
#  [30, 90, 29, 94, 26, 41, 89, 4],
#  [62, 13, 17, 8, 19, 54, 89, 29, 73]]
#
# The best backwards path is [89, 41, 88, 57, 98, 23, 52, 88] with a sum of 536
#  88 is the picked number in the next row
#
# Current Path Sum= 1532 after row 22
#
#
#
#
# Original Cone of choices
# [[54, 52],
#  [71, 19, 23],
#  [7, 77, 98, 52],
#  [24, 68, 5, 57, 7],
#  [24, 30, 71, 8, 88, 70],
#  [30, 90, 29, 94, 26, 41, 89],
#  [62, 13, 17, 8, 19, 54, 89, 29],
#  [9, 30, 43, 89, 30, 39, 15, 2, 44]]
#
# The best backwards path is [15, 89, 41, 88, 57, 98, 19, 54] with a sum of 461
#  54 is the picked number in the next row
#
# Current Path Sum= 1586 after row 23
#
#
#
#
# Original Cone of choices
# [[71, 19],
#  [7, 77, 98],
#  [24, 68, 5, 57],
#  [24, 30, 71, 8, 88],
#  [30, 90, 29, 94, 26, 41],
#  [62, 13, 17, 8, 19, 54, 89],
#  [9, 30, 43, 89, 30, 39, 15, 2],
#  [19, 26, 82, 69, 54, 4, 13, 7, 85]]
#
# The best backwards path is [85, 2, 89, 41, 88, 57, 98, 19] with a sum of 479
#  19 is the picked number in the next row
#
# Current Path Sum= 1605 after row 24
#
#
#
#
# Original Cone of choices
# [[77, 98],
#  [68, 5, 57],
#  [30, 71, 8, 88],
#  [90, 29, 94, 26, 41],
#  [13, 17, 8, 19, 54, 89],
#  [30, 43, 89, 30, 39, 15, 2],
#  [26, 82, 69, 54, 4, 13, 7, 85],
#  [84, 36, 20, 73, 42, 21, 23, 22, 51]]
#
# The best backwards path is [51, 85, 2, 89, 41, 88, 57, 98] with a sum of 511
#  98 is the picked number in the next row
#
# Current Path Sum= 1703 after row 25
#
#
#
#
# Original Cone of choices
# [[5, 57],
#  [71, 8, 88],
#  [29, 94, 26, 41],
#  [17, 8, 19, 54, 89],
#  [43, 89, 30, 39, 15, 2],
#  [82, 69, 54, 4, 13, 7, 85],
#  [36, 20, 73, 42, 21, 23, 22, 51],
#  [72, 11, 46, 52, 90, 27, 8, 65, 78]]
#
# The best backwards path is [78, 51, 85, 2, 89, 41, 88, 57] with a sum of 491
#  57 is the picked number in the next row
#
# Current Path Sum= 1760 after row 26
#
#
#
#
# Original Cone of choices
# [[8, 88],
#  [94, 26, 41],
#  [8, 19, 54, 89],
#  [89, 30, 39, 15, 2],
#  [69, 54, 4, 13, 7, 85],
#  [20, 73, 42, 21, 23, 22, 51],
#  [11, 46, 52, 90, 27, 8, 65, 78],
#  [98, 39, 15, 39, 84, 89, 69, 84, 46]]
#
# The best backwards path is [84, 78, 51, 85, 2, 89, 41, 88] with a sum of 518
#  88 is the picked number in the next row
#
# Current Path Sum= 1848 after row 27
#
#
#
#
# Original Cone of choices
# [[26, 41],
#  [19, 54, 89],
#  [30, 39, 15, 2],
#  [54, 4, 13, 7, 85],
#  [73, 42, 21, 23, 22, 51],
#  [46, 52, 90, 27, 8, 65, 78],
#  [39, 15, 39, 84, 89, 69, 84, 46],
#  [47, 90, 90, 45, 91, 20, 50, 56, 10]]
#
# The best backwards path is [56, 84, 78, 51, 85, 2, 89, 41] with a sum of 486
#  41 is the picked number in the next row
#
# Current Path Sum= 1889 after row 28
#
#
#
#
# Original Cone of choices
# [[54, 89],
#  [39, 15, 2],
#  [4, 13, 7, 85],
#  [42, 21, 23, 22, 51],
#  [52, 90, 27, 8, 65, 78],
#  [15, 39, 84, 89, 69, 84, 46],
#  [90, 90, 45, 91, 20, 50, 56, 10],
#  [33, 75, 84, 18, 31, 71, 50, 84, 63]]
#
# The best backwards path is [84, 56, 84, 78, 51, 85, 2, 89] with a sum of 529
#  89 is the picked number in the next row
#
# Current Path Sum= 1978 after row 29
#
#
#
#
# Original Cone of choices
# [[15, 2],
#  [13, 7, 85],
#  [21, 23, 22, 51],
#  [90, 27, 8, 65, 78],
#  [39, 84, 89, 69, 84, 46],
#  [90, 45, 91, 20, 50, 56, 10],
#  [75, 84, 18, 31, 71, 50, 84, 63],
#  [32, 47, 52, 7, 71, 60, 42, 72, 94]]
#
# The best backwards path is [72, 84, 56, 84, 78, 51, 85, 2] with a sum of 512
#  2 is the picked number in the next row
#
# Current Path Sum= 1980 after row 30
#
#
#
#
# Original Cone of choices
# [[7, 85],
#  [23, 22, 51],
#  [27, 8, 65, 78],
#  [84, 89, 69, 84, 46],
#  [45, 91, 20, 50, 56, 10],
#  [84, 18, 31, 71, 50, 84, 63],
#  [47, 52, 7, 71, 60, 42, 72, 94],
#  [52, 69, 95, 72, 93, 22, 34, 98, 20]]
#
# The best backwards path is [98, 72, 84, 56, 84, 78, 51, 85] with a sum of 608
#  85 is the picked number in the next row
#
# Current Path Sum= 2065 after row 31
#
#
#
#
# Original Cone of choices
# [[22, 51],
#  [8, 65, 78],
#  [89, 69, 84, 46],
#  [91, 20, 50, 56, 10],
#  [18, 31, 71, 50, 84, 63],
#  [52, 7, 71, 60, 42, 72, 94],
#  [69, 95, 72, 93, 22, 34, 98, 20],
#  [30, 15, 65, 94, 80, 44, 61, 84, 12]]
#
# The best backwards path is [84, 98, 72, 84, 56, 84, 78, 51] with a sum of 607
#  51 is the picked number in the next row
#
# Current Path Sum= 2116 after row 32
#
#
#
#
# Original Cone of choices
# [[65, 78],
#  [69, 84, 46],
#  [20, 50, 56, 10],
#  [31, 71, 50, 84, 63],
#  [7, 71, 60, 42, 72, 94],
#  [95, 72, 93, 22, 34, 98, 20],
#  [15, 65, 94, 80, 44, 61, 84, 12],
#  [72, 94, 53, 18, 43, 77, 40, 78, 32]]
#
# The best backwards path is [78, 84, 98, 72, 84, 56, 84, 78] with a sum of 634
#  78 is the picked number in the next row
#
# Current Path Sum= 2194 after row 33
#
#
#
#
# Original Cone of choices
# [[84, 46],
#  [50, 56, 10],
#  [71, 50, 84, 63],
#  [71, 60, 42, 72, 94],
#  [72, 93, 22, 34, 98, 20],
#  [65, 94, 80, 44, 61, 84, 12],
#  [94, 53, 18, 43, 77, 40, 78, 32],
#  [64, 6, 69, 84, 14, 22, 56, 43, 9]]
#
# The best backwards path is [56, 78, 84, 98, 72, 84, 56, 84] with a sum of 612
#  84 is the picked number in the next row
#
# Current Path Sum= 2278 after row 34
#
#
#
#
# Original Cone of choices
# [[50, 56],
#  [71, 50, 84],
#  [71, 60, 42, 72],
#  [72, 93, 22, 34, 98],
#  [65, 94, 80, 44, 61, 84],
#  [94, 53, 18, 43, 77, 40, 78],
#  [64, 6, 69, 84, 14, 22, 56, 43],
#  [67, 96, 12, 73, 8, 20, 36, 47, 81]]
#
# The best backwards path is [81, 43, 78, 84, 98, 72, 84, 56] with a sum of 596
#  56 is the picked number in the next row
#
# Current Path Sum= 2334 after row 35
#
#
#
#
# Original Cone of choices
# [[50, 84],
#  [60, 42, 72],
#  [93, 22, 34, 98],
#  [94, 80, 44, 61, 84],
#  [53, 18, 43, 77, 40, 78],
#  [6, 69, 84, 14, 22, 56, 43],
#  [96, 12, 73, 8, 20, 36, 47, 81],
#  [16, 22, 99, 92, 79, 87, 51, 21, 77]]
#
# The best backwards path is [77, 81, 43, 78, 84, 98, 72, 84] with a sum of 617
#  84 is the picked number in the next row
#
# Current Path Sum= 2418 after row 36
#
#
#
#
# Original Cone of choices
# [[42, 72],
#  [22, 34, 98],
#  [80, 44, 61, 84],
#  [18, 43, 77, 40, 78],
#  [69, 84, 14, 22, 56, 43],
#  [12, 73, 8, 20, 36, 47, 81],
#  [22, 99, 92, 79, 87, 51, 21, 77],
#  [26, 58, 89, 50, 66, 19, 82, 75, 12]]
#
# The best backwards path is [75, 77, 81, 43, 78, 84, 98, 72] with a sum of 608
#  72 is the picked number in the next row
#
# Current Path Sum= 2490 after row 37
#
#
#
#
# Original Cone of choices
# [[34, 98],
#  [44, 61, 84],
#  [43, 77, 40, 78],
#  [84, 14, 22, 56, 43],
#  [73, 8, 20, 36, 47, 81],
#  [99, 92, 79, 87, 51, 21, 77],
#  [58, 89, 50, 66, 19, 82, 75, 12],
#  [4, 45, 47, 59, 88, 43, 20, 66, 15]]
#
# The best backwards path is [66, 75, 77, 81, 43, 78, 84, 98] with a sum of 602
#  98 is the picked number in the next row
#
# Current Path Sum= 2588 after row 38
#
#
#
#
# Original Cone of choices
# [[61, 84],
#  [77, 40, 78],
#  [14, 22, 56, 43],
#  [8, 20, 36, 47, 81],
#  [92, 79, 87, 51, 21, 77],
#  [89, 50, 66, 19, 82, 75, 12],
#  [45, 47, 59, 88, 43, 20, 66, 15],
#  [8, 56, 80, 67, 18, 46, 66, 63, 1]]
#
# The best backwards path is [63, 66, 75, 77, 81, 43, 78, 84] with a sum of 567
#  84 is the picked number in the next row
#
# Current Path Sum= 2672 after row 39
#
#
#
#
# Original Cone of choices
# [[40, 78],
#  [22, 56, 43],
#  [20, 36, 47, 81],
#  [79, 87, 51, 21, 77],
#  [50, 66, 19, 82, 75, 12],
#  [47, 59, 88, 43, 20, 66, 15],
#  [56, 80, 67, 18, 46, 66, 63, 1],
#  [21, 82, 96, 25, 24, 96, 18, 2, 5]]
#
# The best backwards path is [96, 67, 88, 66, 87, 36, 56, 78] with a sum of 574
#  78 is the picked number in the next row
#
# Current Path Sum= 2750 after row 40
#
#
#
#
# Original Cone of choices
# [[56, 43],
#  [36, 47, 81],
#  [87, 51, 21, 77],
#  [66, 19, 82, 75, 12],
#  [59, 88, 43, 20, 66, 15],
#  [80, 67, 18, 46, 66, 63, 1],
#  [82, 96, 25, 24, 96, 18, 2, 5],
#  [25, 74, 81, 88, 98, 21, 67, 84, 79]]
#
# The best backwards path is [74, 96, 67, 88, 66, 87, 36, 56] with a sum of 570
#  56 is the picked number in the next row
#
# Current Path Sum= 2806 after row 41
#
#
#
#
# Original Cone of choices
# [[36, 47],
#  [87, 51, 21],
#  [66, 19, 82, 75],
#  [59, 88, 43, 20, 66],
#  [80, 67, 18, 46, 66, 63],
#  [82, 96, 25, 24, 96, 18, 2],
#  [25, 74, 81, 88, 98, 21, 67, 84],
#  [17, 24, 52, 36, 23, 15, 72, 16, 84]]
#
# The best backwards path is [24, 74, 96, 67, 88, 66, 87, 36] with a sum of 538
#  36 is the picked number in the next row
#
# Current Path Sum= 2842 after row 42
#
#
#
#
# Original Cone of choices
# [[87, 51],
#  [66, 19, 82],
#  [59, 88, 43, 20],
#  [80, 67, 18, 46, 66],
#  [82, 96, 25, 24, 96, 18],
#  [25, 74, 81, 88, 98, 21, 67],
#  [17, 24, 52, 36, 23, 15, 72, 16],
#  [78, 18, 98, 27, 28, 84, 80, 67, 75]]
#
# The best backwards path is [98, 52, 81, 96, 67, 88, 19, 51] with a sum of 552
#  51 is the picked number in the next row
#
# Current Path Sum= 2893 after row 43
#
#
#
#
# Original Cone of choices
# [[19, 82],
#  [88, 43, 20],
#  [67, 18, 46, 66],
#  [96, 25, 24, 96, 18],
#  [74, 81, 88, 98, 21, 67],
#  [24, 52, 36, 23, 15, 72, 16],
#  [18, 98, 27, 28, 84, 80, 67, 75],
#  [31, 38, 26, 8, 15, 56, 88, 86, 1]]
#
# The best backwards path is [38, 98, 52, 81, 96, 67, 88, 19] with a sum of 539
#  19 is the picked number in the next row
#
# Current Path Sum= 2912 after row 44
#
#
#
#
# Original Cone of choices
# [[88, 43],
#  [67, 18, 46],
#  [96, 25, 24, 96],
#  [74, 81, 88, 98, 21],
#  [24, 52, 36, 23, 15, 72],
#  [18, 98, 27, 28, 84, 80, 67],
#  [31, 38, 26, 8, 15, 56, 88, 86],
#  [22, 78, 91, 73, 51, 69, 9, 79, 94]]
#
# The best backwards path is [78, 38, 98, 52, 81, 96, 67, 88] with a sum of 598
#  88 is the picked number in the next row
#
# Current Path Sum= 3000 after row 45
#
#
#
#
# Original Cone of choices
# [[67, 18],
#  [96, 25, 24],
#  [74, 81, 88, 98],
#  [24, 52, 36, 23, 15],
#  [18, 98, 27, 28, 84, 80],
#  [31, 38, 26, 8, 15, 56, 88],
#  [22, 78, 91, 73, 51, 69, 9, 79],
#  [82, 71, 78, 33, 67, 9, 16, 96, 68]]
#
# The best backwards path is [71, 78, 38, 98, 52, 81, 96, 67] with a sum of 581
#  67 is the picked number in the next row
#
# Current Path Sum= 3067 after row 46
#
#
#
#
# Original Cone of choices
# [[96, 25],
#  [74, 81, 88],
#  [24, 52, 36, 23],
#  [18, 98, 27, 28, 84],
#  [31, 38, 26, 8, 15, 56],
#  [22, 78, 91, 73, 51, 69, 9],
#  [82, 71, 78, 33, 67, 9, 16, 96],
#  [36, 69, 53, 90, 75, 25, 82, 39, 50]]
#
# The best backwards path is [69, 71, 78, 38, 98, 52, 81, 96] with a sum of 583
#  96 is the picked number in the next row
#
# Current Path Sum= 3163 after row 47
#
#
#
#
# Original Cone of choices
# [[74, 81],
#  [24, 52, 36],
#  [18, 98, 27, 28],
#  [31, 38, 26, 8, 15],
#  [22, 78, 91, 73, 51, 69],
#  [82, 71, 78, 33, 67, 9, 16],
#  [36, 69, 53, 90, 75, 25, 82, 39],
#  [31, 10, 84, 42, 70, 48, 20, 10, 72]]
#
# The best backwards path is [84, 53, 78, 91, 38, 98, 52, 81] with a sum of 575
#  81 is the picked number in the next row
#
# Current Path Sum= 3244 after row 48
#
#
#
#
# Original Cone of choices
# [[52, 36],
#  [98, 27, 28],
#  [38, 26, 8, 15],
#  [78, 91, 73, 51, 69],
#  [71, 78, 33, 67, 9, 16],
#  [69, 53, 90, 75, 25, 82, 39],
#  [10, 84, 42, 70, 48, 20, 10, 72],
#  [60, 25, 1, 7, 61, 71, 37, 92, 40]]
#
# The best backwards path is [25, 84, 53, 78, 91, 38, 98, 52] with a sum of 519
#  52 is the picked number in the next row
#
# Current Path Sum= 3296 after row 49
#
#
#
#
# Original Cone of choices
# [[98, 27],
#  [38, 26, 8],
#  [78, 91, 73, 51],
#  [71, 78, 33, 67, 9],
#  [69, 53, 90, 75, 25, 82],
#  [10, 84, 42, 70, 48, 20, 10],
#  [60, 25, 1, 7, 61, 71, 37, 92],
#  [81, 6, 14, 18, 17, 5, 31, 50, 92]]
#
# The best backwards path is [81, 60, 10, 69, 71, 78, 38, 98] with a sum of 505
#  98 is the picked number in the next row
#
# Current Path Sum= 3394 after row 50
#
#
#
#
# Original Cone of choices
# [[38, 26],
#  [78, 91, 73],
#  [71, 78, 33, 67],
#  [69, 53, 90, 75, 25],
#  [10, 84, 42, 70, 48, 20],
#  [60, 25, 1, 7, 61, 71, 37],
#  [81, 6, 14, 18, 17, 5, 31, 50],
#  [77, 13, 24, 55, 11, 65, 26, 91, 1]]
#
# The best backwards path is [77, 81, 60, 10, 69, 71, 78, 38] with a sum of 484
#  38 is the picked number in the next row
#
# Current Path Sum= 3432 after row 51
#
#
#
#
# Original Cone of choices
# [[78, 91],
#  [71, 78, 33],
#  [69, 53, 90, 75],
#  [10, 84, 42, 70, 48],
#  [60, 25, 1, 7, 61, 71],
#  [81, 6, 14, 18, 17, 5, 31],
#  [77, 13, 24, 55, 11, 65, 26, 91],
#  [80, 6, 23, 84, 75, 23, 87, 72, 99]]
#
# The best backwards path is [87, 65, 17, 61, 70, 90, 78, 78] with a sum of 546
#  78 is the picked number in the next row
#
# Current Path Sum= 3510 after row 52
#
#
#
#
# Original Cone of choices
# [[71, 78],
#  [69, 53, 90],
#  [10, 84, 42, 70],
#  [60, 25, 1, 7, 61],
#  [81, 6, 14, 18, 17, 5],
#  [77, 13, 24, 55, 11, 65, 26],
#  [80, 6, 23, 84, 75, 23, 87, 72],
#  [3, 32, 39, 24, 74, 47, 26, 90, 13]]
#
# The best backwards path is [90, 87, 65, 17, 61, 70, 90, 78] with a sum of 558
#  78 is the picked number in the next row
#
# Current Path Sum= 3588 after row 53
#
#
#
#
# Original Cone of choices
# [[53, 90],
#  [84, 42, 70],
#  [25, 1, 7, 61],
#  [6, 14, 18, 17, 5],
#  [13, 24, 55, 11, 65, 26],
#  [6, 23, 84, 75, 23, 87, 72],
#  [32, 39, 24, 74, 47, 26, 90, 13],
#  [14, 47, 34, 55, 16, 49, 24, 23, 29]]
#
# The best backwards path is [23, 90, 87, 65, 17, 61, 70, 90] with a sum of 503
#  90 is the picked number in the next row
#
# Current Path Sum= 3678 after row 54
#
#
#
#
# Original Cone of choices
# [[42, 70],
#  [1, 7, 61],
#  [14, 18, 17, 5],
#  [24, 55, 11, 65, 26],
#  [23, 84, 75, 23, 87, 72],
#  [39, 24, 74, 47, 26, 90, 13],
#  [47, 34, 55, 16, 49, 24, 23, 29],
#  [36, 36, 81, 26, 97, 36, 48, 54, 56]]
#
# The best backwards path is [54, 23, 90, 87, 65, 17, 61, 70] with a sum of 467
#  70 is the picked number in the next row
#
# Current Path Sum= 3748 after row 55
#
#
#
#
# Original Cone of choices
# [[7, 61],
#  [18, 17, 5],
#  [55, 11, 65, 26],
#  [84, 75, 23, 87, 72],
#  [24, 74, 47, 26, 90, 13],
#  [34, 55, 16, 49, 24, 23, 29],
#  [36, 81, 26, 97, 36, 48, 54, 56],
#  [47, 68, 87, 3, 84, 23, 44, 89, 72]]
#
# The best backwards path is [89, 54, 23, 90, 87, 65, 17, 61] with a sum of 486
#  61 is the picked number in the next row
#
# Current Path Sum= 3809 after row 56
#
#
#
#
# Original Cone of choices
# [[17, 5],
#  [11, 65, 26],
#  [75, 23, 87, 72],
#  [74, 47, 26, 90, 13],
#  [55, 16, 49, 24, 23, 29],
#  [81, 26, 97, 36, 48, 54, 56],
#  [68, 87, 3, 84, 23, 44, 89, 72],
#  [35, 89, 89, 41, 3, 64, 56, 97, 87]]
#
# The best backwards path is [97, 89, 54, 23, 90, 87, 65, 17] with a sum of 522
#  17 is the picked number in the next row
#
# Current Path Sum= 3826 after row 57
#
#
#
#
# Original Cone of choices
# [[11, 65],
#  [75, 23, 87],
#  [74, 47, 26, 90],
#  [55, 16, 49, 24, 23],
#  [81, 26, 97, 36, 48, 54],
#  [68, 87, 3, 84, 23, 44, 89],
#  [35, 89, 89, 41, 3, 64, 56, 97],
#  [14, 12, 90, 99, 32, 77, 56, 41, 18]]
#
# The best backwards path is [41, 97, 89, 54, 23, 90, 87, 65] with a sum of 546
#  65 is the picked number in the next row
#
# Current Path Sum= 3891 after row 58
#
#
#
#
# Original Cone of choices
# [[23, 87],
#  [47, 26, 90],
#  [16, 49, 24, 23],
#  [26, 97, 36, 48, 54],
#  [87, 3, 84, 23, 44, 89],
#  [89, 89, 41, 3, 64, 56, 97],
#  [12, 90, 99, 32, 77, 56, 41, 18],
#  [39, 73, 79, 73, 19, 97, 32, 64, 29]]
#
# The best backwards path is [79, 99, 41, 84, 97, 49, 26, 87] with a sum of 562
#  87 is the picked number in the next row
#
# Current Path Sum= 3978 after row 59
#
#
#
#
# Original Cone of choices
# [[26, 90],
#  [49, 24, 23],
#  [97, 36, 48, 54],
#  [3, 84, 23, 44, 89],
#  [89, 41, 3, 64, 56, 97],
#  [90, 99, 32, 77, 56, 41, 18],
#  [73, 79, 73, 19, 97, 32, 64, 29],
#  [47, 27, 1, 88, 66, 99, 21, 41, 95]]
#
# The best backwards path is [27, 79, 99, 41, 84, 97, 49, 26] with a sum of 502
#  26 is the picked number in the next row
#
# Current Path Sum= 4004 after row 60
#
#
#
#
# Original Cone of choices
# [[49, 24],
#  [97, 36, 48],
#  [3, 84, 23, 44],
#  [89, 41, 3, 64, 56],
#  [90, 99, 32, 77, 56, 41],
#  [73, 79, 73, 19, 97, 32, 64],
#  [47, 27, 1, 88, 66, 99, 21, 41],
#  [87, 9, 81, 95, 22, 28, 76, 69, 46]]
#
# The best backwards path is [76, 99, 97, 77, 3, 84, 97, 49] with a sum of 582
#  49 is the picked number in the next row
#
# Current Path Sum= 4053 after row 61
#
#
#
#
# Original Cone of choices
# [[97, 36],
#  [3, 84, 23],
#  [89, 41, 3, 64],
#  [90, 99, 32, 77, 56],
#  [73, 79, 73, 19, 97, 32],
#  [47, 27, 1, 88, 66, 99, 21],
#  [87, 9, 81, 95, 22, 28, 76, 69],
#  [54, 19, 86, 67, 68, 55, 66, 84, 65]]
#
# The best backwards path is [84, 76, 99, 97, 77, 3, 84, 97] with a sum of 617
#  97 is the picked number in the next row
#
# Current Path Sum= 4150 after row 62
#
#
#
#
# Original Cone of choices
# [[3, 84],
#  [89, 41, 3],
#  [90, 99, 32, 77],
#  [73, 79, 73, 19, 97],
#  [47, 27, 1, 88, 66, 99],
#  [87, 9, 81, 95, 22, 28, 76],
#  [54, 19, 86, 67, 68, 55, 66, 84],
#  [10, 8, 35, 14, 37, 57, 23, 65, 67]]
#
# The best backwards path is [67, 84, 76, 99, 97, 77, 3, 84] with a sum of 587
#  84 is the picked number in the next row
#
# Current Path Sum= 4234 after row 63
#
#
#
#
# Original Cone of choices
# [[41, 3],
#  [99, 32, 77],
#  [79, 73, 19, 97],
#  [27, 1, 88, 66, 99],
#  [9, 81, 95, 22, 28, 76],
#  [19, 86, 67, 68, 55, 66, 84],
#  [8, 35, 14, 37, 57, 23, 65, 67],
#  [44, 25, 71, 87, 16, 70, 85, 19, 25]]
#
# The best backwards path is [25, 67, 84, 76, 99, 97, 77, 3] with a sum of 528
#  3 is the picked number in the next row
#
# Current Path Sum= 4237 after row 64
#
#
#
#
# Original Cone of choices
# [[32, 77],
#  [73, 19, 97],
#  [1, 88, 66, 99],
#  [81, 95, 22, 28, 76],
#  [86, 67, 68, 55, 66, 84],
#  [35, 14, 37, 57, 23, 65, 67],
#  [25, 71, 87, 16, 70, 85, 19, 25],
#  [23, 69, 73, 72, 7, 5, 27, 61, 24]]
#
# The best backwards path is [61, 25, 67, 84, 76, 99, 97, 77] with a sum of 586
#  77 is the picked number in the next row
#
# Current Path Sum= 4314 after row 65
#
#
#
#
# Original Cone of choices
# [[19, 97],
#  [88, 66, 99],
#  [95, 22, 28, 76],
#  [67, 68, 55, 66, 84],
#  [14, 37, 57, 23, 65, 67],
#  [71, 87, 16, 70, 85, 19, 25],
#  [69, 73, 72, 7, 5, 27, 61, 24],
#  [31, 77, 8, 9, 48, 44, 80, 90, 22]]
#
# The best backwards path is [90, 61, 25, 67, 84, 76, 99, 97] with a sum of 599
#  97 is the picked number in the next row
#
# Current Path Sum= 4411 after row 66
#
#
#
#
# Original Cone of choices
# [[66, 99],
#  [22, 28, 76],
#  [68, 55, 66, 84],
#  [37, 57, 23, 65, 67],
#  [87, 16, 70, 85, 19, 25],
#  [73, 72, 7, 5, 27, 61, 24],
#  [77, 8, 9, 48, 44, 80, 90, 22],
#  [60, 46, 37, 91, 39, 75, 75, 18, 58]]
#
# The best backwards path is [18, 90, 61, 25, 67, 84, 76, 99] with a sum of 520
#  99 is the picked number in the next row
#
# Current Path Sum= 4510 after row 67
#
#
#
#
# Original Cone of choices
# [[28, 76],
#  [55, 66, 84],
#  [57, 23, 65, 67],
#  [16, 70, 85, 19, 25],
#  [72, 7, 5, 27, 61, 24],
#  [8, 9, 48, 44, 80, 90, 22],
#  [46, 37, 91, 39, 75, 75, 18, 58],
#  [52, 33, 61, 36, 27, 28, 46, 98, 14]]
#
# The best backwards path is [98, 18, 90, 61, 25, 67, 84, 76] with a sum of 519
#  76 is the picked number in the next row
#
# Current Path Sum= 4586 after row 68
#
#
#
#
# Original Cone of choices
# [[66, 84],
#  [23, 65, 67],
#  [70, 85, 19, 25],
#  [7, 5, 27, 61, 24],
#  [9, 48, 44, 80, 90, 22],
#  [37, 91, 39, 75, 75, 18, 58],
#  [33, 61, 36, 27, 28, 46, 98, 14],
#  [99, 22, 48, 90, 20, 5, 96, 75, 95]]
#
# The best backwards path is [96, 46, 75, 80, 27, 85, 65, 66] with a sum of 540
#  66 is the picked number in the next row
#
# Current Path Sum= 4652 after row 69
#
#
#
#
# Original Cone of choices
# [[23, 65],
#  [70, 85, 19],
#  [7, 5, 27, 61],
#  [9, 48, 44, 80, 90],
#  [37, 91, 39, 75, 75, 18],
#  [33, 61, 36, 27, 28, 46, 98],
#  [99, 22, 48, 90, 20, 5, 96, 75],
#  [59, 21, 89, 34, 96, 91, 48, 76, 43]]
#
# The best backwards path is [76, 96, 46, 75, 80, 27, 85, 65] with a sum of 550
#  65 is the picked number in the next row
#
# Current Path Sum= 4717 after row 70
#
#
#
#
# Original Cone of choices
# [[85, 19],
#  [5, 27, 61],
#  [48, 44, 80, 90],
#  [91, 39, 75, 75, 18],
#  [61, 36, 27, 28, 46, 98],
#  [22, 48, 90, 20, 5, 96, 75],
#  [21, 89, 34, 96, 91, 48, 76, 43],
#  [68, 22, 7, 9, 49, 34, 31, 77, 49]]
#
# The best backwards path is [77, 76, 96, 46, 75, 80, 27, 85] with a sum of 562
#  85 is the picked number in the next row
#
# Current Path Sum= 4802 after row 71
#
#
#
#
# Original Cone of choices
# [[5, 27],
#  [48, 44, 80],
#  [91, 39, 75, 75],
#  [61, 36, 27, 28, 46],
#  [22, 48, 90, 20, 5, 96],
#  [21, 89, 34, 96, 91, 48, 76],
#  [68, 22, 7, 9, 49, 34, 31, 77],
#  [31, 66, 10, 98, 65, 83, 21, 5, 56]]
#
# The best backwards path is [56, 77, 76, 96, 46, 75, 80, 27] with a sum of 533
#  27 is the picked number in the next row
#
# Current Path Sum= 4829 after row 72
#
#
#
#
# Original Cone of choices
# [[44, 80],
#  [39, 75, 75],
#  [36, 27, 28, 46],
#  [48, 90, 20, 5, 96],
#  [89, 34, 96, 91, 48, 76],
#  [22, 7, 9, 49, 34, 31, 77],
#  [66, 10, 98, 65, 83, 21, 5, 56],
#  [89, 28, 81, 5, 99, 66, 81, 86, 38]]
#
# The best backwards path is [86, 56, 77, 76, 96, 46, 75, 80] with a sum of 592
#  80 is the picked number in the next row
#
# Current Path Sum= 4909 after row 73
#
#
#
#
# Original Cone of choices
# [[75, 75],
#  [27, 28, 46],
#  [90, 20, 5, 96],
#  [34, 96, 91, 48, 76],
#  [7, 9, 49, 34, 31, 77],
#  [10, 98, 65, 83, 21, 5, 56],
#  [28, 81, 5, 99, 66, 81, 86, 38],
#  [65, 97, 86, 9, 50, 94, 68, 69, 74]]
#
# The best backwards path is [69, 86, 56, 77, 76, 96, 46, 75] with a sum of 581
#  75 is the picked number in the next row
#
# Current Path Sum= 4984 after row 74
#
#
#
#
# Original Cone of choices
# [[27, 28],
#  [90, 20, 5],
#  [34, 96, 91, 48],
#  [7, 9, 49, 34, 31],
#  [10, 98, 65, 83, 21, 5],
#  [28, 81, 5, 99, 66, 81, 86],
#  [65, 97, 86, 9, 50, 94, 68, 69],
#  [56, 8, 28, 33, 40, 94, 76, 90, 85]]
#
# The best backwards path is [76, 94, 66, 83, 49, 96, 90, 27] with a sum of 581
#  27 is the picked number in the next row
#
# Current Path Sum= 5011 after row 75
#
#
#
#
# Original Cone of choices
# [[90, 20],
#  [34, 96, 91],
#  [7, 9, 49, 34],
#  [10, 98, 65, 83, 21],
#  [28, 81, 5, 99, 66, 81],
#  [65, 97, 86, 9, 50, 94, 68],
#  [56, 8, 28, 33, 40, 94, 76, 90],
#  [78, 22, 94, 34, 40, 68, 87, 84, 25]]
#
# The best backwards path is [87, 94, 94, 66, 83, 49, 96, 90] with a sum of 659
#  90 is the picked number in the next row
#
# Current Path Sum= 5101 after row 76
#
#
#
#
# Original Cone of choices
# [[34, 96],
#  [7, 9, 49],
#  [10, 98, 65, 83],
#  [28, 81, 5, 99, 66],
#  [65, 97, 86, 9, 50, 94],
#  [56, 8, 28, 33, 40, 94, 76],
#  [78, 22, 94, 34, 40, 68, 87, 84],
#  [37, 40, 83, 64, 83, 58, 85, 17, 76]]
#
# The best backwards path is [76, 84, 76, 94, 66, 83, 49, 96] with a sum of 624
#  96 is the picked number in the next row
#
# Current Path Sum= 5197 after row 77
#
#
#
#
# Original Cone of choices
# [[9, 49],
#  [98, 65, 83],
#  [81, 5, 99, 66],
#  [97, 86, 9, 50, 94],
#  [8, 28, 33, 40, 94, 76],
#  [22, 94, 34, 40, 68, 87, 84],
#  [40, 83, 64, 83, 58, 85, 17, 76],
#  [65, 76, 99, 79, 34, 65, 79, 27, 55]]
#
# The best backwards path is [55, 76, 84, 76, 94, 66, 83, 49] with a sum of 583
#  49 is the picked number in the next row
#
# Current Path Sum= 5246 after row 78
#
#
#
#
# Original Cone of choices
# [[65, 83],
#  [5, 99, 66],
#  [86, 9, 50, 94],
#  [28, 33, 40, 94, 76],
#  [94, 34, 40, 68, 87, 84],
#  [83, 64, 83, 58, 85, 17, 76],
#  [76, 99, 79, 34, 65, 79, 27, 55],
#  [23, 14, 15, 80, 97, 44, 78, 49, 35]]
#
# The best backwards path is [78, 79, 85, 87, 94, 50, 99, 65] with a sum of 637
#  65 is the picked number in the next row
#
# Current Path Sum= 5311 after row 79
#
#
#
#
# Original Cone of choices
# [[5, 99],
#  [86, 9, 50],
#  [28, 33, 40, 94],
#  [94, 34, 40, 68, 87],
#  [83, 64, 83, 58, 85, 17],
#  [76, 99, 79, 34, 65, 79, 27],
#  [23, 14, 15, 80, 97, 44, 78, 49],
#  [99, 86, 72, 45, 25, 10, 28, 19, 6]]
#
# The best backwards path is [19, 78, 79, 85, 87, 94, 50, 99] with a sum of 591
#  99 is the picked number in the next row
#
# Current Path Sum= 5410 after row 80
#
#
#
#
# Original Cone of choices
# [[9, 50],
#  [33, 40, 94],
#  [34, 40, 68, 87],
#  [64, 83, 58, 85, 17],
#  [99, 79, 34, 65, 79, 27],
#  [14, 15, 80, 97, 44, 78, 49],
#  [86, 72, 45, 25, 10, 28, 19, 6],
#  [27, 73, 17, 35, 53, 18, 35, 45, 54]]
#
# The best backwards path is [45, 19, 78, 79, 85, 87, 94, 50] with a sum of 537
#  50 is the picked number in the next row
#
# Current Path Sum= 5460 after row 81
#
#
#
#
# Original Cone of choices
# [[40, 94],
#  [40, 68, 87],
#  [83, 58, 85, 17],
#  [79, 34, 65, 79, 27],
#  [15, 80, 97, 44, 78, 49],
#  [72, 45, 25, 10, 28, 19, 6],
#  [73, 17, 35, 53, 18, 35, 45, 54],
#  [41, 25, 45, 18, 69, 96, 88, 36, 93]]
#
# The best backwards path is [45, 35, 25, 97, 65, 85, 87, 94] with a sum of 533
#  94 is the picked number in the next row
#
# Current Path Sum= 5554 after row 82
#
#
#
#
# Original Cone of choices
# [[68, 87],
#  [58, 85, 17],
#  [34, 65, 79, 27],
#  [80, 97, 44, 78, 49],
#  [45, 25, 10, 28, 19, 6],
#  [17, 35, 53, 18, 35, 45, 54],
#  [25, 45, 18, 69, 96, 88, 36, 93],
#  [50, 99, 73, 5, 93, 48, 17, 31, 70]]
#
# The best backwards path is [99, 45, 35, 25, 97, 65, 85, 87] with a sum of 538
#  87 is the picked number in the next row
#
# Current Path Sum= 5641 after row 83
#
#
#
#
# Original Cone of choices
# [[85, 17],
#  [65, 79, 27],
#  [97, 44, 78, 49],
#  [25, 10, 28, 19, 6],
#  [35, 53, 18, 35, 45, 54],
#  [45, 18, 69, 96, 88, 36, 93],
#  [99, 73, 5, 93, 48, 17, 31, 70],
#  [34, 23, 51, 4, 83, 99, 75, 90, 63]]
#
# The best backwards path is [75, 17, 88, 45, 19, 78, 79, 85] with a sum of 486
#  85 is the picked number in the next row
#
# Current Path Sum= 5726 after row 84
#
#
#
#
# Original Cone of choices
# [[65, 79],
#  [97, 44, 78],
#  [25, 10, 28, 19],
#  [35, 53, 18, 35, 45],
#  [45, 18, 69, 96, 88, 36],
#  [99, 73, 5, 93, 48, 17, 31],
#  [34, 23, 51, 4, 83, 99, 75, 90],
#  [62, 65, 18, 99, 76, 49, 18, 72, 66]]
#
# The best backwards path is [72, 75, 17, 88, 45, 19, 78, 79] with a sum of 473
#  79 is the picked number in the next row
#
# Current Path Sum= 5805 after row 85
#
#
#
#
# Original Cone of choices
# [[44, 78],
#  [10, 28, 19],
#  [53, 18, 35, 45],
#  [18, 69, 96, 88, 36],
#  [73, 5, 93, 48, 17, 31],
#  [23, 51, 4, 83, 99, 75, 90],
#  [65, 18, 99, 76, 49, 18, 72, 66],
#  [88, 97, 32, 14, 6, 35, 78, 20, 71]]
#
# The best backwards path is [32, 99, 4, 93, 96, 35, 28, 78] with a sum of 465
#  78 is the picked number in the next row
#
# Current Path Sum= 5883 after row 86
#
#
#
#
# Original Cone of choices
# [[28, 19],
#  [18, 35, 45],
#  [69, 96, 88, 36],
#  [5, 93, 48, 17, 31],
#  [51, 4, 83, 99, 75, 90],
#  [18, 99, 76, 49, 18, 72, 66],
#  [97, 32, 14, 6, 35, 78, 20, 71],
#  [50, 90, 65, 1, 87, 42, 47, 74, 35]]
#
# The best backwards path is [65, 14, 76, 83, 93, 96, 35, 19] with a sum of 481
#  19 is the picked number in the next row
#
# Current Path Sum= 5902 after row 87
#
#
#
#
# Original Cone of choices
# [[35, 45],
#  [96, 88, 36],
#  [93, 48, 17, 31],
#  [4, 83, 99, 75, 90],
#  [99, 76, 49, 18, 72, 66],
#  [32, 14, 6, 35, 78, 20, 71],
#  [90, 65, 1, 87, 42, 47, 74, 35],
#  [85, 85, 80, 53, 34, 87, 58, 98, 88]]
#
# The best backwards path is [85, 65, 14, 76, 83, 93, 96, 35] with a sum of 547
#  35 is the picked number in the next row
#
# Current Path Sum= 5937 after row 88
#
#
#
#
# Original Cone of choices
# [[96, 88],
#  [93, 48, 17],
#  [4, 83, 99, 75],
#  [99, 76, 49, 18, 72],
#  [32, 14, 6, 35, 78, 20],
#  [90, 65, 1, 87, 42, 47, 74],
#  [85, 85, 80, 53, 34, 87, 58, 98],
#  [28, 83, 15, 75, 99, 1, 89, 85, 79]]
#
# The best backwards path is [83, 85, 65, 14, 76, 83, 93, 96] with a sum of 595
#  96 is the picked number in the next row
#
# Current Path Sum= 6033 after row 89
#
#
#
#
# Original Cone of choices
# [[93, 48],
#  [4, 83, 99],
#  [99, 76, 49, 18],
#  [32, 14, 6, 35, 78],
#  [90, 65, 1, 87, 42, 47],
#  [85, 85, 80, 53, 34, 87, 58],
#  [28, 83, 15, 75, 99, 1, 89, 85],
#  [91, 39, 50, 31, 42, 64, 70, 4, 46]]
#
# The best backwards path is [70, 89, 87, 42, 35, 49, 83, 93] with a sum of 548
#  93 is the picked number in the next row
#
# Current Path Sum= 6126 after row 90
#
#
#
#
# Original Cone of choices
# [[4, 83],
#  [99, 76, 49],
#  [32, 14, 6, 35],
#  [90, 65, 1, 87, 42],
#  [85, 85, 80, 53, 34, 87],
#  [28, 83, 15, 75, 99, 1, 89],
#  [91, 39, 50, 31, 42, 64, 70, 4],
#  [62, 74, 69, 4, 85, 57, 77, 35, 58]]
#
# The best backwards path is [69, 50, 83, 85, 65, 14, 76, 83] with a sum of 525
#  83 is the picked number in the next row
#
# Current Path Sum= 6209 after row 91
#
#
#
#
# Original Cone of choices
# [[76, 49],
#  [14, 6, 35],
#  [65, 1, 87, 42],
#  [85, 80, 53, 34, 87],
#  [83, 15, 75, 99, 1, 89],
#  [39, 50, 31, 42, 64, 70, 4],
#  [74, 69, 4, 85, 57, 77, 35, 58],
#  [68, 39, 51, 56, 59, 63, 7, 25, 70]]
#
# The best backwards path is [68, 74, 39, 83, 85, 65, 14, 76] with a sum of 504
#  76 is the picked number in the next row
#
# Current Path Sum= 6285 after row 92
#
#
#
#
# Adding in 504 for the final 8 rows, and the grand total of 6789
# [[59], [41], [40], [53], [87], [66], [80], [76], [62], [79], [81], [32], [86], [82], [75], [77], [69], [13], [35], [65], [90], [96], [88], [54], [19], [98], [57], [88], [41], [89], [2], [85], [51], [78], [84], [56], [84], [72], [98], [84], [78], [56], [36], [51], [19], [88], [67], [96], [81], [52], [98], [38], [78], [78], [90], [70], [61], [17], [65], [87], [26], [49], [97], [84], [3], [77], [97], [99], [76], [66], [65], [85], [27], [80], [75], [27], [90], [96], [49], [65], [99], [50], [94], [87], [85], [79], [78], [19], [35], [96], [93], [83], [76], [14, 6], [65, 1, 87], [85, 80, 53, 34], [83, 15, 75, 99, 1], [39, 50, 31, 42, 64, 70], [74, 69, 4, 85, 57, 77, 35], [68, 39, 51, 56, 59, 63, 7, 25]]
